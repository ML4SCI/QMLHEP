U_5_cost = [0.9273785466931606, 0.7911960377043499, 0.8617751531896799, 0.983694073272247, 0.904458275541328, 0.898412331777436, 0.9126325519866896, 0.9083521962804674, 0.861834469207739, 0.9347090937893656, 0.8733573880029022, 0.7502549309640255, 0.7815077902214304, 0.7671423552174417, 0.7943562049995746, 0.7512312378508067, 0.8054542251203859, 0.7869146181214444, 0.8091189264955394, 0.7222197955254325, 0.7934269891896847, 0.808325313223993, 0.7652992857697817, 0.7115482533172739, 0.778213678676694, 0.7663913866459922, 0.7539732519877271, 0.7507101061131638, 0.700402206401691, 0.734429140426376, 0.8020474404871449, 0.757844712695086, 0.7262227039395364, 0.6768339278839145, 0.7238682218960297, 0.7307628909434865, 0.7072719675353524, 0.7224566607145884, 0.7547584566869537, 0.7559124637542876]

# %%
import matplotlib.pyplot as plt
import numpy as np
# MNIST
# 12k train. 2k test. lr = 0.01. batch_size = 64. MSE cost
plt.plot(np.arange(0, 200, 5), U2_equiv_cost, label = "EQCNN: U2_equiv")
plt.plot(np.arange(0, 200, 5), U_9_cost, label = "QCNN: U_9")
plt.plot(np.arange(0, 200, 5), U_5_cost, label = "QCNN: U_5")
plt.plot(np.arange(0, 200, 5), U_15_cost, label = "QCNN: U_15")
plt.plot(np.arange(0, 200, 5), U_TTN_cost, label = "QCNN: U_TTN")

plt.title("Loss plot benchmark")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
from tabulate import tabulate

# Datos de accuracy para cada modelo
accuracy_data = [
    ["EQCNN: U2_equiv", 0.9664, 18 ],
    ["QCNN: U_9", 0.9404, 12 ],
    ["QCNN: U_5", 0.9361, 36  ],
    ["QCNN: U_15", 0.7569, 20],
    ["QCNN: U_TTN", 0.5919,12 ],
]

# Crear y mostrar la tabla
table = tabulate(accuracy_data, headers=["Model", "Accuracy", "params"], tablefmt="pretty")
print(table)
# Out:
# +-----------------+----------+--------+
# |      Model      | Accuracy | params |
# +-----------------+----------+--------+
# | EQCNN: U2_equiv |  0.9664  |   18   |
# |    QCNN: U_9    |  0.9404  |   12   |
# |    QCNN: U_5    |  0.9361  |   36   |
# |   QCNN: U_15    |  0.7569  |   20   |
# |   QCNN: U_TTN   |  0.5919  |   12   |
# +-----------------+----------+--------+

# %% [markdown]
# ### Fashion_mnist

# %%
loss_cost_U2_equiv = [
    1.0028235912112904, 1.0026366806636995, 0.9851950362325516, 0.941238215603494,
    0.8662559351724705, 0.8165314237827126, 0.6886422062584237, 0.7179998985989084,
    0.7391235612113943, 0.6564987447491966, 0.7316744953410658, 0.7050911636018772,
    0.6839225499132099, 0.6449544531141745, 0.6887944464424168, 0.6917179139701661,
    0.6862077643813537, 0.6753870326762251, 0.6484297972137893, 0.6367526255158493,
    0.6113709824906717, 0.6825666742981795, 0.6283511255910282, 0.7088077995543746,
    0.6343914697740969, 0.6375505949479426, 0.6763694863903341, 0.6868381051853705,
    0.7059507682089725, 0.6083405470769789, 0.632098762210195, 0.6483297479388863,
    0.6179783042273965, 0.6311804919985274, 0.5763705210984675, 0.6413300641189663,
    0.6695806223689537, 0.5572895835566354, 0.7060310984479734, 0.5975034762529126
]
loss_cost_U_TTN = [
    0.9624748703216538, 0.926597498666682, 0.9458004918375128, 0.9771304131036779,
    0.8296565653604513, 0.8994435016123271, 0.8363801544757925, 0.8409490537473661,
    0.8565033025281541, 0.8800839012990939, 0.9222744471122934, 0.8653654819868097,
    0.8480473852462052, 0.8736730803785377, 0.8686945401051509, 0.8338148696006465,
    0.9434336510532134, 0.8484137365653633, 0.7993144166743718, 0.8728234679812367,
    0.7901028730627149, 0.8330099352757805, 0.7865023269070471, 0.7562405008238082,
    0.750888561927062, 0.8241335531160725, 0.7294627466563132, 0.7404301748157344,
    0.7567340477063034, 0.7653825481713772, 0.7547357467157008, 0.6949074577046375,
    0.7456360969744461, 0.7648167996576505, 0.6940298662892713, 0.817735023057339,
    0.6359003679763281, 0.6959921954621897, 0.7297171323005154, 0.7174673283725733
]
loss_cost_U_9 = [
    0.9259972666484617, 0.9217026082928913, 0.9338764426642028, 0.8948319524311715,
    0.9174923416497115, 0.8817179017018262, 0.896088544366823, 0.8849890720097477,
    0.8824157374185515, 0.8871669266271617, 0.8983364591064746, 0.8934424359529686,
    0.8945553098824536, 0.8170196335042079, 0.8598285134553925, 0.843995684732734,
    0.8357811046790251, 0.8777442677937939, 0.8109870115770228, 0.8417382263161673,
    0.8576012437279517, 0.8749270930877742, 0.8276396397816762, 0.8054608153226268,
    0.8152807710329258, 0.860024810093596, 0.826233474299814, 0.7737252766110874,
    0.8361276783932614, 0.8172698111115637, 0.7935617999132244, 0.8233856121121964,
    0.762665924392406, 0.8702231851507656, 0.8046273317476316, 0.7950134331145782,
    0.8137873657543648, 0.8030285488362535, 0.7648437126074191, 0.8646377727149008
]
loss_cost_U_15 = [
    1.042670691499952, 0.9982716894477821, 0.9529084916790896, 0.90789209199437,
    0.9314843512554659, 0.8881388516731148, 0.8696946077880235, 0.8875280855243539,
    0.8625538982590727, 0.8728970799113819, 0.8688471348316517, 0.8732797406663025,
    0.8743913596223885, 0.8726032322094331, 0.8614619735143021, 0.8549255383218387,
    0.8352182255733245, 0.8300689568590273, 0.8410976153644367, 0.8369532816094571,
    0.8887848918444887, 0.8742193676482288, 0.8530699495827084, 0.8954146652761796,
    0.81095200172503, 0.811148548689826, 0.8213281290852387, 0.8160921962157184,
    0.795587269242448, 0.8230460519301656, 0.8064457155030252, 0.7825989590633551,
    0.8042390899338759, 0.7825044026520886, 0.768575614978411, 0.7626445157585721,
    0.6599935527308738, 0.7120111604928431, 0.7138437386334326, 0.7152705061023049
]
loss_cost_U_5 = [
    1.0838893993524445, 0.9985108953082653, 0.8532594893006386, 0.9686328658227246,
    0.8869988473363607, 0.9871719479961256, 0.9469526534911301, 0.7791150962820886,
    0.7654348374274984, 0.9872541594869232, 0.8622039567410543, 0.7035063043941202,
    0.8032103202835372, 0.7882593495667902, 0.8688661969344994, 0.7896423002825204,
    0.6468250002200159, 0.7269494162082228, 0.8138645266174935, 0.6854864024558446,
    0.6974550825328365, 0.6744614024222858, 0.7103286351309339, 0.7061324276528816,
    0.6703308307496214, 0.6742207729801402, 0.7195829754651993, 0.6614765530295884,
    0.6254073923126362, 0.6828371401000323, 0.6971146964790056, 0.7126401044165975,
    0.6454749370565708, 0.6800113714916417, 0.6801846362285077, 0.6612087761640633,
    0.7135295268824321, 0.6630551983472033, 0.6333365467497618, 0.7091403788480068
]

# %%
# Fahion_MNIST
# 12k train. 2k test. lr = 0.01. batch_size = 64. MSE cost
plt.plot(np.arange(0, 200, 5), loss_cost_U2_equiv, label = "EQCNN: U2_equiv")
plt.plot(np.arange(0, 200, 5), loss_cost_U_9, label = "QCNN: U_9")
plt.plot(np.arange(0, 200, 5), loss_cost_U_5, label = "QCNN: U_5")
plt.plot(np.arange(0, 200, 5), loss_cost_U_15, label = "QCNN: U_15")
plt.plot(np.arange(0, 200, 5), loss_cost_U_TTN, label = "QCNN: U_TTN")

plt.title("Loss plot benchmark")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
from tabulate import tabulate

accuracy_data = [
    ["U2_equiv img16x16x1", 0.877, 12],
    ["U_15 img16x16x1", 0.8555, 20],
    ["U_5 img16x16x1", 0.8505, 36 ],
    ["U_TTN img16x16x1", 0.8085, 12],
    ["U_9 img16x16x1", 0.7335, 12],
]

table = tabulate(accuracy_data, headers=["Model", "Accuracy", "params"], tablefmt="pretty")
print(table)
# Out:
# +---------------------+----------+--------+
# |        Model        | Accuracy | params |
# +---------------------+----------+--------+
# | U2_equiv img16x16x1 |  0.877   |   12   |
# |   U_15 img16x16x1   |  0.8555  |   20   |
# |   U_5 img16x16x1    |  0.8505  |   36   |
# |  U_TTN img16x16x1   |  0.8085  |   12   |
# |   U_9 img16x16x1    |  0.7335  |   12   |
# +---------------------+----------+--------+

# %% [markdown]
# ### quark_gluon

# %%
#batch_size 64 #BCE
cost_U2_equiv = [
    88.9935590105756,
    88.56664901103913,
    88.87389218114,
    88.97805630564322,
    88.9597608242989,
    88.83005752190249,
    88.80236343795178,
    88.45936976246895,
    88.61712384491265,
    88.64920098532404
]

cost_U_5 = [
    99.86190693306882,
    96.8008725774673,
    89.87760991794748,
    88.89692862986499,
    89.2281294041484,
    92.09815243426851,
    92.3784216144862,
    89.1508224091963,
    102.2351202622035,
    94.75506629373098
]




# batch 128. lr = 0.05 #BCE
cost_U2_equiv_128 = [
    88.9935590105756,
    88.56664901103913,
    88.87389218114,
    88.97805630564322,
    88.9597608242989,
    88.83005752190249,
    88.80236343795178,
    88.45936976246895,
    88.61712384491265,
    88.64920098532404
]

cost_U_5_128 = [
    99.86190693306882,
    96.8008725774673,
    89.87760991794748,
    88.89692862986499,
    89.2281294041484,
    92.09815243426851,
    92.3784216144862,
    89.1508224091963,
    102.2351202622035,
    94.75506629373098
]

# %%
# batch 128. lr = 0.05 #BCE

cost_U2_equiv_cross_entropy = [
    88.9935590105756,
    88.56664901103913,
    88.87389218114,
    88.97805630564322,
    88.9597608242989,
    88.83005752190249,
    88.80236343795178,
    88.45936976246895,
    88.61712384491265,
    88.64920098532404
]

cost_U_5_cross_entropy = [
    99.86190693306882,
    96.8008725774673,
    89.87760991794748,
    88.89692862986499,
    89.2281294041484,
    92.09815243426851,
    92.3784216144862,
    89.1508224091963,
    102.2351202622035,
    94.75506629373098
]


#batch 256, lr = 0.01 # MSE
cost_U2_equiv_mse = [
    1.0015045673574117,
    1.0043067789842481,
    0.9988940000087461,
    1.002954662745817,
    1.003463558154517,
    0.9953431345624121,
    1.0008640020439943,
    1.0021156432670375,
    1.0020436623602593,
    0.9938861878176546
]

cost_U_5_mse = [
    0.9751065421436211,
    1.1139035451162629,
    1.0270126291357322,
    0.9899370553378345,
    0.9997961199079859,
    0.9834392478101458,
    0.9951877751244378,
    0.9976684902107925,
    0.9984110370237359,
    0.9911068124706093
]

# %%
# Quark_gluon

## MSE
# 12k train. 2k test. lr = 0.01. batch_size = 64. MSE cost
plt.plot(np.arange(0, 50, 5), cost_U2_equiv_mse, label = "EQCNN: U2_equiv")
plt.plot(np.arange(0, 50, 5), cost_U_5_mse, label = "QCNN: U_5")


plt.title("Loss plot benchmark. MSE")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
