# %% [markdown]
# # Hyperparameter Scan
#
# Simple hyperparameter scan for Latentbits and number of layers on MNIST

# %%
import numpy as np
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit
import tensorflow as tf
import tensorflow_quantum as tfq
from hep_VQAE import data_preprocessing as dp


import warnings
warnings.filterwarnings('ignore')
# Out:
# 2022-06-27 14:47:44.077022: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-27 14:47:44.077053: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-27 14:47:46.022765: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-27 14:47:46.022802: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-27 14:47:46.022826: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tomskopfbahnhof): /proc/driver/nvidia/version does not exist
# 2022-06-27 14:47:46.023154: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Rescale the images from [0,255] to the [0.0,1.0] range.
x_train, x_test = x_train/255.0, x_test/255.0
# Out:
# x_train:  (60000, 28, 28)
# x_test:  (10000, 28, 28)
# y_train:  (60000,)
# y_test:  (10000,)

# %%
def filter_36(x, y):
    keep = (y == 3) | (y == 6)
    x, y = x[keep], y[keep]
    y = y == 3
    return x,y

x_train, y_train = filter_36(x_train, y_train)
x_test, y_test = filter_36(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))
# Out:
# Number of filtered training examples: 12049
# Number of filtered test examples: 1968

# %%
DOWNSCALE = 2
DATA_DIMENSION = DOWNSCALE*DOWNSCALE
LATENT_BITS = 1

x_train, x_test = dp.PCA_reduce(x_train, DATA_DIMENSION, val_data=x_test)
# Out:
# 1.0
# 0.0
# (12049, 4)
# (1968, 4)

# %%
x_train_threes = x_train[y_train==True]
x_train = x_train[y_train==False]

x_test_threes = x_test[y_test==True]
x_test = x_test[y_test==False]

# %% [markdown]
# Build models with different parameters. Additionally safe parameter configurations for later reference

# %%
from hep_VQAE import QAE as qae

models = []
hyperspace = []
latent_bit_poss = [1, 2]
layer_poss = [1,2,3,4,5,6,7]

from itertools import product

for i, j in product(latent_bit_poss, layer_poss):
    model = tf.keras.Sequential([
                             
    # The input is the data-circuit, encoded as a tf.string
        tf.keras.layers.Input(shape=(), dtype=tf.string),
    
    # The PQC stands for Paramaterized Quantum Circuit
    # This returns the expectation value
        qae.QAE_layer(DATA_DIMENSION, i, j),
    ])
    models.append(model)
    hyperspace.append((i,j))

# %% [markdown]
# Since input states depend on number of latent bits, states need to be prepared seperately
#
# (could be simplified since number of layers does not change input state)

# %%
trains = []
tests = []

trains_threes = []
tests_threes = []

for params in hyperspace:
    latent_space, _ = params
    x_train_circuit = [dp.input_states(x,DATA_DIMENSION,latent_space) for x in x_train]
    x_test_circuit = [dp.input_states(x,DATA_DIMENSION,latent_space) for x in x_test]

    x_train_circuit_threes = [dp.input_states(x,DATA_DIMENSION,latent_space) for x in x_train_threes]
    x_test_circuit_threes = [dp.input_states(x,DATA_DIMENSION,latent_space) for x in x_test_threes]

    x_train_tf = tfq.convert_to_tensor(x_train_circuit)
    x_test_tf = tfq.convert_to_tensor(x_test_circuit)

    x_train_tf_threes = tfq.convert_to_tensor(x_train_circuit_threes)
    x_test_tf_threes = tfq.convert_to_tensor(x_test_circuit_threes)
    
    trains.append(x_train_tf)
    tests.append(x_test_tf)
    
    trains_threes.append(x_train_tf_threes)
    tests_threes.append(x_test_tf_threes)

# %%
for model in models:
    model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(lr=0.1))

# %%
y_train_ones = np.ones(shape=len(x_train_tf))
y_test_ones = np.ones(shape=len(x_test_tf))

y_train_ones_threes = np.ones(shape=len(x_train_tf_threes))
y_test_ones_threes = np.ones(shape=len(x_test_tf_threes))

# %% [markdown]
# Train all models and safe all histories

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7)
histories = []
for index, model in enumerate(models):
    x_train_tf = trains[index]
    x_test_tf = tests[index]
    print("Training model with: ", hyperspace[index])
    history = model.fit(x_train_tf, y_train_ones, epochs=50, batch_size=64, validation_data=(x_test_tf, y_test_ones), callbacks=[es])
    histories.append(history)
# Out:
# Training model with:  (1, 1)
# Epoch 1/50
# 93/93 [==============================] - 9s 92ms/step - loss: 0.7817 - val_loss: 0.7701
# Epoch 2/50
# 93/93 [==============================] - 8s 88ms/step - loss: 0.7601 - val_loss: 0.7703
# Epoch 3/50
# 93/93 [==============================] - 8s 85ms/step - loss: 0.7601 - val_loss: 0.7703
# Epoch 4/50
# 93/93 [==============================] - 8s 88ms/step - loss: 0.7599 - val_loss: 0.7705
# Epoch 5/50
# 93/93 [==============================] - 8s 89ms/step - loss: 0.7601 - val_loss: 0.7700
# Epoch 6/50
# 93/93 [==============================] - 8s 86ms/step - loss: 0.7598 - val_loss: 0.7704
# Epoch 7/50
# 93/93 [==============================] - 8s 84ms/step - loss: 0.7599 - val_loss: 0.7704
# Epoch 8/50
# 93/93 [==============================] - 8s 82ms/step - loss: 0.7599 - val_loss: 0.7717
# Epoch 9/50
# 93/93 [==============================] - 8s 82ms/step - loss: 0.7602 - val_loss: 0.7704
# Epoch 10/50
# 93/93 [==============================] - 8s 83ms/step - loss: 0.7599 - val_loss: 0.7708
# Epoch 11/50
# 93/93 [==============================] - 8s 83ms/step - loss: 0.7605 - val_loss: 0.7707
# Epoch 12/50
# 93/93 [==============================] - 8s 83ms/step - loss: 0.7602 - val_loss: 0.7706
# Training model with:  (1, 2)
# Epoch 1/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4384 - val_loss: 0.3818
# Epoch 2/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3766 - val_loss: 0.3814
# Epoch 3/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3764 - val_loss: 0.3809
# Epoch 4/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3760 - val_loss: 0.3814
# Epoch 5/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3758 - val_loss: 0.3817
# Epoch 6/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3763 - val_loss: 0.3796
# Epoch 7/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3759 - val_loss: 0.3779
# Epoch 8/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3767 - val_loss: 0.3774
# Epoch 9/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3767 - val_loss: 0.3814
# Epoch 10/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3767 - val_loss: 0.3803
# Epoch 11/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3761 - val_loss: 0.3834
# Epoch 12/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3760 - val_loss: 0.3788
# Epoch 13/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3761 - val_loss: 0.3780
# Epoch 14/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3762 - val_loss: 0.3815
# Epoch 15/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3759 - val_loss: 0.3823
# Training model with:  (1, 3)
# Epoch 1/50
# 93/93 [==============================] - 17s 179ms/step - loss: 0.4381 - val_loss: 0.3783
# Epoch 2/50
# 93/93 [==============================] - 16s 175ms/step - loss: 0.3693 - val_loss: 0.3731
# Epoch 3/50
# 93/93 [==============================] - 17s 178ms/step - loss: 0.3683 - val_loss: 0.3712
# Epoch 4/50
# 93/93 [==============================] - 17s 181ms/step - loss: 0.3678 - val_loss: 0.3714
# Epoch 5/50
# 93/93 [==============================] - 16s 177ms/step - loss: 0.3678 - val_loss: 0.3744
# Epoch 6/50
# 93/93 [==============================] - 17s 178ms/step - loss: 0.3685 - val_loss: 0.3748
# Epoch 7/50
# 93/93 [==============================] - 16s 176ms/step - loss: 0.3682 - val_loss: 0.3769
# Epoch 8/50
# 93/93 [==============================] - 17s 179ms/step - loss: 0.3686 - val_loss: 0.3784
# Epoch 9/50
# 93/93 [==============================] - 17s 183ms/step - loss: 0.3687 - val_loss: 0.3712
# Epoch 10/50
# 93/93 [==============================] - 16s 175ms/step - loss: 0.3684 - val_loss: 0.3743
# Epoch 11/50
# 93/93 [==============================] - 17s 182ms/step - loss: 0.3682 - val_loss: 0.3722
# Epoch 12/50
# 93/93 [==============================] - 17s 185ms/step - loss: 0.3685 - val_loss: 0.3825
# Epoch 13/50
# 93/93 [==============================] - 19s 203ms/step - loss: 0.3693 - val_loss: 0.3735
# Epoch 14/50
# 93/93 [==============================] - 18s 193ms/step - loss: 0.3682 - val_loss: 0.3732
# Epoch 15/50
# 93/93 [==============================] - 18s 192ms/step - loss: 0.3682 - val_loss: 0.3709
# Epoch 16/50
# 93/93 [==============================] - 17s 185ms/step - loss: 0.3681 - val_loss: 0.3731
# Epoch 17/50
# 93/93 [==============================] - 17s 180ms/step - loss: 0.3690 - val_loss: 0.3735
# Epoch 18/50
# 93/93 [==============================] - 16s 169ms/step - loss: 0.3696 - val_loss: 0.3719
# Epoch 19/50
# 93/93 [==============================] - 16s 172ms/step - loss: 0.3683 - val_loss: 0.3770
# Epoch 20/50
# 93/93 [==============================] - 16s 177ms/step - loss: 0.3683 - val_loss: 0.3703
# Epoch 21/50
# 93/93 [==============================] - 17s 178ms/step - loss: 0.3680 - val_loss: 0.3740
# Epoch 22/50
# 93/93 [==============================] - 16s 176ms/step - loss: 0.3687 - val_loss: 0.3741
# Epoch 23/50
# 93/93 [==============================] - 16s 177ms/step - loss: 0.3682 - val_loss: 0.3734
# Epoch 24/50
# 93/93 [==============================] - 17s 182ms/step - loss: 0.3686 - val_loss: 0.3758
# Epoch 25/50
# 93/93 [==============================] - 17s 180ms/step - loss: 0.3685 - val_loss: 0.3748
# Epoch 26/50
# 93/93 [==============================] - 16s 178ms/step - loss: 0.3686 - val_loss: 0.3775
# Epoch 27/50
# 93/93 [==============================] - 17s 178ms/step - loss: 0.3682 - val_loss: 0.3713
# Training model with:  (1, 4)
# Epoch 1/50
# 93/93 [==============================] - 22s 231ms/step - loss: 0.3935 - val_loss: 0.3507
# Epoch 2/50
# 93/93 [==============================] - 21s 228ms/step - loss: 0.3461 - val_loss: 0.3520
# Epoch 3/50
# 93/93 [==============================] - 21s 230ms/step - loss: 0.3454 - val_loss: 0.3501
# Epoch 4/50
# 93/93 [==============================] - 22s 233ms/step - loss: 0.3453 - val_loss: 0.3507
# Epoch 5/50
# 93/93 [==============================] - 22s 239ms/step - loss: 0.3455 - val_loss: 0.3490
# Epoch 6/50
# 93/93 [==============================] - 22s 241ms/step - loss: 0.3456 - val_loss: 0.3497
# Epoch 7/50
# 93/93 [==============================] - 22s 235ms/step - loss: 0.3452 - val_loss: 0.3536
# Epoch 8/50
# 93/93 [==============================] - 22s 234ms/step - loss: 0.3455 - val_loss: 0.3495
# Epoch 9/50
# 93/93 [==============================] - 23s 249ms/step - loss: 0.3455 - val_loss: 0.3527
# Epoch 10/50
# 93/93 [==============================] - 22s 232ms/step - loss: 0.3450 - val_loss: 0.3513
# Epoch 11/50
# 93/93 [==============================] - 22s 233ms/step - loss: 0.3451 - val_loss: 0.3499
# Epoch 12/50
# 93/93 [==============================] - 23s 247ms/step - loss: 0.3455 - val_loss: 0.3516
# Training model with:  (1, 5)
# Epoch 1/50
# 93/93 [==============================] - 29s 303ms/step - loss: 0.1369 - val_loss: 0.0566
# Epoch 2/50
# 93/93 [==============================] - 27s 290ms/step - loss: 0.0502 - val_loss: 0.0543
# Epoch 3/50
# 93/93 [==============================] - 27s 290ms/step - loss: 0.0504 - val_loss: 0.0512
# Epoch 4/50
# 93/93 [==============================] - 27s 289ms/step - loss: 0.0497 - val_loss: 0.0543
# Epoch 5/50
# 93/93 [==============================] - 27s 292ms/step - loss: 0.0501 - val_loss: 0.0544
# Epoch 6/50
# 93/93 [==============================] - 28s 299ms/step - loss: 0.0504 - val_loss: 0.0513
# Epoch 7/50
# 93/93 [==============================] - 28s 298ms/step - loss: 0.0502 - val_loss: 0.0546
# Epoch 8/50
# 93/93 [==============================] - 28s 300ms/step - loss: 0.0504 - val_loss: 0.0567
# Epoch 9/50
# 93/93 [==============================] - 27s 286ms/step - loss: 0.0505 - val_loss: 0.0509
# Epoch 10/50
# 93/93 [==============================] - 27s 296ms/step - loss: 0.0507 - val_loss: 0.0520
# Epoch 11/50
# 93/93 [==============================] - 26s 285ms/step - loss: 0.0500 - val_loss: 0.0535
# Epoch 12/50
# 93/93 [==============================] - 26s 278ms/step - loss: 0.0497 - val_loss: 0.0571
# Epoch 13/50
# 93/93 [==============================] - 26s 279ms/step - loss: 0.0502 - val_loss: 0.0524
# Epoch 14/50
# 93/93 [==============================] - 26s 284ms/step - loss: 0.0503 - val_loss: 0.0526
# Epoch 15/50
# 93/93 [==============================] - 26s 281ms/step - loss: 0.0507 - val_loss: 0.0515
# Epoch 16/50
# 93/93 [==============================] - 26s 283ms/step - loss: 0.0499 - val_loss: 0.0555
# Training model with:  (1, 6)
# Epoch 1/50
# 93/93 [==============================] - 32s 339ms/step - loss: 0.1224 - val_loss: 0.0524
# Epoch 2/50
# 93/93 [==============================] - 31s 336ms/step - loss: 0.0502 - val_loss: 0.0512
# Epoch 3/50
# 93/93 [==============================] - 30s 321ms/step - loss: 0.0502 - val_loss: 0.0515
# Epoch 4/50
# 93/93 [==============================] - 31s 333ms/step - loss: 0.0498 - val_loss: 0.0526
# Epoch 5/50
# 93/93 [==============================] - 30s 327ms/step - loss: 0.0504 - val_loss: 0.0539
# Epoch 6/50
# 93/93 [==============================] - 31s 332ms/step - loss: 0.0502 - val_loss: 0.0523
# Epoch 7/50
# 93/93 [==============================] - 30s 324ms/step - loss: 0.0498 - val_loss: 0.0506
# Epoch 8/50
# 93/93 [==============================] - 30s 325ms/step - loss: 0.0495 - val_loss: 0.0503
# Epoch 9/50
# 93/93 [==============================] - 31s 334ms/step - loss: 0.0500 - val_loss: 0.0504
# Epoch 10/50
# 93/93 [==============================] - 31s 329ms/step - loss: 0.0500 - val_loss: 0.0517
# Epoch 11/50
# 93/93 [==============================] - 31s 336ms/step - loss: 0.0494 - val_loss: 0.0535
# Epoch 12/50
# 93/93 [==============================] - 30s 323ms/step - loss: 0.0499 - val_loss: 0.0573
# Epoch 13/50
# 93/93 [==============================] - 30s 325ms/step - loss: 0.0512 - val_loss: 0.0499
# Epoch 14/50
# 93/93 [==============================] - 31s 332ms/step - loss: 0.0495 - val_loss: 0.0501
# Epoch 15/50
# 93/93 [==============================] - 30s 319ms/step - loss: 0.0491 - val_loss: 0.0517
# Epoch 16/50
# 93/93 [==============================] - 29s 314ms/step - loss: 0.0493 - val_loss: 0.0514
# Epoch 17/50
# 93/93 [==============================] - 30s 327ms/step - loss: 0.0489 - val_loss: 0.0521
# Epoch 18/50
# 93/93 [==============================] - 31s 333ms/step - loss: 0.0495 - val_loss: 0.0513
# Epoch 19/50
# 93/93 [==============================] - 31s 331ms/step - loss: 0.0491 - val_loss: 0.0518
# Epoch 20/50
# 93/93 [==============================] - 31s 334ms/step - loss: 0.0499 - val_loss: 0.0523
# Training model with:  (1, 7)
# Epoch 1/50
# 93/93 [==============================] - 36s 380ms/step - loss: 0.0971 - val_loss: 0.0532
# Epoch 2/50
# 93/93 [==============================] - 35s 380ms/step - loss: 0.0482 - val_loss: 0.0496
# Epoch 3/50
# 93/93 [==============================] - 36s 388ms/step - loss: 0.0464 - val_loss: 0.0489
# Epoch 4/50
# 93/93 [==============================] - 35s 378ms/step - loss: 0.0463 - val_loss: 0.0481
# Epoch 5/50
# 93/93 [==============================] - 35s 378ms/step - loss: 0.0462 - val_loss: 0.0480
# Epoch 6/50
# 93/93 [==============================] - 35s 373ms/step - loss: 0.0458 - val_loss: 0.0485
# Epoch 7/50
# 93/93 [==============================] - 36s 383ms/step - loss: 0.0459 - val_loss: 0.0478
# Epoch 8/50
# 93/93 [==============================] - 35s 382ms/step - loss: 0.0458 - val_loss: 0.0486
# Epoch 9/50
# 93/93 [==============================] - 35s 379ms/step - loss: 0.0453 - val_loss: 0.0484
# Epoch 10/50
# 93/93 [==============================] - 35s 379ms/step - loss: 0.0458 - val_loss: 0.0535
# Epoch 11/50
# 93/93 [==============================] - 35s 379ms/step - loss: 0.0457 - val_loss: 0.0477
# Epoch 12/50
# 93/93 [==============================] - 54s 578ms/step - loss: 0.0456 - val_loss: 0.0471
# Epoch 13/50
# 93/93 [==============================] - 35s 379ms/step - loss: 0.0459 - val_loss: 0.0476
# Epoch 14/50
# 93/93 [==============================] - 35s 373ms/step - loss: 0.0460 - val_loss: 0.0480
# Epoch 15/50
# 93/93 [==============================] - 35s 378ms/step - loss: 0.0455 - val_loss: 0.0517
# Epoch 16/50
# 93/93 [==============================] - 35s 378ms/step - loss: 0.0454 - val_loss: 0.0480
# Epoch 17/50
# 93/93 [==============================] - 35s 374ms/step - loss: 0.0451 - val_loss: 0.0491
# Epoch 18/50
# 93/93 [==============================] - 35s 380ms/step - loss: 0.0456 - val_loss: 0.0504
# Epoch 19/50
# 93/93 [==============================] - 36s 387ms/step - loss: 0.0458 - val_loss: 0.0512
# Training model with:  (2, 1)
# Epoch 1/50
# 93/93 [==============================] - 8s 81ms/step - loss: 0.7842 - val_loss: 0.7686
# Epoch 2/50
# 93/93 [==============================] - 8s 81ms/step - loss: 0.7763 - val_loss: 0.7683
# Epoch 3/50
# 93/93 [==============================] - 9s 96ms/step - loss: 0.7764 - val_loss: 0.7682
# Epoch 4/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.7764 - val_loss: 0.7683
# Epoch 5/50
# 93/93 [==============================] - 15s 163ms/step - loss: 0.7764 - val_loss: 0.7688
# Epoch 6/50
# 93/93 [==============================] - 8s 83ms/step - loss: 0.7765 - val_loss: 0.7702
# Epoch 7/50
# 93/93 [==============================] - 7s 78ms/step - loss: 0.7766 - val_loss: 0.7688
# Epoch 8/50
# 93/93 [==============================] - 7s 79ms/step - loss: 0.7766 - val_loss: 0.7679
# Epoch 9/50
# 93/93 [==============================] - 7s 78ms/step - loss: 0.7767 - val_loss: 0.7694
# Epoch 10/50
# 93/93 [==============================] - 7s 78ms/step - loss: 0.7766 - val_loss: 0.7699
# Epoch 11/50
# 93/93 [==============================] - 7s 77ms/step - loss: 0.7766 - val_loss: 0.7681
# Epoch 12/50
# 93/93 [==============================] - 7s 78ms/step - loss: 0.7765 - val_loss: 0.7705
# Epoch 13/50
# 93/93 [==============================] - 7s 77ms/step - loss: 0.7765 - val_loss: 0.7682
# Epoch 14/50
# 93/93 [==============================] - 7s 76ms/step - loss: 0.7767 - val_loss: 0.7681
# Epoch 15/50
# 93/93 [==============================] - 7s 80ms/step - loss: 0.7765 - val_loss: 0.7683
# Training model with:  (2, 2)
# Epoch 1/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.6156 - val_loss: 0.6018
# Epoch 2/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5793 - val_loss: 0.6078
# Epoch 3/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5794 - val_loss: 0.6052
# Epoch 4/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5797 - val_loss: 0.6026
# Epoch 5/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5794 - val_loss: 0.6098
# Epoch 6/50
# 93/93 [==============================] - 13s 139ms/step - loss: 0.5794 - val_loss: 0.6074
# Epoch 7/50
# 93/93 [==============================] - 17s 180ms/step - loss: 0.5795 - val_loss: 0.5977
# Epoch 8/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5794 - val_loss: 0.5972
# Epoch 9/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5793 - val_loss: 0.6075
# Epoch 10/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5788 - val_loss: 0.6060
# Epoch 11/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5789 - val_loss: 0.5942
# Epoch 12/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5793 - val_loss: 0.6085
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5789 - val_loss: 0.6023
# Epoch 14/50
# 93/93 [==============================] - 14s 147ms/step - loss: 0.5789 - val_loss: 0.6013
# Epoch 15/50
# 93/93 [==============================] - 15s 164ms/step - loss: 0.5788 - val_loss: 0.6042
# Epoch 16/50
# 93/93 [==============================] - 15s 165ms/step - loss: 0.5794 - val_loss: 0.5964
# Epoch 17/50
# 93/93 [==============================] - 15s 161ms/step - loss: 0.5792 - val_loss: 0.5999
# Epoch 18/50
# 93/93 [==============================] - 13s 141ms/step - loss: 0.5790 - val_loss: 0.6150
# Training model with:  (2, 3)
# Epoch 1/50
# 93/93 [==============================] - 16s 166ms/step - loss: 0.4011 - val_loss: 0.3642
# Epoch 2/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.3598 - val_loss: 0.3700
# Epoch 3/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.3602 - val_loss: 0.3629
# Epoch 4/50
# 93/93 [==============================] - 15s 160ms/step - loss: 0.3598 - val_loss: 0.3679
# Epoch 5/50
# 93/93 [==============================] - 15s 160ms/step - loss: 0.3602 - val_loss: 0.3638
# Epoch 6/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.3601 - val_loss: 0.3671
# Epoch 7/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.3603 - val_loss: 0.3671
# Epoch 8/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.3601 - val_loss: 0.3675
# Epoch 9/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.3603 - val_loss: 0.3630
# Epoch 10/50
# 93/93 [==============================] - 15s 162ms/step - loss: 0.3602 - val_loss: 0.3652
# Training model with:  (2, 4)
# Epoch 1/50
# 93/93 [==============================] - 20s 207ms/step - loss: 0.1667 - val_loss: 0.0559
# Epoch 2/50
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0519 - val_loss: 0.0539
# Epoch 3/50
# 93/93 [==============================] - 19s 204ms/step - loss: 0.0511 - val_loss: 0.0568
# Epoch 4/50
# 93/93 [==============================] - 19s 205ms/step - loss: 0.0511 - val_loss: 0.0524
# Epoch 5/50
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0508 - val_loss: 0.0525
# Epoch 6/50
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0509 - val_loss: 0.0529
# Epoch 7/50
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0509 - val_loss: 0.0538
# Epoch 8/50
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0508 - val_loss: 0.0522
# Epoch 9/50
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0510 - val_loss: 0.0535
# Epoch 10/50
# 93/93 [==============================] - 19s 210ms/step - loss: 0.0512 - val_loss: 0.0533
# Epoch 11/50
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0529 - val_loss: 0.0522
# Epoch 12/50
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0511 - val_loss: 0.0519
# Epoch 13/50
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0515 - val_loss: 0.0522
# Epoch 14/50
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0511 - val_loss: 0.0531
# Epoch 15/50
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0513 - val_loss: 0.0525
# Epoch 16/50
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0516 - val_loss: 0.0546
# Epoch 17/50
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0520 - val_loss: 0.0532
# Epoch 18/50
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0512 - val_loss: 0.0523
# Epoch 19/50
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0519 - val_loss: 0.0531
# Training model with:  (2, 5)
# Epoch 1/50
# 93/93 [==============================] - 24s 257ms/step - loss: 0.1603 - val_loss: 0.0473
# Epoch 2/50
# 93/93 [==============================] - 23s 253ms/step - loss: 0.0437 - val_loss: 0.0453
# Epoch 3/50
# 93/93 [==============================] - 23s 252ms/step - loss: 0.0435 - val_loss: 0.0457
# Epoch 4/50
# 93/93 [==============================] - 23s 253ms/step - loss: 0.0441 - val_loss: 0.0459
# Epoch 5/50
# 93/93 [==============================] - 23s 252ms/step - loss: 0.0438 - val_loss: 0.0459
# Epoch 6/50
# 93/93 [==============================] - 24s 255ms/step - loss: 0.0438 - val_loss: 0.0457
# Epoch 7/50
# 93/93 [==============================] - 24s 253ms/step - loss: 0.0440 - val_loss: 0.0469
# Epoch 8/50
# 93/93 [==============================] - 24s 256ms/step - loss: 0.0442 - val_loss: 0.0446
# Epoch 9/50
# 93/93 [==============================] - 24s 254ms/step - loss: 0.0439 - val_loss: 0.0465
# Epoch 10/50
# 93/93 [==============================] - 25s 264ms/step - loss: 0.0439 - val_loss: 0.0471
# Epoch 11/50
# 93/93 [==============================] - 24s 255ms/step - loss: 0.0442 - val_loss: 0.0469
# Epoch 12/50
# 93/93 [==============================] - 24s 254ms/step - loss: 0.0442 - val_loss: 0.0471
# Epoch 13/50
# 93/93 [==============================] - 24s 256ms/step - loss: 0.0439 - val_loss: 0.0455
# Epoch 14/50
# 93/93 [==============================] - 23s 253ms/step - loss: 0.0443 - val_loss: 0.0453
# Epoch 15/50
# 93/93 [==============================] - 24s 254ms/step - loss: 0.0441 - val_loss: 0.0454
# Training model with:  (2, 6)
# Epoch 1/50
# 93/93 [==============================] - 28s 302ms/step - loss: 0.1472 - val_loss: 0.0453
# Epoch 2/50
# 93/93 [==============================] - 28s 299ms/step - loss: 0.0395 - val_loss: 0.0407
# Epoch 3/50
# 93/93 [==============================] - 28s 298ms/step - loss: 0.0385 - val_loss: 0.0405
# Epoch 4/50
# 93/93 [==============================] - 28s 300ms/step - loss: 0.0361 - val_loss: 0.0347
# Epoch 5/50
# 93/93 [==============================] - 28s 300ms/step - loss: 0.0341 - val_loss: 0.0371
# Epoch 6/50
# 93/93 [==============================] - 28s 302ms/step - loss: 0.0354 - val_loss: 0.0339
# Epoch 7/50
# 93/93 [==============================] - 28s 300ms/step - loss: 0.0342 - val_loss: 0.0351
# Epoch 8/50
# 93/93 [==============================] - 28s 298ms/step - loss: 0.0344 - val_loss: 0.0337
# Epoch 9/50
# 93/93 [==============================] - 28s 297ms/step - loss: 0.0345 - val_loss: 0.0389
# Epoch 10/50
# 93/93 [==============================] - 28s 296ms/step - loss: 0.0342 - val_loss: 0.0341
# Epoch 11/50
# 93/93 [==============================] - 28s 298ms/step - loss: 0.0350 - val_loss: 0.0361
# Epoch 12/50
# 93/93 [==============================] - 28s 296ms/step - loss: 0.0342 - val_loss: 0.0357
# Epoch 13/50
# 93/93 [==============================] - 28s 298ms/step - loss: 0.0344 - val_loss: 0.0343
# Epoch 14/50
# 93/93 [==============================] - 28s 298ms/step - loss: 0.0348 - val_loss: 0.0384
# Epoch 15/50
# 93/93 [==============================] - 28s 297ms/step - loss: 0.0348 - val_loss: 0.0347
# Training model with:  (2, 7)
# Epoch 1/50
# 93/93 [==============================] - 33s 351ms/step - loss: 0.0895 - val_loss: 0.0222
# Epoch 2/50
# 93/93 [==============================] - 32s 347ms/step - loss: 0.0180 - val_loss: 0.0194
# Epoch 3/50
# 93/93 [==============================] - 32s 347ms/step - loss: 0.0170 - val_loss: 0.0189
# Epoch 4/50
# 93/93 [==============================] - 33s 350ms/step - loss: 0.0168 - val_loss: 0.0188
# Epoch 5/50
# 93/93 [==============================] - 32s 347ms/step - loss: 0.0165 - val_loss: 0.0178
# Epoch 6/50
# 93/93 [==============================] - 32s 348ms/step - loss: 0.0165 - val_loss: 0.0181
# Epoch 7/50
# 93/93 [==============================] - 32s 347ms/step - loss: 0.0162 - val_loss: 0.0177
# Epoch 8/50
# 93/93 [==============================] - 32s 346ms/step - loss: 0.0163 - val_loss: 0.0181
# Epoch 9/50
# 93/93 [==============================] - 33s 353ms/step - loss: 0.0165 - val_loss: 0.0173
# Epoch 10/50
# 93/93 [==============================] - 32s 349ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 11/50
# 93/93 [==============================] - 32s 344ms/step - loss: 0.0161 - val_loss: 0.0178
# Epoch 12/50
# 93/93 [==============================] - 32s 346ms/step - loss: 0.0163 - val_loss: 0.0179
# Epoch 13/50
# 93/93 [==============================] - 33s 352ms/step - loss: 0.0161 - val_loss: 0.0176
# Epoch 14/50
# 93/93 [==============================] - 33s 353ms/step - loss: 0.0162 - val_loss: 0.0174
# Epoch 15/50
# 93/93 [==============================] - 33s 350ms/step - loss: 0.0162 - val_loss: 0.0173
# Epoch 16/50
# 93/93 [==============================] - 32s 345ms/step - loss: 0.0163 - val_loss: 0.0173
# Epoch 17/50
# 93/93 [==============================] - 32s 346ms/step - loss: 0.0161 - val_loss: 0.0176

# %%
for i,hist in enumerate(histories):
    #plt.plot(i.history['loss'], label="training")
    plt.plot(hist.history['val_loss'], label="validation_"+str(hyperspace[i]))
plt.yscale('log')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
def acc_for_threshold(T, predsix, predthree):
    # sixes that are predicted six
    num_six_right = np.sum(predsix > T)
    # threes that are predicted three
    num_three_right = np.sum(predthree < T)
    acc = (num_six_right + num_three_right)/(len(pred_six) + len(pred_three))
    return acc

# %% [markdown]
# See tagging curve for all models.

# %%
for i, model in enumerate(models):
    pred_six = model.predict(tests[i])
    #print(np.median(pred_six))
    pred_three = model.predict(tests_threes[i])
    #print(np.median(pred_three))

    Ts = np.linspace(0,1,100)
    accs = []
    for j in Ts:
        accs.append(acc_for_threshold(j, pred_six, pred_three))
    print(hyperspace[i], max(accs))
    plt.plot(Ts, accs, label=str(hyperspace[i]))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# (1, 1) 0.6097560975609756
# (1, 2) 0.8058943089430894
# (1, 3) 0.8963414634146342
# (1, 4) 0.9258130081300813
# (1, 5) 0.8739837398373984
# (1, 6) 0.8973577235772358
# (1, 7) 0.9065040650406504
# (2, 1) 0.6407520325203252
# (2, 2) 0.5853658536585366
# (2, 3) 0.9054878048780488
# (2, 4) 0.8363821138211383
# (2, 5) 0.9598577235772358
# (2, 6) 0.6463414634146342
# (2, 7) 0.9491869918699187
