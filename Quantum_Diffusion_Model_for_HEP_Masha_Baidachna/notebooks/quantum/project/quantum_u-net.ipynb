# %% [markdown]
# ## Classical noising, fully quantum simple U-Net ##

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import h5py

filename = "../../../data/QG1_normalized_16x16_100k"
data_X = np.array(h5py.File(filename, "r")['X'])

def scramble_state_vectors(encoded_data, seed):
    np.random.seed(seed)
    scrambled_vectors = []
    for i in range(len(encoded_data)):
        # scrambled_state = np.random.permutation(encoded_data[i].flatten())
        gaussian_matrix = np.random.normal(0, 0.1, (16, 16))
        scrambled_state = np.multiply(gaussian_matrix, encoded_data[i])
        scrambled_vectors.append(scrambled_state)
    return np.array(scrambled_vectors).reshape(len(encoded_data), 8, 8, 4)

def reshape_scrambled_states(scrambled_states):
    reshaped_scrambled_states = scrambled_states.reshape(scrambled_states.shape[0], 8, 8, 4)
    return reshaped_scrambled_states

input_dim = 8 * 8 * 4
hidden_dim = 128
output_dim = 8 * 8 * 4

num_samples = 10000

scrambled_states = scramble_state_vectors(data_X[:num_samples], seed=42)
scrambled_states = torch.tensor(scrambled_states, dtype=torch.float32).view(num_samples, -1)
encoded_data = torch.tensor(data_X[:num_samples], dtype=torch.float32).view(num_samples, -1)

# %% [markdown]
# Simple hybrid U-Net-like architecture that incorportates validation and the FID graphs and metrics from other models. This model uses fully convolutional classical layers as well as a quantum layer with a quantum circuit.

# %%
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import scipy.linalg
import pennylane as qml

train_encoded_data, val_encoded_data, train_scrambled_states, val_scrambled_states = train_test_split(
    encoded_data, scrambled_states, test_size=0.2, random_state=42, shuffle=True
)

n_qubits = 8
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev, interface='torch')
def quantum_circuit(inputs, weights):
    qml.templates.AngleEmbedding(inputs, wires=range(n_qubits))
    qml.templates.StronglyEntanglingLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

class QuantumLayer(nn.Module):
    def __init__(self, n_qubits, n_layers):
        super(QuantumLayer, self).__init__()
        weight_shapes = {"weights": (n_layers, n_qubits, 3)}
        self.qlayer = qml.qnn.TorchLayer(quantum_circuit, weight_shapes)

    def forward(self, x):
        return self.qlayer(x)

class QuantumDiffusionModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, n_qubits, n_layers):
        super(QuantumDiffusionModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, n_qubits)
        self.quantum_layer = QuantumLayer(n_qubits, n_layers)
        self.fc2 = nn.Linear(n_qubits, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.quantum_layer(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x

def decode(encoded_data):
    num_samples, encoded_height, encoded_width, num_channels = encoded_data.shape
    decoded_data = np.zeros((num_samples, 16, 16))

    for sample in range(num_samples):
        for i in range(encoded_height):
            for j in range(encoded_width):
                for c in range(num_channels):
                    if c == 0:
                        decoded_data[sample, 2*i, 2*j] = encoded_data[sample, i, j, c]
                    elif c == 1:
                        decoded_data[sample, 2*i, 2*j+1] = encoded_data[sample, i, j, c]
                    elif c == 2:
                        decoded_data[sample, 2*i+1, 2*j] = encoded_data[sample, i, j, c]
                    elif c == 3:
                        decoded_data[sample, 2*i+1, 2*j+1] = encoded_data[sample, i, j, c]

    return decoded_data

def flip(decoded_data):
    return 1 - decoded_data

def calculate_statistics(data):
    data = data.reshape(data.shape[0], -1)  # flatten images
    mean = np.mean(data, axis=0)
    covariance = np.cov(data, rowvar=False)
    return mean, covariance

def calculate_fid(mu1, sigma1, mu2, sigma2, eps=1e-6):
    diff = mu1 - mu2
    covmean, _ = scipy.linalg.sqrtm(sigma1 @ sigma2, disp=False)
    if np.iscomplexobj(covmean):
        covmean = covmean.real
    fid = diff @ diff + np.trace(sigma1) + np.trace(sigma2) - 2 * np.trace(covmean)
    return fid

n_layers = 6

model = QuantumDiffusionModel(input_dim, hidden_dim, output_dim, n_qubits, n_layers)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

num_epochs = 50
loss_values = []
val_loss_values = []
fid_scores = []

for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(train_scrambled_states.view(len(train_scrambled_states), -1))
    loss = criterion(outputs, train_encoded_data.view(len(train_encoded_data), -1))
    loss.backward()
    optimizer.step()
    loss_values.append(loss.item())
    
    model.eval()
    with torch.no_grad():
        val_outputs = model(val_scrambled_states.view(len(val_scrambled_states), -1))
        val_loss = criterion(val_outputs, val_encoded_data.view(len(val_encoded_data), -1))
        val_loss_values.append(val_loss.item())
        
        denoised_states = model(val_scrambled_states.view(len(val_scrambled_states), -1))
        denoised_states = denoised_states.view(len(val_scrambled_states), 8, 8, 4).detach().numpy()
        decoded_data = decode(denoised_states)
        # decoded_data = flip(decoded_data)

        mu1, sigma1 = calculate_statistics(data_X[:len(decoded_data)])
        mu2, sigma2 = calculate_statistics(decoded_data)
        fid = calculate_fid(mu1, sigma1, mu2, sigma2)
        fid_scores.append(fid)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f}, FID: {fid:.4f}')

plt.figure(figsize=(18, 5))

plt.subplot(1, 2, 1)
plt.plot(loss_values, label='Training Loss', color='blue')
plt.plot(val_loss_values, label='Validation Loss', color='orange')
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Training and Validation Loss Over Epochs', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)

plt.subplot(1, 2, 2)
plt.plot(fid_scores, label='FID Score', color='green')
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('FID', fontsize=14)
plt.title('FID Score Over Epochs', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/50], Loss: 0.0183, Val Loss: 0.0108, FID: 2.8707
# Epoch [2/50], Loss: 0.0123, Val Loss: 0.0086, FID: 2.3821
# Epoch [3/50], Loss: 0.0099, Val Loss: 0.0087, FID: 2.4334
# Epoch [4/50], Loss: 0.0098, Val Loss: 0.0089, FID: 2.5138
# Epoch [5/50], Loss: 0.0099, Val Loss: 0.0084, FID: 2.3774
# Epoch [6/50], Loss: 0.0092, Val Loss: 0.0076, FID: 2.1639
# Epoch [7/50], Loss: 0.0083, Val Loss: 0.0071, FID: 2.0168
# Epoch [8/50], Loss: 0.0076, Val Loss: 0.0069, FID: 1.9598
# Epoch [9/50], Loss: 0.0074, Val Loss: 0.0070, FID: 1.9536
# Epoch [10/50], Loss: 0.0073, Val Loss: 0.0070, FID: 1.9551
# Epoch [11/50], Loss: 0.0073, Val Loss: 0.0070, FID: 1.9450
# Epoch [12/50], Loss: 0.0073, Val Loss: 0.0069, FID: 1.9223
# Epoch [13/50], Loss: 0.0071, Val Loss: 0.0068, FID: 1.8936
# Epoch [14/50], Loss: 0.0070, Val Loss: 0.0067, FID: 1.8664
# Epoch [15/50], Loss: 0.0068, Val Loss: 0.0066, FID: 1.8471
# Epoch [16/50], Loss: 0.0067, Val Loss: 0.0065, FID: 1.8346
# Epoch [17/50], Loss: 0.0067, Val Loss: 0.0065, FID: 1.8276
# Epoch [18/50], Loss: 0.0066, Val Loss: 0.0064, FID: 1.8235
# Epoch [19/50], Loss: 0.0066, Val Loss: 0.0064, FID: 1.8205
# Epoch [20/50], Loss: 0.0065, Val Loss: 0.0064, FID: 1.8181
# Epoch [21/50], Loss: 0.0065, Val Loss: 0.0064, FID: 1.8158
# Epoch [22/50], Loss: 0.0065, Val Loss: 0.0064, FID: 1.8136
# Epoch [23/50], Loss: 0.0065, Val Loss: 0.0064, FID: 1.8117
# Epoch [24/50], Loss: 0.0065, Val Loss: 0.0064, FID: 1.8103
# Epoch [25/50], Loss: 0.0064, Val Loss: 0.0064, FID: 1.8096
# Epoch [26/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8099
# Epoch [27/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8113
# Epoch [28/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8127
# Epoch [29/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8139
# Epoch [30/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8138
# Epoch [31/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8129
# Epoch [32/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8114
# Epoch [33/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8101
# Epoch [34/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8091
# Epoch [35/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8089
# Epoch [36/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8097
# Epoch [37/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8114
# Epoch [38/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8131
# Epoch [39/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8148
# Epoch [40/50], Loss: 0.0064, Val Loss: 0.0063, FID: 1.8153
# Epoch [41/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8144
# Epoch [42/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8126
# Epoch [43/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8110
# Epoch [44/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8102
# Epoch [45/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8103
# Epoch [46/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8112
# Epoch [47/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8125
# Epoch [48/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8133
# Epoch [49/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8133
# Epoch [50/50], Loss: 0.0063, Val Loss: 0.0063, FID: 1.8123

# %%
def generate_new_images(model, num_images, input_dim=8*8*4):
    model.eval()
    with torch.no_grad():
        random_noise = torch.randn(num_images, input_dim)
        generated_data = model(random_noise)
        generated_data = generated_data.view(num_images, 8, 8, 4).detach().numpy()
        decoded_images = decode(generated_data)
        
        for i in range(num_images):
            fig, axes = plt.subplots(1, 5, figsize=(10, 2))
            for qubit in range(4):
                im = axes[qubit].imshow(generated_data[i, :, :, qubit], cmap='viridis')
                axes[qubit].set_title(f"Encoded {qubit+1}")
                fig.colorbar(im, ax=axes[qubit])
            im = axes[4].imshow(decoded_images[i], cmap='viridis')
            axes[4].set_title("Decoded")
            fig.colorbar(im, ax=axes[4])
            plt.tight_layout()
            plt.show()
    return decoded_images

num_samples_to_generate = 5
new_images = generate_new_images(model, num_samples_to_generate)

# %%
def plot_max_values(decoded_data, minimized_value=0):
    """
    Plots only the maximum values in the decoded data, setting the rest to a minimized value,
    and arranges the plots in rows of 5.
    """
    num_samples, height, width = decoded_data.shape
    num_cols = 5
    num_rows = (num_samples + num_cols - 1) // num_cols

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 3))

    if num_rows == 1:
        axes = np.expand_dims(axes, axis=0)
    if num_cols == 1:
        axes = np.expand_dims(axes, axis=1)

    axes = axes.flatten()

    for i in range(num_samples):
        max_value = np.max(decoded_data[i])
        max_mask = (decoded_data[i] == max_value)
        modified_data = np.where(max_mask, decoded_data[i], minimized_value)

        ax = axes[i]
        im = ax.imshow(modified_data, cmap='viridis')
        ax.set_title(f"Sample {i + 1}")
        fig.colorbar(im, ax=ax)

    plt.tight_layout()
    plt.show()

num_samples_to_generate = 10
random_noise = torch.randn(num_samples_to_generate, input_dim)
generated_data = model(random_noise)
generated_data = generated_data.view(num_samples_to_generate, 8, 8, 4).detach().numpy()
decoded_images = flip(decode(generated_data))
plot_max_values(decoded_images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

def plot_mean_max(decoded_data):
    """
    Computes the mean of the maximum values at each pixel across all samples
    and plots a 16x16 image of the resulting mean values.
    """
    # Assuming the shape is (num_samples, height, width)
    num_samples, height, width = decoded_data.shape
    
    # Initialize an array to store the maximum values at each pixel
    max_values = np.zeros((num_samples, height, width))
    
    # Extract the maximum values at each pixel across all samples
    for i in range(num_samples):
        max_values[i] = np.max(decoded_data[i], axis=0)
    
    # Compute the mean of the maximum values at each pixel
    mean_max_values = np.mean(max_values, axis=0)
    
    # Plot the resulting 16x16 image
    plt.figure(figsize=(6, 6))
    plt.imshow(mean_max_values, cmap='viridis')
    plt.colorbar()
    plt.title("Mean of Maximum Values Across All Samples")
    plt.show()

# Example usage
num_samples_to_generate = 100
input_dim = 100  # example input dimension
random_noise = torch.randn(num_samples_to_generate, input_dim)

# Assuming `model`, `decode`, and `flip` are defined elsewhere in the code
generated_data = model(random_noise)
generated_data = generated_data.view(num_samples_to_generate, 8, 8, 4).detach().numpy()
decoded_images = flip(decode(generated_data))

# Call the new function to plot the mean of max values
plot_mean_max(decoded_images)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 36
#      33 random_noise = torch.randn(num_samples_to_generate, input_dim)
#      35 # Assuming `model`, `decode`, and `flip` are defined elsewhere in the code
# ---> 36 generated_data = model(random_noise)
#      37 generated_data = generated_data.view(num_samples_to_generate, 8, 8, 4).detach().numpy()
#      38 decoded_images = flip(decode(generated_data))
#
# File c:\Users\realc\OneDrive\Documents\GSOC\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\realc\OneDrive\Documents\GSOC\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[6], line 42, in QuantumDiffusionModel.forward(self, x)
#      41 def forward(self, x):
# ---> 42     x = torch.relu(self.fc1(x))
#      43     x = self.quantum_layer(x)
#      44     x = torch.relu(self.fc2(x))
#
# File c:\Users\realc\OneDrive\Documents\GSOC\.venv\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\realc\OneDrive\Documents\GSOC\.venv\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\realc\OneDrive\Documents\GSOC\.venv\Lib\site-packages\torch\nn\modules\linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (100x100 and 256x8)

# %%
train_encoded_data, val_encoded_data, train_scrambled_states, val_scrambled_states = train_test_split(
    encoded_data, scrambled_states, test_size=0.2, random_state=42, shuffle=True
)

class QuantumDiffusionModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, n_qubits, n_layers):
        super(QuantumDiffusionModel, self).__init__()
        # self.fc1 = nn.Linear(input_dim, n_qubits)
        self.quantum_layer = QuantumLayer(n_qubits, n_layers)
        # self.fc2 = nn.Linear(n_qubits, hidden_dim)
        # self.fc3 = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # x = torch.relu(self.fc1(x))
        x = self.quantum_layer(x)
        # x = torch.relu(self.fc2(x))
        # x = self.fc3(x)
        return x

def decode(encoded_data):
    num_samples, encoded_height, encoded_width, num_channels = encoded_data.shape
    decoded_data = np.zeros((num_samples, 16, 16))

    for sample in range(num_samples):
        for i in range(encoded_height):
            for j in range(encoded_width):
                for c in range(num_channels):
                    if c == 0:
                        decoded_data[sample, 2*i, 2*j] = encoded_data[sample, i, j, c]
                    elif c == 1:
                        decoded_data[sample, 2*i, 2*j+1] = encoded_data[sample, i, j, c]
                    elif c == 2:
                        decoded_data[sample, 2*i+1, 2*j] = encoded_data[sample, i, j, c]
                    elif c == 3:
                        decoded_data[sample, 2*i+1, 2*j+1] = encoded_data[sample, i, j, c]

    return decoded_data

num_epochs = 50
loss_values = []
val_loss_values = []
fid_scores = []

for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(train_scrambled_states.view(len(train_scrambled_states), -1))
    loss = criterion(outputs, train_encoded_data.view(len(train_encoded_data), -1))
    loss.backward()
    optimizer.step()
    loss_values.append(loss.item())
    
    model.eval()
    with torch.no_grad():
        val_outputs = model(val_scrambled_states.view(len(val_scrambled_states), -1))
        val_loss = criterion(val_outputs, val_encoded_data.view(len(val_encoded_data), -1))
        val_loss_values.append(val_loss.item())
        
        denoised_states = model(val_scrambled_states.view(len(val_scrambled_states), -1))
        denoised_states = denoised_states.view(len(val_scrambled_states), 8, 8, 4).detach().numpy()
        decoded_data = decode(denoised_states)
        decoded_data = flip(decoded_data)

        mu1, sigma1 = calculate_statistics(data_X[:len(decoded_data)])
        mu2, sigma2 = calculate_statistics(decoded_data)
        fid = calculate_fid(mu1, sigma1, mu2, sigma2)
        fid_scores.append(fid)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f}, FID: {fid:.4f}')

plt.figure(figsize=(18, 5))

plt.subplot(1, 2, 1)
plt.plot(loss_values, label='Training Loss', color='blue')
plt.plot(val_loss_values, label='Validation Loss', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(fid_scores, label='FID Score', color='green')
plt.xlabel('Epoch')
plt.ylabel('FID')
plt.title('FID Score Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/50], Loss: 0.0039, Val Loss: 0.0038, FID: 253.0148
# Epoch [2/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9887
# Epoch [3/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9602
# Epoch [4/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9338
# Epoch [5/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9134
# Epoch [6/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9026
# Epoch [7/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.8985
# Epoch [8/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.8982
# Epoch [9/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.8982
# Epoch [10/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.8988
# Epoch [11/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.8999
# Epoch [12/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.8976
# Epoch [13/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.8946
# Epoch [14/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.8959
# Epoch [15/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9000
# Epoch [16/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9054
# Epoch [17/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9137
# Epoch [18/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9239
# Epoch [19/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9359
# Epoch [20/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9452
# Epoch [21/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9476
# Epoch [22/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9446
# Epoch [23/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9410
# Epoch [24/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9383
# Epoch [25/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9374
# Epoch [26/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9396
# Epoch [27/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9436
# Epoch [28/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9450
# Epoch [29/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9439
# Epoch [30/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9377
# Epoch [31/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9322
# Epoch [32/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9263
# Epoch [33/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9248
# Epoch [34/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9255
# Epoch [35/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9273
# Epoch [36/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9272
# Epoch [37/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9236
# Epoch [38/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9200
# Epoch [39/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9224
# Epoch [40/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9251
# Epoch [41/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9257
# Epoch [42/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9226
# Epoch [43/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9222
# Epoch [44/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9247
# Epoch [45/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9297
# Epoch [46/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9360
# Epoch [47/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9354
# Epoch [48/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9292
# Epoch [49/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9240
# Epoch [50/50], Loss: 0.0039, Val Loss: 0.0038, FID: 252.9228

# %%
def generate_new_images(model, num_images, input_dim=8*8*4):
    model.eval()  
    with torch.no_grad():
        
        for i in range(num_images):
            random_noise = torch.randn(num_images, input_dim)
            
            generated_data = model(random_noise)
            generated_data = generated_data.view(num_images, 8, 8, 4).detach().numpy()
            
            # decoded_images = flip(decode(generated_data))
            decoded_images = decode(generated_data)
            fig, axes = plt.subplots(1, 5, figsize=(10, 2))

            for qubit in range(4):
                im = axes[qubit].imshow(generated_data[i, :, :, qubit], cmap='viridis')
                axes[qubit].set_title(f"Encoded {qubit+1}")
                fig.colorbar(im, ax=axes[qubit])

            im = axes[4].imshow(decoded_images[i], cmap='viridis')
            axes[4].set_title("Decoded")
            fig.colorbar(im, ax=axes[4])
            
            plt.tight_layout()
            plt.show()

    return decoded_images

num_samples_to_generate = 5
new_images = generate_new_images(model, num_samples_to_generate)
