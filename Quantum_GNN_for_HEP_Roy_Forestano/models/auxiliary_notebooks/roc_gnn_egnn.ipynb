# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = '/content/drive/MyDrive/research/'
directory = path
os.chdir(directory)
print(os.getcwd())
# Out:
# /content/drive/MyDrive/research/gsoc/2023_gsoc

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# %%
plot_path = 'plots/'

# %%
fpr_gnn = np.load(plot_path+'fpr_gnn_5122_10_5_2.npy')
tpr_gnn = np.load(plot_path+'tpr_gnn_5122_10_5_2.npy')
y_score_gnn = np.load(plot_path+'y_score_gnn_5122_10_5_2.npy')
labels_all = np.load(plot_path+'labels_all_gnn_5122_10_5_2.npy')

# %%
auc_score_gnn = roc_auc_score(labels_all, y_score_gnn)

# %%
fpr_egnn = np.load(plot_path+'fpr_egnn_5252_10_4_2.npy')
tpr_egnn = np.load(plot_path+'tpr_egnn_5252_10_4_2.npy')
y_score_egnn = np.load(plot_path+'y_score_egnn_5252_10_4_2.npy')
labels_all = np.load(plot_path+'labels_all_egnn_5252_10_4_2.npy')

# %%
auc_score_egnn = roc_auc_score(labels_all, y_score_egnn)

# %%
fpr_qgnn = np.load(plot_path+'fpr_qgnn_5156_8_6_3.npy')
tpr_qgnn = np.load(plot_path+'tpr_qgnn_5156_8_6_3.npy')
y_score_qgnn = np.load(plot_path+'y_score_qgnn_5156_8_6_3.npy')
labels_all = np.load(plot_path+'labels_all_qgnn_5156_8_6_3.npy')

# %%
auc_score_qgnn = roc_auc_score(labels_all, y_score_qgnn)

# %%
fpr_eqgnn = np.load(plot_path+'fpr_eqgnn_5140_8_6_3.npy')
tpr_eqgnn = np.load(plot_path+'tpr_eqgnn_5140_8_6_3.npy')
y_score_eqgnn = np.load(plot_path+'y_score_eqgnn_5140_8_6_3.npy')
labels_all = np.load(plot_path+'labels_all_eqgnn_5140_8_6_3.npy')

# %%
auc_score_eqgnn = roc_auc_score(labels_all, y_score_eqgnn)

# %%
fig = plt.figure(figsize=(10,8))
plt.plot(fpr_gnn,tpr_gnn,label = f'GNN AUC: {100*auc_score_gnn:.2f}',c='magenta')
plt.plot(fpr_egnn,tpr_egnn,label = f'EGNN AUC: {100*auc_score_egnn:.2f}',ls='--',c='red')
plt.plot(fpr_qgnn,tpr_qgnn,label = f'QGNN AUC: {100*auc_score_qgnn:.2f}',ls=':',c='b')
plt.plot(fpr_eqgnn,tpr_eqgnn,label = f'EQGNN AUC: {100*auc_score_eqgnn:.2f}',ls='-.',c='dodgerblue')
plt.plot(np.linspace(0,1,100),np.linspace(0,1,100),ls='-.',c='black')
# plt.title('ROC', fontsize = 25)
plt.xlabel('FPR',fontsize = 25)
plt.ylabel('TPR',fontsize = 25)
plt.xlim([-0.001,1.001])
plt.ylim([-0.001,1.001])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.savefig(plot_path+'roc_gnn_egnn_qgnn_eqgnn_5000.png',bbox_inches='tight')

# %% [markdown]
# # AUC vs. $|\Theta|$ Plot

# %% [markdown]
# Begin defining the classical auc values

# %%
fpr_gnn = np.load(plot_path+'fpr_gnn_5122_10_5_2.npy')
tpr_gnn = np.load(plot_path+'tpr_gnn_5122_10_5_2.npy')
y_score_gnn = np.load(plot_path+'y_score_gnn_5122_10_5_2.npy')
labels_all = np.load(plot_path+'labels_all_gnn_5122_10_5_2.npy')

# %%
auc_score_gnn_5000 = roc_auc_score(labels_all, y_score_gnn)

# %%
fpr_egnn = np.load(plot_path+'fpr_egnn_5252_10_4_2.npy')
tpr_egnn = np.load(plot_path+'tpr_egnn_5252_10_4_2.npy')
y_score_egnn = np.load(plot_path+'y_score_egnn_5252_10_4_2.npy')
labels_all = np.load(plot_path+'labels_all_egnn_5252_10_4_2.npy')

# %%
auc_score_egnn_5000 = roc_auc_score(labels_all, y_score_egnn)

# %%
fpr_gnn = np.load(plot_path+'fpr_gnn_3362_8_5_2.npy')
tpr_gnn = np.load(plot_path+'tpr_gnn_3362_8_5_2.npy')
y_score_gnn = np.load(plot_path+'y_score_gnn_3362_8_5_2.npy')
labels_all = np.load(plot_path+'labels_all_gnn_3362_8_5_2.npy')

# %%
auc_score_gnn_3000 = roc_auc_score(labels_all, y_score_gnn)

# %%
fpr_egnn = np.load(plot_path+'fpr_egnn_3466_8_4_2.npy')
tpr_egnn = np.load(plot_path+'tpr_egnn_3466_8_4_2.npy')
y_score_egnn = np.load(plot_path+'y_score_egnn_3466_8_4_2.npy')
labels_all = np.load(plot_path+'labels_all_egnn_3466_8_4_2.npy')

# %%
auc_score_egnn_3000 = roc_auc_score(labels_all, y_score_egnn)

# %%
fpr_gnn = np.load(plot_path+'fpr_gnn_2794_8_4_2.npy')
tpr_gnn = np.load(plot_path+'tpr_gnn_2794_8_4_2.npy')
y_score_gnn = np.load(plot_path+'y_score_gnn_2794_8_4_2.npy')
labels_all = np.load(plot_path+'labels_all_gnn_2794_8_4_2.npy')

# %%
auc_score_gnn_2000 = roc_auc_score(labels_all, y_score_gnn)

# %%
fpr_egnn = np.load(plot_path+'fpr_egnn_2730_8_3_2.npy')
tpr_egnn = np.load(plot_path+'tpr_egnn_2730_8_3_2.npy')
y_score_egnn = np.load(plot_path+'y_score_egnn_2730_8_3_2.npy')
labels_all = np.load(plot_path+'labels_all_egnn_2730_8_3_2.npy')

# %%
auc_score_egnn_2000 = roc_auc_score(labels_all, y_score_egnn)

# %%
fpr_gnn = np.load(plot_path+'fpr_gnn_1640_6_4_2.npy')
tpr_gnn = np.load(plot_path+'tpr_gnn_1640_6_4_2.npy')
y_score_gnn = np.load(plot_path+'y_score_gnn_1640_6_4_2.npy')
labels_all = np.load(plot_path+'labels_all_gnn_1640_6_4_2.npy')

# %%
auc_score_gnn_1500 = roc_auc_score(labels_all, y_score_gnn)

# %%
fpr_egnn = np.load(plot_path+'fpr_egnn_1616_6_3_2.npy')
tpr_egnn = np.load(plot_path+'tpr_egnn_1616_6_3_2.npy')
y_score_egnn = np.load(plot_path+'y_score_egnn_1616_6_3_2.npy')
labels_all = np.load(plot_path+'labels_all_egnn_1616_6_3_2.npy')

# %%
auc_score_egnn_1500 = roc_auc_score(labels_all, y_score_egnn)

# %%
fpr_gnn = np.load(plot_path+'fpr_gnn_1177_5_4_2.npy')
tpr_gnn = np.load(plot_path+'tpr_gnn_1177_5_4_2.npy')
y_score_gnn = np.load(plot_path+'y_score_gnn_1177_5_4_2.npy')
labels_all = np.load(plot_path+'labels_all_gnn_1177_5_4_2.npy')

# %%
auc_score_gnn_1000 = roc_auc_score(labels_all, y_score_gnn)

# %%
fpr_egnn = np.load(plot_path+'fpr_egnn_1167_5_3_2.npy')
tpr_egnn = np.load(plot_path+'tpr_egnn_1167_5_3_2.npy')
y_score_egnn = np.load(plot_path+'y_score_egnn_1167_5_3_2.npy')
labels_all = np.load(plot_path+'labels_all_egnn_1167_5_3_2.npy')

# %%
auc_score_egnn_1000 = roc_auc_score(labels_all, y_score_egnn)

# %%
fpr_gnn = np.load(plot_path+'fpr_gnn_478_4_2_2.npy')
tpr_gnn = np.load(plot_path+'tpr_gnn_478_4_2_2.npy')
y_score_gnn = np.load(plot_path+'y_score_gnn_478_4_2_2.npy')
labels_all = np.load(plot_path+'labels_all_gnn_478_4_2_2.npy')

# %%
auc_score_gnn_500 = roc_auc_score(labels_all, y_score_gnn)

# %%
fpr_egnn = np.load(plot_path+'fpr_egnn_485_3_3_2.npy')
tpr_egnn = np.load(plot_path+'tpr_egnn_485_3_3_2.npy')
y_score_egnn = np.load(plot_path+'y_score_egnn_485_3_3_2.npy')
labels_all = np.load(plot_path+'labels_all_egnn_485_3_3_2.npy')

# %%
auc_score_egnn_500 = roc_auc_score(labels_all, y_score_egnn)

# %%
gnn_auc_array = np.array([auc_score_gnn_500,
                           auc_score_gnn_1000,
                           auc_score_gnn_1500,
                           auc_score_gnn_2000,
                           auc_score_gnn_3000,
                           auc_score_gnn_5000])

# %%
egnn_auc_array = np.array([auc_score_egnn_500,
                           auc_score_egnn_1000,
                           auc_score_egnn_1500,
                           auc_score_egnn_2000,
                           auc_score_egnn_3000,
                           auc_score_egnn_5000])

# %% [markdown]
# Now the quantum numbers

# %%
fpr_qgnn = np.load(plot_path+'fpr_qgnn_5156_8_6_3.npy')
tpr_qgnn = np.load(plot_path+'tpr_qgnn_5156_8_6_3.npy')
y_score_qgnn = np.load(plot_path+'y_score_qgnn_5156_8_6_3.npy')
labels_all = np.load(plot_path+'labels_all_qgnn_5156_8_6_3.npy')

# %%
auc_score_qgnn_5000 = roc_auc_score(labels_all, y_score_qgnn)

# %%
fpr_eqgnn = np.load(plot_path+'fpr_eqgnn_5140_8_6_3.npy')
tpr_eqgnn = np.load(plot_path+'tpr_eqgnn_5140_8_6_3.npy')
y_score_eqgnn = np.load(plot_path+'y_score_eqgnn_5140_8_6_3.npy')
labels_all = np.load(plot_path+'labels_all_eqgnn_5140_8_6_3.npy')

# %%
auc_score_eqgnn_5000 = roc_auc_score(labels_all, y_score_eqgnn)

# %%
fpr_qgnn = np.load(plot_path+'fpr_qgnn_3584_8_4_3.npy')
tpr_qgnn = np.load(plot_path+'tpr_qgnn_3584_8_4_3.npy')
y_score_qgnn = np.load(plot_path+'y_score_qgnn_3584_8_4_3.npy')
labels_all = np.load(plot_path+'labels_all_qgnn_3584_8_4_3.npy')

# %%
auc_score_qgnn_3000 = roc_auc_score(labels_all, y_score_qgnn)

# %%
fpr_eqgnn = np.load(plot_path+'fpr_eqgnn_3792_8_4_3.npy')
tpr_eqgnn = np.load(plot_path+'tpr_eqgnn_3792_8_4_3.npy')
y_score_eqgnn = np.load(plot_path+'y_score_eqgnn_3792_8_4_3.npy')
labels_all = np.load(plot_path+'labels_all_eqgnn_3792_8_4_3.npy')

# %%
auc_score_eqgnn_3000 = roc_auc_score(labels_all, y_score_eqgnn)

# %%
fpr_qgnn = np.load(plot_path+'fpr_qgnn_2798_8_3_3.npy')
tpr_qgnn = np.load(plot_path+'tpr_qgnn_2798_8_3_3.npy')
y_score_qgnn = np.load(plot_path+'y_score_qgnn_2798_8_3_3.npy')
labels_all = np.load(plot_path+'labels_all_qgnn_2798_8_3_3.npy')

# %%
auc_score_qgnn_2000 = roc_auc_score(labels_all, y_score_qgnn)

# %%
fpr_eqgnn = np.load(plot_path+'fpr_eqgnn_2686_8_3_3.npy')
tpr_eqgnn = np.load(plot_path+'tpr_eqgnn_2686_8_3_3.npy')
y_score_eqgnn = np.load(plot_path+'y_score_eqgnn_2686_8_3_3.npy')
labels_all = np.load(plot_path+'labels_all_eqgnn_2686_8_3_3.npy')

# %%
auc_score_eqgnn_2000 = roc_auc_score(labels_all, y_score_eqgnn)

# %%
fpr_qgnn = np.load(plot_path+'fpr_qgnn_1660_8_2_3.npy')
tpr_qgnn = np.load(plot_path+'tpr_qgnn_1660_8_2_3.npy')
y_score_qgnn = np.load(plot_path+'y_score_qgnn_1660_8_2_3.npy')
labels_all = np.load(plot_path+'labels_all_qgnn_1660_8_2_3.npy')

# %%
auc_score_qgnn_1500 = roc_auc_score(labels_all, y_score_qgnn)

# %%
fpr_eqgnn = np.load(plot_path+'fpr_eqgnn_1548_8_2_3.npy')
tpr_eqgnn = np.load(plot_path+'tpr_eqgnn_1548_8_2_3.npy')
y_score_eqgnn = np.load(plot_path+'y_score_eqgnn_1548_8_2_3.npy')
labels_all = np.load(plot_path+'labels_all_eqgnn_1548_8_2_3.npy')

# %%
auc_score_eqgnn_1500 = roc_auc_score(labels_all, y_score_eqgnn)

# %%
fpr_qgnn = np.load(plot_path+'fpr_qgnn_1194_8_2_3.npy')
tpr_qgnn = np.load(plot_path+'tpr_qgnn_1194_8_2_3.npy')
y_score_qgnn = np.load(plot_path+'y_score_qgnn_1194_8_2_3.npy')
labels_all = np.load(plot_path+'labels_all_qgnn_1194_8_2_3.npy')

# %%
auc_score_qgnn_1000 = roc_auc_score(labels_all, y_score_qgnn)

# %%
fpr_eqgnn = np.load(plot_path+'fpr_eqgnn_1082_8_2_3.npy')
tpr_eqgnn = np.load(plot_path+'tpr_eqgnn_1082_8_2_3.npy')
y_score_eqgnn = np.load(plot_path+'y_score_eqgnn_1082_8_2_3.npy')
labels_all = np.load(plot_path+'labels_all_eqgnn_1082_8_2_3.npy')

# %%
auc_score_eqgnn_1000 = roc_auc_score(labels_all, y_score_eqgnn)

# %%
fpr_qgnn = np.load(plot_path+'fpr_qgnn_558_8_1_3.npy')
tpr_qgnn = np.load(plot_path+'tpr_qgnn_558_8_1_3.npy')
y_score_qgnn = np.load(plot_path+'y_score_qgnn_558_8_1_3.npy')
labels_all = np.load(plot_path+'labels_all_qgnn_558_8_1_3.npy')

# %%
auc_score_qgnn_500 = roc_auc_score(labels_all, y_score_qgnn)

# %%
fpr_eqgnn = np.load(plot_path+'fpr_eqgnn_446_8_1_3.npy')
tpr_eqgnn = np.load(plot_path+'tpr_eqgnn_446_8_1_3.npy')
y_score_eqgnn = np.load(plot_path+'y_score_eqgnn_446_8_1_3.npy')
labels_all = np.load(plot_path+'labels_all_eqgnn_446_8_1_3.npy')

# %%
auc_score_eqgnn_500 = roc_auc_score(labels_all, y_score_eqgnn)

# %%
qgnn_auc_array = np.array([auc_score_qgnn_500,
                           auc_score_qgnn_1000,
                           auc_score_qgnn_1500,
                           auc_score_qgnn_2000,
                           auc_score_qgnn_3000,
                           auc_score_qgnn_5000])

# %%
eqgnn_auc_array = np.array([auc_score_eqgnn_500,
                           auc_score_eqgnn_1000,
                           auc_score_eqgnn_1500,
                           auc_score_eqgnn_2000,
                           auc_score_eqgnn_3000,
                           auc_score_eqgnn_5000])

# %%
gnn_param_array = np.array([478.0,1177.0,1640.0,2794.0,3362.0,5122.0])
egnn_param_array = np.array([485.0,1167.0,1616.0,2730.0,3466.0,5252.0])
qgnn_param_array = np.array([558.0,1194.0,1660.0,2798.0,3584.0,5156.0])
eqgnn_param_array = np.array([446.0,1082.0,1548.0,2686.0,3792.0,5140.0])

# %%
fig = plt.figure(figsize=(10,8))
plt.plot(gnn_param_array,gnn_auc_array,c='magenta',marker='^',markersize=15,ls='-',label='GNN')
plt.plot(egnn_param_array,egnn_auc_array,c='red',marker='s',markersize=15,ls='--',label='EGNN')
plt.plot(qgnn_param_array,qgnn_auc_array,c='blue',marker='v',markersize=15,ls=':',label='QGNN')
plt.plot(eqgnn_param_array,eqgnn_auc_array,c='dodgerblue',marker='o',markersize=15,ls='-.',label='EQGNN')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.ylabel('AUC',fontsize=25)
plt.xlabel('$|\Theta|$',fontsize=25)
plt.savefig(plot_path+'auc_theta_gnn_egnn_qgnn_eqgnn.png',bbox_inches='tight')
