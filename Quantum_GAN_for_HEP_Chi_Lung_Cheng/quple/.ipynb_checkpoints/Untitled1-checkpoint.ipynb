# %%
from quple.data_encoding.second_order_expansion import SecondOrderExpansion
from quple.data_encoding.first_order_expansion import FirstOrderExpansion
from quple import ParameterisedCircuit

# %%
A = FirstOrderExpansion(5)
B = SecondOrderExpansion(5)

# %%
B
# Out:
#                                                                                                 ┌──┐                                                         ┌─────────────────────┐                                      ┌──┐                          ┌─────────────────────┐                                                                                                                                                          ┌──┐                                                         ┌─────────────────────┐                                      ┌──┐                          ┌─────────────────────┐
# ...

# %%
A
# Out:
#                                                            ┌──┐       ┌──┐                                                             ┌──┐       ┌──┐
# (0, 0): ───Rx(pi*<θ_0/pi>)───Ry(pi*<θ_5/pi>)───@───@───@────@────────────────────────Rx(pi*<θ_10/pi>)───Ry(pi*<θ_15/pi>)───@───@───@────@────────────────────────Rz(pi*<θ_20/pi>)───
#                                                │   │   │    │                                                              │   │   │    │
# (0, 1): ───Rx(pi*<θ_1/pi>)───Ry(pi*<θ_6/pi>)───X───┼───┼────┼@────@────@─────────────Rx(pi*<θ_11/pi>)───Ry(pi*<θ_16/pi>)───X───┼───┼────┼@────@────@─────────────Rz(pi*<θ_21/pi>)───
#                                                    │   │    ││    │    │                                                       │   │    ││    │    │
# (0, 2): ───Rx(pi*<θ_2/pi>)───Ry(pi*<θ_7/pi>)───────X───┼────┼X────┼────┼@────@───────Rx(pi*<θ_12/pi>)───Ry(pi*<θ_17/pi>)───────X───┼────┼X────┼────┼@────@───────Rz(pi*<θ_22/pi>)───
# ...

# %%
A
# Out:
#                                                            ┌──┐       ┌──┐                                                             ┌──┐       ┌──┐
# (0, 0): ───Rx(pi*<θ_0/pi>)───Ry(pi*<θ_5/pi>)───@───@───@────@────────────────────────Rx(pi*<θ_10/pi>)───Ry(pi*<θ_15/pi>)───@───@───@────@────────────────────────Rz(pi*<θ_20/pi>)───
#                                                │   │   │    │                                                              │   │   │    │
# (0, 1): ───Rx(pi*<θ_1/pi>)───Ry(pi*<θ_6/pi>)───X───┼───┼────┼@────@────@─────────────Rx(pi*<θ_11/pi>)───Ry(pi*<θ_16/pi>)───X───┼───┼────┼@────@────@─────────────Rz(pi*<θ_21/pi>)───
#                                                    │   │    ││    │    │                                                       │   │    ││    │    │
# (0, 2): ───Rx(pi*<θ_2/pi>)───Ry(pi*<θ_7/pi>)───────X───┼────┼X────┼────┼@────@───────Rx(pi*<θ_12/pi>)───Ry(pi*<θ_17/pi>)───────X───┼────┼X────┼────┼@────@───────Rz(pi*<θ_22/pi>)───
# ...

# %%
from quple.utils.utils import pqc_symbol_map, replace_symbol_in_op

# %%
tt = list(A.expr_map.items())

# %%
new_map = { val:key for key,val in A.expr_map.items()}

# %%
from cirq.protocols import resolve_parameters

# %%
resolve_parameters(A, new_map)
# Out:
#                                            ┌──┐       ┌──┐                                             ┌──┐       ┌──┐
# (0, 0): ───Rx(θ_0)───Ry(θ_5)───@───@───@────@────────────────────────Rx(θ_10)───Ry(θ_15)───@───@───@────@────────────────────────
#                                │   │   │    │                                              │   │   │    │
# (0, 1): ───Rx(θ_1)───Ry(θ_6)───X───┼───┼────┼@────@────@─────────────Rx(θ_11)───Ry(θ_16)───X───┼───┼────┼@────@────@─────────────
#                                    │   │    ││    │    │                                       │   │    ││    │    │
# (0, 2): ───Rx(θ_2)───Ry(θ_7)───────X───┼────┼X────┼────┼@────@───────Rx(θ_12)───Ry(θ_17)───────X───┼────┼X────┼────┼@────@───────
#                                        │    │     │    ││    │                                     │    │     │    ││    │
# ...

# %%
replace_symbol_in_op(test[0].gate,
# Out:
# cirq.rx(sympy.Mul(sympy.pi, sympy.Symbol('<θ_0/sympy.pi>')))

# %%
cirq.protocols.resolve_parameters(tt[0][0], [tt[0][1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-7a01b1bc1dc6> in <module>
# ----> 1 cirq.protocols.resolve_parameters(tt[0][0], [tt[0][1]])
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/cirq/protocols/resolve_parameters.py in resolve_parameters(val, param_resolver)
#      93     param_resolver = study.ParamResolver(param_resolver)
#      94     if isinstance(val, sympy.Basic):
# ---> 95         return param_resolver.value_of(val)
#      96     if isinstance(val, (list, tuple)):
#      97         return type(val)(resolve_parameters(e, param_resolver) for e in val)
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/cirq/study/resolver.py in value_of(self, value)
#     119         # only use it for cases that require complicated resolution.
# ...

# %%
np.ndarray([1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-0815f9a5d243> in <module>
# ----> 1 np.ndarray([1])
#
# NameError: name 'np' is not defined

# %%
quple.circuit_entangling_measure(yans_clever_circuit)
# Out:
# 0.8502506238408387
