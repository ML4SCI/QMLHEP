# %% [markdown]
# # Circuit Descriptors
# - find the variance of gradients of a particular symbol in a circuit
# - sample final states of a circuit with symbols filled with random values
# - sample density matrices of circuit qubits with symbols filled with random values
# - calculate the Meyer Wallach measure of a state
# - calculate the von Neumann entropy of PQC
# - calculate the entangling measure of PQC
# - calculate the expressibility measure of PQC
# - Plotting the fidelity pdf of PQC and Haar
#
# Reference: https://arxiv.org/pdf/1905.10876.pdf

# %%
import quple
from quple.trial_wavefunction.real_amplitudes import RealAmplitudes
# define a PQC
n_qubit = 5
# define a parameterised circuit
cq = RealAmplitudes(n_qubit)

# %% [markdown]
# ## Gradient Variance Test
#
# This is inspired from https://www.tensorflow.org/quantum/tutorials/barren_plateaus

# %%
# define a measurement
qubits = cq.qubits
op = cirq.Z(qubits[0]) * cirq.Z(qubits[1])

# %%
# Do the gradient variance test
quple.gradient_variance_test([cq]*200, op)
# Out:
# 0.32825005

# %% [markdown]
# ## Sample Circuit Qubit Final States

# %%
final_states = quple.sample_final_states(cq, samples=200)
final_states
# Out:
# WARNING:tensorflow:From /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/tensorflow_core/python/util/deprecation.py:507: calling count_nonzero (from tensorflow.python.ops.math_ops) with axis is deprecated and will be removed in a future version.
# Instructions for updating:
# reduction_indices is deprecated, use axis instead
# [array([-0.0850793 -1.8895072e-08j, -0.04621872-6.2270393e-09j,
#         -0.02957638-8.2619369e-09j, -0.0584286 -9.7494723e-09j,
#          0.04328102+2.0818183e-09j,  0.08400565+1.0946739e-09j,
#          0.12907322+1.2186518e-08j,  0.06959779-5.2065454e-09j,
#         -0.03493428+4.7609472e-09j, -0.06560938+4.1610293e-09j,
#         -0.11088794-8.1807450e-10j, -0.05905576+7.2023587e-09j,
#         -0.16868225-9.5456834e-09j, -0.09051839+8.7997902e-09j,
#         -0.05522786+8.5695424e-09j, -0.10589024+2.9943938e-09j,
#          0.1269134 -6.3645089e-10j,  0.23958965+1.2271974e-08j,
#          0.39907128+4.9159475e-08j,  0.21292348-2.5489619e-09j,
#          0.4791859 +4.9551499e-08j,  0.25688496-1.2207300e-08j,
#          0.15610722-1.8315403e-08j,  0.2985276 +4.9919593e-09j,
#          0.09678946+6.2417030e-08j,  0.05308776+2.1812056e-08j,
#          0.0351975 +1.8636442e-08j,  0.0709933 +3.3732164e-08j,
#         -0.10410489-1.0439614e-08j, -0.20106302-4.2466805e-08j,
#         -0.31351024-1.1525006e-07j, -0.16871381-1.5469363e-08j],
#        dtype=complex64),
#  array([ 0.0543438 +1.5486297e-09j,  0.00352928-7.1997217e-09j,
#         -0.07141793-8.4095957e-09j,  0.06191925+7.6533704e-09j,
#         -0.10762078-3.8862783e-08j,  0.09300005+3.1401466e-08j,
#          0.05964191+1.2654878e-08j,  0.00427685-1.2088407e-08j,
#         -0.022786  +6.0005858e-09j,  0.01966742-5.4419034e-09j,
#          0.01096031-3.4598130e-11j,  0.00082747+1.6011810e-09j,
#          0.04331459+3.2767413e-09j,  0.00276744-2.2149025e-09j,
#         -0.05362148-1.9487153e-08j,  0.04652442+1.4338476e-08j,
#         -0.17349827-1.7774271e-09j,  0.14975044-9.5821662e-10j,
#          0.08329886-3.5815240e-09j,  0.00629327+3.7715586e-10j,
#          0.33277676+8.7499821e-08j,  0.02126051-3.5147536e-08j,
#         -0.41188046-2.1863968e-07j,  0.35736704+1.6980019e-07j,
#          0.20052637+8.8019192e-09j,  0.01302379-8.5555154e-09j,
#         -0.26359448-8.0059024e-08j,  0.22853537+5.8118683e-08j,
#         -0.39836103-2.5843926e-07j,  0.34424248+2.0377840e-07j,
#          0.22079898+7.1142708e-08j,  0.0158324 -1.9187175e-08j],
#        dtype=complex64),
#  array([ 0.24793652+6.2172745e-08j, -0.00494555+1.2272281e-08j,
#          0.1277745 -2.4092625e-08j,  0.5803078 +1.2464848e-07j,
#         -0.15003209+1.2871849e-08j, -0.58287024-1.1908715e-07j,
#         -0.16644701-1.7288844e-08j,  0.05409454+3.3498551e-08j,
#          0.03098114-2.1618918e-09j,  0.11764389+2.8285674e-08j,
#          0.03093259+5.3787255e-09j, -0.01250194-5.7908927e-09j,
#          0.01772994-6.7717889e-09j, -0.00199773-3.3995649e-09j,
#          0.01121768-7.7232531e-09j,  0.04775661-4.5603405e-09j,
#         -0.01231233+2.6130582e-09j, -0.04898471-3.7107206e-09j,
#         -0.01511684-4.1073700e-11j,  0.00387479+2.3889444e-09j,
#          0.04956526+5.6183405e-09j, -0.00168559-5.4729314e-09j,
#          0.02642548-1.2042450e-08j,  0.11866307+3.0295332e-08j,
#          0.11344567+5.1631343e-08j, -0.00254173-1.2653167e-08j,
#          0.0588173 -7.8988380e-09j,  0.26658678+1.5632065e-07j,
#         -0.0615747 -1.6422597e-10j, -0.23967658-1.3754521e-07j,
#         -0.06889461-2.0060494e-08j,  0.02197511+3.1891624e-08j],
#        dtype=complex64),
#  array([-0.04418813-1.9889301e-08j,  0.09472556+1.2731860e-09j,
#          0.06386617+2.1365024e-08j,  0.03376166+3.6246806e-08j,
#         -0.2319308 -1.1816646e-07j, -0.7066878 -3.3222682e-07j,
#          0.19827494+1.2642801e-07j,  0.41914833+1.9752905e-07j,
#         -0.01960195-1.1271100e-08j, -0.10377629-3.3536391e-08j,
#          0.01960863+8.2438500e-09j,  0.09297888+3.0030513e-08j,
#          0.03495285+6.1011157e-08j,  0.15627563+1.2149968e-07j,
#         -0.03555335-5.5524779e-08j, -0.17876124-2.0162356e-07j,
#         -0.03275109-1.3193903e-08j, -0.12083539-3.5158958e-08j,
#          0.02936059+1.3091958e-08j,  0.08668315+2.4286681e-08j,
#          0.01224215+2.3054945e-08j,  0.08420845+5.0163873e-08j,
#         -0.01054479-2.2266635e-08j, -0.08199438-8.1236976e-08j,
#         -0.01137193-1.8238062e-08j,  0.04769128-3.4071026e-09j,
#          0.0179451 +1.4655768e-08j, -0.00664388+3.1802280e-08j,
#         -0.08016351-5.3242935e-08j, -0.24869807-1.7217970e-07j,
#          0.06881833+6.9565317e-08j,  0.15067594+1.0043318e-07j],
#        dtype=complex64),
#  array([-0.05910722-7.3060683e-08j,  0.1496915 +8.5386127e-08j,
#          0.02086103+6.0465965e-08j, -0.13513394-1.0091737e-07j,
#          0.10301607+5.3509446e-08j, -0.03791508-5.8243582e-08j,
#         -0.0991618 -6.4615762e-08j,  0.02899239+5.4866984e-08j,
#         -0.13004047-5.2563376e-08j, -0.15368389-9.4560583e-08j,
#          0.06346241+3.7784105e-09j,  0.1908243 +1.1937465e-07j,
#         -0.08302421-6.3258760e-08j, -0.14100452-8.4280032e-08j,
#          0.13685916+1.0523236e-07j,  0.10872383+5.2609668e-08j,
#         -0.14433423-7.3916482e-08j, -0.24798502-1.6804728e-07j,
#          0.04673577-7.5851769e-09j,  0.29914653+2.0546018e-07j,
#         -0.15269457-1.2942455e-07j, -0.13808474-1.0059118e-07j,
#          0.2145807 +1.8946402e-07j,  0.0969156 +4.6063235e-08j,
#         -0.2159553 -1.8219785e-07j,  0.3766111 +2.8152229e-07j,
#          0.12836517+1.3392031e-07j, -0.34898764-3.0281853e-07j,
#          0.24317895+1.7285950e-07j, -0.18721731-1.2448287e-07j,
#         -0.26400068-1.9129800e-07j,  0.17870048+1.1676922e-07j],
#        dtype=complex64),
#  array([ 4.15130705e-02+4.1704585e-08j,  2.33621687e-01+4.6278711e-08j,
#         -4.55670357e-02-8.7247054e-10j,  2.58945301e-03+1.1271048e-08j,
#         -2.63493478e-01-5.2870003e-08j, -4.04735088e-01-9.7196562e-08j,
#         -4.36008088e-02-1.8286915e-08j,  2.15324730e-01+6.7670960e-08j,
#         -1.53337479e-01-5.4048726e-08j, -2.73189306e-01-1.1866999e-07j,
#         -5.08232825e-02-2.7072517e-08j,  2.34159529e-02+6.3389347e-09j,
#          3.65877114e-02-3.5050007e-10j, -3.31190154e-02-2.3224807e-08j,
#          1.21378034e-01+5.5072810e-08j,  2.10859716e-01+1.3228805e-07j,
#         -3.04179966e-01-8.7611085e-08j, -5.06202400e-01-1.7575356e-07j,
#         -7.66714737e-02-3.1990457e-08j,  1.43128112e-01+6.0045707e-08j,
#          6.07864261e-02+2.6284154e-08j,  9.47235674e-02+3.8669551e-08j,
#          1.00452423e-01+3.0210575e-08j,  2.19646633e-01+1.2709468e-07j,
#          1.94218010e-05-6.8947159e-09j, -1.31870985e-01-5.4690862e-08j,
#          8.91749784e-02+1.9171706e-08j,  1.15170762e-01+1.6791368e-08j,
#          4.34391983e-02+3.9583931e-08j,  4.59307581e-02+4.7752128e-08j,
#         -6.86479453e-03+1.5088425e-08j, -9.17585343e-02-4.0218506e-08j],
#        dtype=complex64),
#  array([-0.48248094-1.41679607e-07j, -0.14868034-4.34607621e-08j,
#         -0.09833586-9.77397718e-09j, -0.33041644-5.84527378e-08j,
#          0.11238861+2.81189871e-09j,  0.1439682 +2.77428231e-08j,
#          0.4818442 +2.39000315e-07j,  0.10085984+3.31743628e-08j,
#          0.03280826+6.57415100e-09j,  0.07095722+2.84182509e-08j,
#          0.1492745 +9.59592867e-08j,  0.03799412+1.72404562e-08j,
#         -0.3053833 -1.30531433e-07j, -0.08736727-1.45427554e-08j,
#         -0.06424795+3.32421646e-09j, -0.18281361-4.48080684e-08j,
#         -0.05098697-1.12679670e-08j, -0.05896   -2.61528008e-08j,
#         -0.21670446-1.51902981e-07j, -0.04387873-2.45274254e-08j,
#          0.1827502 +1.10776824e-07j,  0.05779592+1.92207530e-08j,
#          0.0368061 +2.22752083e-09j,  0.13093302+5.08848714e-08j,
#         -0.12025969-8.92309515e-08j, -0.04054828-1.66573368e-08j,
#         -0.02347137-5.28847899e-09j, -0.09598577-4.47094806e-08j,
#          0.04785821+1.15797576e-08j,  0.04632623+1.25717365e-08j,
#          0.20072174+1.79071293e-07j,  0.03852125+1.12411875e-08j],
#        dtype=complex64),
#  array([-0.01786456+1.57638524e-08j,  0.04787212+6.52858390e-09j,
#          0.38134122+7.57463852e-08j,  0.2505537 +7.91319010e-08j,
#         -0.09374562-2.59328417e-08j, -0.00806899+1.06858726e-08j,
#         -0.40718412-1.70958998e-07j, -0.05141581+2.64409117e-08j,
#          0.01189734+1.40416345e-09j, -0.00252696-2.86882784e-09j,
#          0.07898129-4.21884891e-08j,  0.00915556-1.24979875e-08j,
#          0.0087204 -7.55947749e-09j, -0.00473413+3.36246053e-09j,
#         -0.04286206+1.27879787e-08j, -0.02903473+3.11889927e-08j,
#         -0.09980887-5.72098600e-08j,  0.00557256+2.07454374e-08j,
#         -0.54242814-4.01794892e-07j, -0.06523247+1.45189842e-08j,
#         -0.04475899-1.94802787e-08j,  0.04561824-9.53600221e-09j,
#          0.38393182+1.60266865e-07j,  0.25573763+1.54404276e-07j,
#         -0.00457484+7.70188002e-09j,  0.02266623+9.85778903e-10j,
#          0.17767891+1.18248671e-07j,  0.11625336+1.14731229e-07j,
#         -0.0429192 -4.23722319e-08j, -0.00567735+6.12616935e-09j,
#         -0.17117003-1.83050332e-07j, -0.02207051+1.47487054e-08j],
#        dtype=complex64),
#  array([-3.7700467e-02+1.5345849e-09j,  1.9464338e-01+5.4527614e-09j,
#          3.0315363e-01+7.4274247e-08j,  3.8518794e-03-1.2621127e-08j,
#         -1.0055367e-01-7.9786808e-08j, -2.2624447e-03+1.1675742e-08j,
#          1.1524910e-02+6.0554122e-09j, -5.1582985e-02-1.7410946e-08j,
#          2.6241723e-01+7.9691489e-08j,  3.6089020e-03-9.9634372e-09j,
#         -3.2361150e-02-1.8921956e-08j,  1.6486880e-01+2.8037563e-08j,
#          3.2488517e-02+2.4266260e-08j, -1.6161238e-01-4.9425108e-08j,
#         -2.6733649e-01-1.2456444e-07j, -4.1581616e-03+3.0906261e-08j,
#         -4.0255523e-01-6.8992279e-08j, -3.6667269e-03+1.4148380e-08j,
#          5.1503293e-02+2.8681722e-08j, -2.7755061e-01-4.2913332e-08j,
#          3.8309973e-03-5.3638116e-10j, -3.4156889e-02+1.8222387e-08j,
#         -1.6497105e-02+2.1800480e-08j,  1.5784320e-03+1.8891191e-09j,
#          6.1258797e-02+4.2403947e-08j, -3.2928485e-01-7.6586602e-08j,
#         -4.7963953e-01-1.7248169e-07j, -4.4761263e-03+5.5726822e-08j,
#         -2.1018167e-01-7.4542200e-08j,  1.4962815e-04+3.0417077e-08j,
#          2.8944973e-02+3.8822289e-08j, -1.7211749e-01-7.5008806e-08j],
#        dtype=complex64),
#  array([-0.28670022-7.80785214e-08j,  0.04913484+7.50803864e-09j,
#          0.29212868+3.85854086e-08j, -0.5301543 -9.25821269e-08j,
#         -0.09821819-1.51144413e-08j,  0.20826024+5.05510762e-08j,
#         -0.23949827-9.28767321e-08j,  0.01046293+2.78710779e-08j,
#          0.10335763+4.02814777e-08j, -0.17786327-6.43078195e-08j,
#         -0.21010125-1.12834385e-07j,  0.02611354+2.62663953e-08j,
#         -0.03578993-4.48231567e-08j, -0.00801305+1.18475283e-08j,
#         -0.12185021-6.22729743e-08j,  0.2350173 +1.26842437e-07j,
#          0.05083976+1.60340079e-08j, -0.11301854-4.56518805e-08j,
#          0.1823727 +5.48443175e-08j, -0.01010749-1.88597653e-08j,
#          0.19105366+5.11706766e-08j, -0.03095505-1.12117586e-08j,
#         -0.17466316-8.23901303e-08j,  0.3152236 +1.15833330e-07j,
#          0.02842179+5.98485173e-09j,  0.0043331 -4.05482048e-09j,
#          0.0740435 +5.82098743e-08j, -0.14340694-9.65995426e-08j,
#         -0.06548606-5.13833562e-08j,  0.11198882+5.32482325e-08j,
#          0.14098513+4.32607834e-08j, -0.01717723-2.39648426e-08j],
#        dtype=complex64),
#  array([ 0.03211178+1.6310734e-08j,  0.01430247+1.0983481e-08j,
#         -0.01305377-1.9023272e-08j, -0.03108294-5.0877549e-08j,
#          0.02052322+4.9876969e-09j,  0.04956237+2.4408665e-08j,
#         -0.09876653-3.6312858e-08j, -0.04427221-1.8738797e-08j,
#         -0.06826471-1.3364337e-08j, -0.16486683-6.1030335e-08j,
#          0.3293285 +9.3333462e-08j,  0.1476243 +2.7515984e-08j,
#         -0.08486933-3.6581806e-08j, -0.03779308-6.9181390e-09j,
#          0.0350177 +5.6937144e-09j,  0.08336399+3.6148119e-08j,
#          0.09746944+1.3899626e-08j,  0.23534158+6.8357458e-08j,
#         -0.4661883 -1.0874731e-07j, -0.20896088-1.7237257e-08j,
#          0.23045313+7.6802294e-08j,  0.10266946+9.5635571e-09j,
#         -0.09184334+4.3337289e-10j, -0.21875739-5.8888656e-08j,
#          0.39724505+1.6749344e-07j,  0.17705473+5.2674711e-08j,
#         -0.1529124 -5.3677148e-08j, -0.36440977-2.3778196e-07j,
#          0.02158398+5.5577027e-09j,  0.05193136+2.5385065e-08j,
#         -0.09045946-3.4468503e-08j, -0.04050853+4.0541237e-09j],
#        dtype=complex64),
#  array([-0.08684686+7.2324351e-09j,  0.21757618+1.5766645e-07j,
#         -0.06914343-3.9894292e-08j,  0.06907419+3.6857475e-08j,
#         -0.20455678-8.6806118e-08j,  0.29018018+1.0685624e-07j,
#          0.06000637+1.4302079e-08j, -0.08200064-4.6279915e-08j,
#          0.18931736+8.3109896e-08j, -0.2741906 -1.0215000e-07j,
#         -0.07632113-2.8181205e-08j,  0.12348321+5.9642353e-08j,
#          0.17289536+4.9366797e-08j, -0.41989446-2.7055907e-07j,
#          0.08869426+8.3916603e-08j, -0.07195316-5.9747208e-08j,
#         -0.11316283-7.4654089e-08j,  0.16395226+9.7462859e-08j,
#          0.04583151+2.2149125e-08j, -0.0742946 -4.9935164e-08j,
#         -0.10428677-3.0462125e-08j,  0.25320867+2.0491103e-07j,
#         -0.05326722-6.0564815e-08j,  0.04309092+4.2745704e-08j,
#          0.10917205+5.9917312e-08j, -0.2736318 -2.4880913e-07j,
#          0.08737805+7.3121122e-08j, -0.08744716-5.0468991e-08j,
#          0.25919014+1.7583969e-07j, -0.36762905-2.1372342e-07j,
#         -0.07583752-2.1280680e-08j,  0.10345398+7.9099642e-08j],
#        dtype=complex64),
#  array([ 0.09763852+6.0202803e-09j,  0.02485066+8.0075715e-09j,
#          0.02088928-1.8284116e-08j,  0.38448125-3.7850501e-10j,
#         -0.03973865-4.2721071e-09j,  0.1030862 +1.3831434e-08j,
#         -0.6818215 -8.5673122e-08j,  0.00500253+4.0837502e-08j,
#          0.00370435+2.5007878e-09j, -0.04818171-1.0944143e-08j,
#          0.0864876 -4.3756998e-10j, -0.00288267-8.2078007e-09j,
#          0.05695638+1.5943961e-08j, -0.00120244-4.6225552e-09j,
#          0.00285321+4.7263855e-09j, -0.02086259-1.6598786e-10j,
#          0.01281272+1.7595938e-09j, -0.06579036-4.3050181e-09j,
#          0.23918757+7.5055389e-08j, -0.00365222-9.3713020e-09j,
#          0.02426819-3.5063432e-09j, -0.00707225-4.1749422e-09j,
#         -0.00268392+1.2615156e-08j, -0.11132576-3.9081982e-08j,
#          0.04794821+2.5096147e-08j,  0.01603029+4.5927031e-09j,
#          0.01253308-2.9655773e-08j,  0.24856588+6.6510729e-08j,
#         -0.02606826-2.0502021e-08j,  0.07702592+6.3272161e-08j,
#         -0.4528591 -2.1847622e-07j,  0.00387065+7.0559736e-08j],
#        dtype=complex64),
#  array([-0.06371284+4.4857114e-09j, -0.01239211+1.2245362e-08j,
#         -0.08582791+1.5162192e-09j,  0.04595931-1.8254349e-09j,
#          0.15275247+1.5987712e-08j, -0.03422861-4.6765036e-09j,
#         -0.06423172-1.0553915e-08j,  0.05158557+2.7131275e-08j,
#          0.43961158+6.9556194e-08j, -0.17095254-2.7473519e-08j,
#          0.08566558-7.5206472e-09j,  0.10348504-2.6669156e-09j,
#          0.23893021+2.9662495e-08j, -0.12721586-4.3810175e-08j,
#         -0.32671213-7.1566724e-08j,  0.04601458+3.0065120e-08j,
#          0.38351378+5.1674206e-08j, -0.13640222-2.1081636e-08j,
#          0.0271779 -5.8517213e-09j,  0.09818592+9.2205168e-09j,
#          0.13420416+2.0846219e-08j, -0.09488771-2.0587795e-08j,
#         -0.27100942-5.8050865e-08j,  0.05530567+2.9399651e-08j,
#          0.05396106+1.3066533e-08j, -0.07737775-3.2353647e-08j,
#         -0.25544065-1.2450870e-07j,  0.07155284+5.8458255e-08j,
#          0.38285294+2.0439577e-07j, -0.12244103-9.7068451e-08j,
#         -0.02412458-2.5583372e-08j,  0.10653815+3.0148076e-08j],
#        dtype=complex64),
#  array([ 0.15881665+1.62537255e-08j, -0.03129547+2.27850916e-09j,
#          0.0119535 +1.06710747e-08j, -0.11011489+1.11401666e-09j,
#          0.03415387-1.12163754e-08j,  0.01355266-3.08189776e-08j,
#          0.15839005-1.05694440e-08j, -0.00651089-2.30873276e-08j,
#         -0.18919331-3.56225982e-08j, -0.46741974-1.06236961e-07j,
#         -0.5242485 -5.07229814e-08j, -0.06305198+3.25401395e-08j,
#         -0.05265084-1.32259075e-08j,  0.09474987+4.26416129e-08j,
#          0.07198145+7.96934607e-09j,  0.4579324 +2.31572841e-07j,
#         -0.02167021-2.80306285e-08j, -0.07725663-7.14649602e-08j,
#         -0.03869899-3.73993174e-08j, -0.01321397-1.21542758e-08j,
#          0.04397005+3.68499045e-08j,  0.0061005 +6.11586204e-09j,
#          0.01659914+2.05847872e-08j,  0.04326025+5.07875058e-08j,
#         -0.10559149-4.75097330e-08j,  0.04906215+4.90899907e-08j,
#          0.0174843 +1.20173302e-08j,  0.21433645+1.93134952e-07j,
#         -0.08227195-6.03172552e-08j, -0.1640328 -1.23987405e-07j,
#         -0.263281  -1.49369043e-07j, -0.01750844+2.70816471e-08j],
#        dtype=complex64),
#  array([-0.00527037+3.4720766e-09j, -0.02188184+6.1163141e-09j,
#         -0.02060552+2.0532845e-08j, -0.00699515-7.3941870e-09j,
#         -0.14166349+1.8323320e-08j, -0.04917734+1.2419590e-08j,
#         -0.01743455+9.8836477e-09j, -0.07662947+1.7291823e-08j,
#          0.2024346 +8.5208768e-08j,  0.07030504-2.3201675e-08j,
#          0.02436825+1.3271390e-08j,  0.10736084+6.3833710e-08j,
#         -0.10717826+1.6661872e-10j, -0.4458354 -1.3978267e-07j,
#         -0.43369374-2.0027429e-07j, -0.14744683+3.0765932e-08j,
#         -0.03389833-5.1218475e-08j, -0.01176124-2.4858748e-10j,
#         -0.00428091-8.9527257e-09j, -0.01876457-3.4686373e-08j,
#         -0.02419311-7.9894571e-09j, -0.10061563-6.0526332e-08j,
#         -0.09751834-8.2047919e-08j, -0.03314879+2.5407982e-09j,
#         -0.04029185-1.4392937e-08j, -0.16773045-1.0340389e-07j,
#         -0.16522463-1.6089582e-07j, -0.05620409+1.3756498e-09j,
#          0.5355993 +3.1198385e-07j,  0.18594551-2.5616195e-08j,
#          0.06562994-4.7725344e-09j,  0.2885955 +1.5622982e-07j],
#        dtype=complex64),
#  array([ 0.14305173+3.39793900e-08j,  0.09420875+1.92184544e-08j,
#         -0.05726536-1.49644706e-08j, -0.06963797-1.69784311e-08j,
#          0.09412795+2.48107970e-08j,  0.12480072+3.74128675e-08j,
#         -0.0978098 -2.78097385e-08j, -0.06855156-1.50534838e-08j,
#          0.01270575+2.23604246e-09j,  0.01823656+8.23537860e-09j,
#          0.00527205+3.20649995e-08j,  0.00235686+1.69949761e-08j,
#          0.03869372+4.48136674e-08j,  0.02456736+2.24713421e-08j,
#         -0.00333317+7.35251415e-09j, -0.00176776+1.63537344e-08j,
#          0.1117683 +3.08872252e-08j,  0.177891  +7.21670688e-08j,
#          0.27849242+1.47094738e-07j,  0.16660228+6.55835422e-08j,
#          0.58391595+3.48757396e-07j,  0.36500248+1.60462534e-07j,
#          0.02591927+2.41585560e-08j,  0.08034033+9.68671046e-08j,
#          0.24713528+1.07071820e-07j,  0.1643061 +6.45241158e-08j,
#         -0.11954764-1.17095446e-07j, -0.14925295-1.67517285e-07j,
#          0.18424588+1.23987562e-07j,  0.24192657+1.75549204e-07j,
#         -0.22278467-2.44504122e-07j, -0.15387276-1.40098649e-07j],
#        dtype=complex64),
#  array([ 0.01287396-7.1825146e-09j, -0.03468392-1.6899977e-08j,
#          0.04214824+8.4843013e-09j,  0.05399678+4.7543951e-09j,
#          0.11655079+2.5530207e-08j,  0.11890583+1.9982071e-08j,
#          0.006654  -1.2003909e-09j, -0.11748382-5.1909353e-08j,
#          0.15115786+4.1179657e-08j,  0.15234639+3.3594322e-08j,
#          0.00685377-2.0245627e-09j, -0.15369159-7.5924746e-08j,
#          0.01480606-6.2452066e-09j, -0.02299803-3.0104545e-08j,
#          0.03239545+1.7400609e-08j,  0.04666164+1.2234706e-08j,
#          0.5262504 +1.5687121e-07j,  0.5250737 +1.3145713e-07j,
#          0.01880237-3.5837573e-09j, -0.538842  -2.7672311e-07j,
#          0.04616164-1.7845514e-08j, -0.01744468-2.2581130e-08j,
#          0.04935456-1.2541741e-09j,  0.09588706-4.3347672e-09j,
#          0.00713819-7.3621123e-09j, -0.08163141-4.7124537e-08j,
#          0.08276721+2.5865814e-08j,  0.08697453+1.6211484e-08j,
#          0.00139499-2.8369787e-08j,  0.00831579-2.7679619e-08j,
#          0.00664056-1.7941899e-09j,  0.0034838 +2.7054996e-08j],
#        dtype=complex64),
#  array([-0.03775796-7.21876603e-08j, -0.5278769 -6.25593159e-08j,
#         -0.0140309 -3.26108136e-08j, -0.18415114-5.20268486e-08j,
#          0.3045165 +8.03767222e-08j,  0.25392738+6.79936818e-08j,
#          0.09886596+4.98741457e-08j, -0.00861166+6.67519018e-09j,
#         -0.29784593-4.09066487e-08j, -0.32733297-5.46394219e-08j,
#         -0.11190426-1.28484148e-08j, -0.23348151-2.32374973e-08j,
#          0.0454997 +3.13821964e-08j, -0.00076284+3.32132899e-08j,
#          0.13952717+4.99997981e-08j,  0.11738669+4.57762930e-08j,
#         -0.10597864-4.65281822e-08j, -0.07981467-4.18862669e-08j,
#         -0.03275994-2.82335240e-08j,  0.02921242-1.64283520e-08j,
#          0.01221202+6.14247941e-09j,  0.23974916+7.39281134e-08j,
#         -0.00875036-7.28550908e-09j,  0.07088695+4.37977903e-08j,
#          0.00354529+1.08016796e-08j,  0.33871815+1.30225402e-07j,
#         -0.05435421-5.36012621e-08j,  0.06474595+2.91916535e-08j,
#         -0.05996867-2.69910974e-08j, -0.01415311+3.67326058e-09j,
#         -0.01256684-1.83902049e-08j,  0.11152528+3.57974805e-08j],
#        dtype=complex64),
#  array([ 0.06174727+2.29493988e-08j,  0.03161464+1.61667533e-08j,
#          0.0084401 +1.16826149e-08j,  0.00547531-2.41790676e-09j,
#          0.00073141-1.81620174e-09j,  0.00073438-1.82390387e-08j,
#          0.00331258+1.42574486e-08j,  0.00173159+9.61939328e-09j,
#         -0.01805149-4.97851982e-09j, -0.01719279+2.25341683e-08j,
#         -0.08906758-4.31631975e-08j, -0.04635202-2.06983888e-08j,
#          0.56811744+1.43868760e-07j,  0.29086536+3.71750808e-08j,
#          0.07756811+6.66966482e-09j,  0.0502396 -6.41063878e-08j,
#         -0.02155052-8.76388384e-09j, -0.02071051-7.53086038e-09j,
#         -0.10487998-4.20247090e-08j, -0.05461854-1.39938763e-08j,
#          0.26274478+1.27658666e-07j,  0.13451447+5.33748157e-08j,
#          0.03582782+2.00681818e-08j,  0.023162  -2.73758882e-08j,
#         -0.06062423-1.17253492e-07j, -0.03098551-5.93486078e-08j,
#         -0.00786209-1.96407832e-08j, -0.00470435+1.34227973e-09j,
#          0.1207495 -4.10707912e-10j,  0.11667193-1.05770837e-07j,
#          0.58271915+2.76654475e-07j,  0.30359283+6.69099762e-08j],
#        dtype=complex64),
#  array([ 0.05683611+1.43188705e-08j, -0.05994923-1.69378076e-08j,
#          0.01060756+5.39103295e-09j, -0.00507963-5.28684763e-10j,
#          0.02906702+3.01512024e-08j, -0.02090841-1.71167436e-08j,
#          0.05537369+3.51075400e-08j, -0.05971111-4.26226734e-08j,
#          0.0420168 +3.97961628e-08j, -0.03141443-2.52838568e-08j,
#          0.0629392 +4.73243418e-08j, -0.06849443-5.60809674e-08j,
#          0.01365599+1.15598144e-08j, -0.01379486-1.30876003e-08j,
#         -0.00619875-1.11867515e-09j,  0.00623208+4.56602356e-09j,
#          0.30054426+2.56466308e-07j, -0.22491299-1.59328934e-07j,
#          0.44722897+2.85351206e-07j, -0.48684102-3.44407908e-07j,
#          0.08577637+5.49987860e-08j, -0.08601178-6.28919494e-08j,
#         -0.04808131-1.32795748e-08j,  0.04693683+3.24832321e-08j,
#          0.29275692+1.59786268e-07j, -0.30894524-1.75975870e-07j,
#          0.05683585+6.01588255e-08j, -0.02803678-3.39465132e-08j,
#          0.1409208 +2.15386208e-07j, -0.10106756-1.43613732e-07j,
#          0.2727557 +2.50588613e-07j, -0.29396358-2.93903469e-07j],
#        dtype=complex64),
#  array([ 0.07801719+3.74814100e-08j, -0.0254609 -1.73456272e-08j,
#         -0.10348034-8.58330154e-08j,  0.26527148+1.73363361e-07j,
#          0.09580573+5.35108811e-08j, -0.24134387-1.00891910e-07j,
#          0.0094481 +1.55030797e-08j, -0.00872542-7.51912843e-09j,
#         -0.03147202-2.15474980e-08j,  0.08390655+4.37918750e-08j,
#          0.08571302+2.37759039e-08j, -0.0322541 -1.61051457e-08j,
#         -0.02676053+6.78895828e-09j,  0.00305324-1.27989397e-09j,
#          0.14456218+1.42566222e-07j, -0.36630228-2.38295144e-07j,
#         -0.18068588-1.14466474e-07j,  0.44519642+2.24744554e-07j,
#         -0.2092387 -8.78920403e-08j,  0.0921481 +5.45522312e-08j,
#         -0.14469768-7.74882736e-08j,  0.05946387+4.39637411e-08j,
#         -0.0431412 -2.52720618e-08j,  0.10136282+3.08327905e-08j,
#         -0.10534465-4.78019437e-08j,  0.04911297+2.83943624e-08j,
#         -0.1431889 -1.86697420e-07j,  0.35595605+3.44985352e-07j,
#         -0.13296989-1.41437908e-07j,  0.32296595+2.46102303e-07j,
#         -0.24349916-1.91371669e-07j,  0.10321061+1.17395444e-07j],
#        dtype=complex64),
#  array([-0.0949665 +1.15538796e-08j, -0.217045  -3.33158177e-08j,
#         -0.29887512-1.20407009e-07j, -0.14163342-3.26383471e-08j,
#          0.13924128+3.42598625e-08j,  0.06598076+4.96141483e-09j,
#          0.05258823-5.11703568e-09j,  0.12017719+2.48461927e-08j,
#         -0.38780528-1.26243023e-07j, -0.18375534-2.81229013e-08j,
#         -0.16673192+5.10743714e-09j, -0.38099787-1.35443742e-07j,
#          0.06273149-5.90360827e-09j,  0.1433866 +3.48240761e-08j,
#          0.22714175+1.06893410e-07j,  0.10764436+1.73343722e-08j,
#          0.24535464+6.93321525e-08j,  0.11625536+1.27594859e-08j,
#          0.10964051-8.39682368e-09j,  0.25053406+7.51734532e-08j,
#          0.00166016+2.32238451e-09j,  0.00378222+8.69550476e-09j,
#         -0.01966522-1.54916524e-08j, -0.00932294-4.51618520e-09j,
#         -0.05253298-3.00627034e-09j, -0.1200718 -4.90583787e-08j,
#         -0.1822908 -1.06555234e-07j, -0.0863881 -2.37322570e-08j,
#          0.2458767 +1.02528453e-07j,  0.11650535+1.25875603e-08j,
#          0.10442982-1.28498945e-08j,  0.23863328+1.03085789e-07j],
#        dtype=complex64),
#  array([-0.0716646 +4.5784798e-09j, -0.0379241 -3.6195056e-09j,
#          0.05636343+2.9208632e-08j, -0.1349044 -5.9754356e-08j,
#         -0.02737477+6.7385120e-09j,  0.16923429+4.7677702e-08j,
#          0.42075393+1.7847935e-07j,  0.1410887 +7.8655532e-08j,
#         -0.00571637-7.0112010e-09j, -0.02187244-1.8798616e-08j,
#         -0.12504007-9.3381104e-08j, -0.03820661-4.3421416e-08j,
#          0.05130574+1.0432082e-09j,  0.04900443+3.5556280e-08j,
#         -0.1216765 -8.7091308e-08j,  0.2634427 +1.3383935e-07j,
#         -0.0226794 -1.3373372e-08j,  0.01565794+2.0507377e-08j,
#         -0.11489711-2.4038426e-08j, -0.03042439+7.9752667e-09j,
#          0.08489736-1.1998583e-08j,  0.09250251+8.4126512e-08j,
#         -0.24381402-2.0791175e-07j,  0.52307105+3.3693894e-07j,
#          0.08105762+3.4046959e-08j,  0.05106566+2.7520136e-08j,
#         -0.09415704-6.4188512e-08j,  0.21497336+9.9801191e-08j,
#          0.02149817+2.8448287e-08j, -0.15429485-8.0525069e-08j,
#         -0.41002992-3.0428205e-07j, -0.13610098-1.1306492e-07j],
#        dtype=complex64),
#  array([ 0.02521697+1.32776901e-08j, -0.03517541-1.08520721e-08j,
#          0.08555075+3.15558282e-08j, -0.13360378-6.35173407e-08j,
#          0.04707659+2.02870361e-08j, -0.07114297-4.41920456e-08j,
#         -0.01631602-6.62679867e-09j,  0.03082047+1.28911495e-08j,
#          0.03419172+7.25939309e-09j, -0.04608704-2.37257272e-08j,
#         -0.08280582-4.79687756e-08j,  0.14030597+5.69528886e-08j,
#          0.06321599+5.66867158e-08j, -0.09860533-5.42195693e-08j,
#          0.08200165+7.79816602e-08j, -0.13113402-1.11100697e-07j,
#         -0.07437055+4.07664746e-09j,  0.1014189 +3.57275343e-09j,
#          0.16518274+9.40415674e-08j, -0.2803703 -1.08741318e-07j,
#         -0.12805454-1.03318868e-07j,  0.19910617+9.60450848e-08j,
#         -0.17418244-1.12364830e-07j,  0.27805614+1.17605062e-07j,
#          0.09926457+1.29115193e-07j, -0.13687214-1.10240201e-07j,
#          0.35700515+2.36536692e-07j, -0.55706203-3.04664070e-07j,
#          0.19812211+1.22284376e-07j, -0.30025887-1.95978828e-07j,
#         -0.05782347-2.01206518e-08j,  0.11168891+5.89968181e-08j],
#        dtype=complex64),
#  array([-0.05407747-4.5803031e-08j,  0.01683846-1.4831603e-08j,
#         -0.0044118 -2.6961544e-09j, -0.10622264-1.8614820e-08j,
#         -0.00299293-1.1685371e-08j, -0.1082878 -9.4011853e-08j,
#         -0.06686349-4.1958685e-08j,  0.01786422+4.3327235e-09j,
#         -0.03126879-2.2412803e-09j,  0.0039928 -4.1388944e-08j,
#          0.24719046+1.1777300e-07j, -0.01522332-6.1337637e-09j,
#          0.1461042 +5.0684655e-08j, -0.10832885+1.5307624e-08j,
#          0.06426239-6.3981886e-10j,  0.7770393 +4.6063636e-07j,
#          0.01522028+1.1112649e-09j,  0.0597099 +3.1881466e-08j,
#         -0.0689633 -3.7445709e-08j, -0.00355183-7.8462459e-10j,
#         -0.03250243-1.0530757e-08j,  0.0372938 -4.9350737e-09j,
#         -0.02528738+4.6725113e-10j, -0.27576715-1.6774406e-07j,
#         -0.05926456-4.8597659e-09j,  0.05410299-5.8373568e-09j,
#         -0.0345314 -2.3287843e-09j, -0.39443994-2.4975122e-07j,
#          0.01904785+6.5413661e-09j,  0.04504675+9.6246133e-08j,
#         -0.11102904-7.0137723e-08j,  0.00083183+6.5181811e-09j],
#        dtype=complex64),
#  array([ 0.07082543-1.4171034e-09j, -0.02344535-2.5442510e-09j,
#         -0.02701249-1.1886777e-08j,  0.17563486+8.3049079e-09j,
#          0.00820756+5.0394542e-09j, -0.04400174-2.8713509e-09j,
#         -0.05503856-7.6850473e-09j,  0.01464814+1.0320924e-08j,
#          0.00995753+1.0515456e-08j, -0.06567964-2.3689497e-08j,
#         -0.0227578 -5.7414615e-09j,  0.00789048+1.4972731e-08j,
#         -0.02233876+7.4609856e-09j,  0.00881973+9.0452987e-09j,
#          0.01362064+1.9177616e-08j, -0.09229729-3.3004209e-08j,
#          0.02043085+3.4128263e-08j, -0.09586455-2.4292421e-08j,
#         -0.18593182-1.6032847e-07j,  0.04744631+1.0172933e-07j,
#          0.2966464 +6.5308576e-08j, -0.09978276-1.7369089e-07j,
#         -0.1188093 -2.1480763e-07j,  0.77664936+4.8564226e-07j,
#          0.07282206+4.4242228e-08j, -0.01863766-2.6932431e-08j,
#         -0.00819826-1.0925517e-08j,  0.03896648-6.8498007e-09j,
#          0.05658923+1.0764978e-07j, -0.35057217-2.3573847e-07j,
#         -0.21055332-1.2982072e-07j,  0.06307456+1.4262810e-07j],
#        dtype=complex64),
#  array([-1.9547004e-02-3.6345682e-09j, -7.0445918e-02+4.1890935e-08j,
#         -6.9121784e-03+2.2749896e-10j, -2.0719431e-02+1.4353496e-08j,
#          8.2968399e-03+2.9136357e-08j,  9.5207365e-03+4.5831257e-08j,
#         -2.3356616e-04+5.2526730e-09j, -6.2695523e-03+4.2742410e-08j,
#         -1.2948802e-01-4.1118291e-08j, -1.9682951e-01-6.8187077e-08j,
#         -7.0828155e-02+4.3566665e-08j, -1.8760704e-01-1.1081278e-07j,
#         -1.5037262e-01+8.8363684e-08j, -5.6240720e-01-2.8333832e-07j,
#         -2.1563753e-02+3.6939017e-08j, -1.2254170e-01-4.7838835e-08j,
#          6.1902914e-02+6.3099471e-08j,  8.8027984e-02+9.5268526e-08j,
#          2.4491990e-02+5.6550109e-10j,  5.3779759e-02+9.1549332e-08j,
#          1.4597018e-02-1.8083686e-08j,  5.9819520e-02+1.0350956e-07j,
#         -5.9737116e-03-5.7126677e-09j,  2.4913531e-03+1.9825343e-08j,
#         -2.5900358e-02+2.3181389e-08j, -1.3354091e-01-7.9932953e-08j,
#          5.2899141e-02+4.4205198e-08j,  4.4890225e-02+3.0737400e-08j,
#         -3.6852044e-01-1.2810530e-07j, -5.1758724e-01-2.2102334e-07j,
#         -1.3583136e-01+7.6821436e-08j, -2.8192979e-01-1.5170050e-07j],
#        dtype=complex64),
#  array([ 0.02474796+3.1019994e-08j, -0.01841241-2.7750266e-08j,
#          0.00979579+1.7525297e-08j,  0.0226338 +2.5787102e-08j,
#         -0.05962389-4.7062496e-08j,  0.04638439+6.3246681e-08j,
#          0.07707053+9.7224017e-08j,  0.01555007-1.1474499e-08j,
#          0.3445163 +1.0502533e-07j, -0.09534711-4.1747988e-08j,
#         -0.23181748-8.6769887e-08j, -0.1803542 -2.9766412e-08j,
#          0.14111383+3.1406440e-08j,  0.31101435+1.2537633e-07j,
#         -0.45853812-2.0286771e-07j, -0.00849836+3.8072198e-08j,
#          0.02319366-4.3191875e-08j, -0.01026144+4.5320249e-08j,
#         -0.02035777+6.5407605e-08j, -0.01012789+8.3884046e-09j,
#          0.00317772+1.3376253e-08j,  0.01638466-3.3466097e-08j,
#         -0.02192548+3.4344026e-08j, -0.00329332+2.0746443e-08j,
#         -0.17182557-4.8992447e-08j,  0.07434697+6.4662451e-08j,
#         -0.0018701 -1.6016401e-08j, -0.13945954-2.8787813e-08j,
#          0.32595563+1.8969475e-07j, -0.2757795 -1.4364065e-07j,
#         -0.44878775-2.5910194e-07j, -0.07337296+5.0132417e-08j],
#        dtype=complex64),
#  array([ 0.00719098-4.31498606e-08j, -0.08775902-5.52683055e-08j,
#          0.20085093+7.15874577e-08j,  0.46805695+1.80381988e-07j,
#          0.03803897+1.97145855e-08j,  0.04447872+2.85251591e-08j,
#         -0.09973256-3.27434933e-08j, -0.01646209-4.49633397e-09j,
#          0.00171359+1.20290125e-08j,  0.04094469+4.71646544e-08j,
#          0.08464152+2.84923196e-08j, -0.00088135-1.52940309e-08j,
#         -0.02185271+4.06390654e-08j,  0.06070062+6.89681272e-08j,
#         -0.13886276-6.30308392e-08j, -0.33097655-2.01903717e-07j,
#         -0.00172392-1.23031425e-08j, -0.04928816-5.59958337e-08j,
#         -0.10368466-4.42535502e-08j,  0.00091572+1.76147115e-08j,
#          0.02659542-4.78942255e-08j, -0.07450947-9.05034128e-08j,
#          0.17045362+9.08088609e-08j,  0.40617284+2.81424661e-07j,
#         -0.00834363+7.40189989e-08j,  0.09989673+1.17053723e-07j,
#         -0.22862953-1.20090675e-07j, -0.5328603 -3.66004230e-07j,
#         -0.04303754-1.27877140e-08j, -0.04995877-5.06481790e-09j,
#          0.11367296+7.98120467e-08j,  0.01862401-4.20736423e-09j],
#        dtype=complex64),
#  array([-0.02399037+1.9835605e-08j, -0.00635679+2.3149806e-08j,
#          0.10111436+3.0915629e-08j,  0.02279309+3.2807900e-08j,
#         -0.3845305 -3.3844330e-08j, -0.02260179-2.2525755e-08j,
#         -0.11345104-6.2595769e-09j, -0.3001393 -1.5916559e-08j,
#         -0.10783727-1.5557113e-08j,  0.02544724+1.4592915e-08j,
#         -0.13334814+2.6566797e-08j, -0.24504378+2.2858135e-08j,
#         -0.42890286-1.1066783e-07j, -0.62312436-1.5148301e-07j,
#          0.18032575+1.2817411e-07j,  0.16152729+1.0167592e-07j,
#          0.01378342-1.7667290e-09j, -0.00146057-3.3507892e-09j,
#          0.01131994-5.7144955e-09j,  0.02225098-6.7627042e-09j,
#          0.03101952+2.7607578e-09j,  0.04461563+3.2811638e-09j,
#         -0.0144809 -8.1949683e-09j, -0.01189965-5.8747607e-09j,
#          0.01168709+1.8997168e-09j,  0.01115192-1.6128915e-10j,
#         -0.02352818-2.5455327e-08j, -0.00721486-1.0876971e-08j,
#          0.08033851+4.1012640e-08j,  0.00421956+1.1684222e-09j,
#          0.02530819+8.7038039e-09j,  0.06525047+2.5766310e-08j],
#        dtype=complex64),
#  array([ 0.01247793-1.0615319e-08j,  0.02052628-1.1323689e-08j,
#         -0.00660406+8.9389758e-09j,  0.00306484-9.6945865e-09j,
#          0.02760665+2.0027358e-09j,  0.00415627-2.2200630e-10j,
#         -0.04618131+1.0768156e-08j, -0.08494903+1.1172675e-08j,
#          0.00575211+1.8764110e-08j, -0.04224054-2.3024691e-08j,
#         -0.02481326-1.3705153e-08j, -0.0198746 -1.3156250e-08j,
#         -0.09101281-1.7764371e-08j, -0.05434605-1.2237170e-08j,
#          0.01456035+5.5072150e-08j, -0.18695351-9.8803781e-08j,
#         -0.01665945-4.3091543e-08j,  0.09116644+4.7075513e-08j,
#          0.06087984+3.1287833e-08j,  0.05598885+3.4364543e-08j,
#          0.19589937+2.0551003e-08j,  0.11500636+1.7098957e-08j,
#         -0.03064597-1.0548273e-07j,  0.40580595+1.8033533e-07j,
#         -0.08740334-2.5568378e-08j, -0.15814877-7.9295596e-08j,
#          0.05132301+3.0069039e-08j,  0.00333246+1.8540382e-08j,
#         -0.22458066-2.2120894e-07j, -0.02731633-2.5202086e-08j,
#          0.37797463+1.0164071e-07j,  0.69138956+3.4603681e-07j],
#        dtype=complex64),
#  array([-0.00873397-6.1703034e-09j, -0.02074359+7.1933699e-09j,
#          0.03860627-8.9149577e-09j,  0.11232863+3.5415827e-08j,
#          0.00150268-1.0407030e-09j, -0.02421984-1.8651464e-10j,
#         -0.05648982-5.0816373e-09j, -0.00778231+4.3239976e-09j,
#         -0.0083834 +6.1220993e-09j, -0.08442877+3.8122860e-08j,
#         -0.11600488+5.2496780e-08j, -0.01014115+1.1772122e-08j,
#          0.01752034+1.5980795e-08j,  0.003838  -5.8335076e-10j,
#         -0.00326317+2.0735258e-09j, -0.00094893+8.5708924e-09j,
#         -0.05204406-1.3692954e-08j, -0.5561671 -3.0090723e-07j,
#         -0.78306633-4.2235919e-07j, -0.07077064+1.3611757e-08j,
#          0.10421293+1.7359135e-07j,  0.00750088+8.8648084e-09j,
#          0.01069186+2.0538240e-09j,  0.08540684+1.3205134e-07j,
#          0.01624537+3.3203516e-08j,  0.00783551+3.7070096e-09j,
#         -0.0114246 -6.9216727e-10j, -0.02628479-1.0567757e-08j,
#         -0.00716544+1.7696805e-09j, -0.0632247 -6.4976980e-08j,
#         -0.0815986 -9.5120988e-08j, -0.00648743+3.8685797e-09j],
#        dtype=complex64),
#  array([-0.14630295-2.4653586e-08j,  0.2621556 +2.1042389e-08j,
#          0.01485447+2.2126434e-09j, -0.02243276-2.1683665e-08j,
#         -0.14468065-4.8896666e-08j,  0.15904611+9.0256933e-08j,
#         -0.24730219-1.1053396e-07j,  0.4491686 +9.7198253e-08j,
#         -0.14433055-2.8133304e-08j,  0.1632173 +5.3128772e-08j,
#         -0.11853649-6.7601313e-08j,  0.21796028+6.3740536e-08j,
#         -0.04490801-1.4997037e-08j,  0.07596365+3.2293354e-08j,
#          0.13130568+2.2014570e-08j, -0.15391788-5.7131825e-08j,
#         -0.24788164-7.7073267e-08j,  0.28330392+1.4026112e-07j,
#         -0.11960758-7.8812043e-08j,  0.2235644 +7.3846351e-08j,
#         -0.01092659+3.9507253e-08j,  0.0088889 -3.2945621e-08j,
#          0.30183306+1.4957249e-07j, -0.3505307 -2.9359938e-07j,
#         -0.0197325 -9.4908650e-09j,  0.03830291-1.9636466e-09j,
#         -0.08083827-5.8051050e-08j,  0.09307522+7.2630364e-08j,
#          0.04579476+4.7923919e-08j, -0.05331963-5.4562939e-08j,
#         -0.0054938 +2.6198977e-08j,  0.00823607-4.1188354e-08j],
#        dtype=complex64),
#  array([-0.00174333-2.5528089e-09j,  0.11065123+2.0926898e-09j,
#         -0.10369033-1.8413232e-08j,  0.08384176+9.1897983e-09j,
#         -0.0075467 -4.8025477e-09j,  0.09811313-8.7428447e-09j,
#          0.0848313 -1.3751741e-08j,  0.08831672-6.7124502e-09j,
#         -0.01032445-2.3612198e-08j,  0.14426115+1.7689080e-08j,
#          0.1253214 -5.7265357e-09j,  0.12957765+2.5213264e-08j,
#         -0.00353242-3.9984993e-08j,  0.18076444+8.9035829e-08j,
#         -0.16998988-1.2837864e-07j,  0.13671982+8.0331361e-08j,
#          0.00063478-7.2224227e-11j, -0.03584793-9.7946353e-09j,
#         -0.03261551-8.3178353e-09j, -0.03150065-8.5500922e-09j,
#          0.00330183+1.9163565e-08j, -0.0901132 -5.6008378e-08j,
#          0.08608609+7.4136437e-08j, -0.06759895-4.9340880e-08j,
#         -0.00957857-1.0572329e-07j,  0.44818634+1.4576948e-07j,
#         -0.4221875 -2.5869605e-07j,  0.33868557+1.4136924e-07j,
#         -0.02319638-3.6453947e-08j,  0.33847952+4.9110689e-08j,
#          0.2948259 +1.9781606e-08j,  0.3036558 +2.8916475e-08j],
#        dtype=complex64),
#  array([-0.00307458+1.8831687e-09j,  0.00791982+1.7742000e-09j,
#         -0.01537474+6.1296532e-09j,  0.00534484-1.9156416e-09j,
#          0.03649184+1.8304593e-08j, -0.01273705-8.5043537e-09j,
#          0.01066776+1.2714299e-08j, -0.0277347 -1.6428523e-08j,
#         -0.02714493+2.0722486e-09j,  0.00945989+2.2173041e-11j,
#         -0.00696457-2.1070107e-10j,  0.01805657+1.9983988e-09j,
#          0.02979343+2.5459276e-08j, -0.07691974-3.1505657e-08j,
#          0.137463  +8.1120390e-08j, -0.04782223-4.5687784e-08j,
#         -0.06939253+3.6163148e-09j,  0.02416034-1.4144614e-09j,
#         -0.01630799+1.1368126e-08j,  0.04219214+7.1184210e-09j,
#          0.11855321+1.1813380e-07j, -0.3060977 -1.4613522e-07j,
#          0.5456259 +3.9998278e-07j, -0.18982321-2.0981823e-07j,
#         -0.01340815-1.5313701e-08j,  0.03433779+8.1149977e-08j,
#         -0.08025726-7.7233395e-08j,  0.02786038+3.3594979e-08j,
#          0.5333952 +3.8993767e-07j, -0.18619207-2.0526818e-07j,
#          0.15704171+2.3059211e-07j, -0.4083445 -3.3923706e-07j],
#        dtype=complex64),
#  array([-0.18297479-5.0581290e-09j,  0.01377306-5.6382197e-09j,
#         -0.10868877-4.3048789e-08j,  0.44237474+1.2512362e-07j,
#          0.00938228+2.6105669e-09j, -0.00675961-1.3712100e-09j,
#         -0.07503662-1.2276171e-08j,  0.02431631+1.1234197e-08j,
#          0.17528875+8.7668134e-08j, -0.6499262 -2.7816429e-07j,
#          0.11151461+3.5583838e-08j,  0.02933607+2.3171323e-09j,
#          0.17976522+7.7842927e-08j, -0.04038162-3.0214622e-08j,
#          0.02917952+3.0081956e-08j, -0.16396537-6.1046386e-08j,
#         -0.02440707-1.3671514e-08j,  0.10010188+3.8487578e-08j,
#         -0.04329229-1.2714597e-08j,  0.00371163+2.0722155e-09j,
#         -0.091044  -5.0970048e-08j,  0.01108434+1.4103710e-08j,
#         -0.04185193-5.2829449e-08j,  0.17746498+1.4997566e-07j,
#          0.15771051+8.3585178e-08j, -0.02107438-2.3976828e-08j,
#          0.06708273+7.4634698e-08j, -0.28852707-1.8842988e-07j,
#          0.05515382+5.6341651e-08j, -0.2192159 -1.3615355e-07j,
#          0.07763012+5.0259985e-08j, -0.00271538-1.6563453e-08j],
#        dtype=complex64),
#  array([ 0.02878025+1.5545528e-08j, -0.02118996-6.6167924e-09j,
#          0.07190824+4.2380393e-08j,  0.05327787+2.9303694e-08j,
#          0.00364538-2.0551008e-08j,  0.00269812-1.5287792e-08j,
#          0.00134819-3.0521010e-09j, -0.0009996 +2.2908944e-09j,
#         -0.5275205 -1.4513347e-07j, -0.39093384-7.7089844e-08j,
#         -0.21455188-4.0148322e-08j,  0.15775234+4.2485443e-08j,
#         -0.13196726-3.6315399e-08j,  0.09722525+5.4810162e-08j,
#         -0.33218804-7.3463170e-08j, -0.24609816-1.4393099e-08j,
#         -0.3384881 -1.1449879e-07j, -0.25084653-6.5303411e-08j,
#         -0.13768905-3.4501806e-08j,  0.10123663+3.3687360e-08j,
#         -0.08053385-2.8089506e-08j,  0.05933433+3.7786581e-08j,
#         -0.20279977-5.8482819e-08j, -0.15024137-1.8905087e-08j,
#         -0.00109145+1.0710207e-08j,  0.00081282-7.6011890e-09j,
#         -0.00309345+3.4224893e-08j, -0.00228829+2.5632410e-08j,
#         -0.0760961 -4.3687127e-08j, -0.05639533-2.0694461e-08j,
#         -0.0310362 -9.8838475e-09j,  0.02281445+2.0746947e-08j],
#        dtype=complex64),
#  array([-0.02454787-2.2455753e-08j, -0.02771795-5.8626224e-08j,
#          0.07945705+3.7436404e-08j, -0.01850738-3.9914854e-09j,
#         -0.36337596-1.3828557e-07j,  0.09676051+7.9826577e-08j,
#          0.09593748+2.2470035e-08j,  0.06909035+1.0285040e-08j,
#         -0.22348835-9.5876246e-08j,  0.04001183+3.6077182e-08j,
#          0.08526608+2.4001288e-08j,  0.13526064+6.2723245e-08j,
#          0.23970847+7.9495706e-08j,  0.55930454+3.0825834e-07j,
#         -0.3871541 -2.7917463e-07j,  0.00100306+5.7935125e-08j,
#         -0.05259754+3.3220193e-08j,  0.01433302-1.9690569e-08j,
#          0.01344592-1.6322968e-08j,  0.00844374-9.1104448e-09j,
#         -0.0078295 -2.3279288e-08j, -0.01368469-6.2050859e-08j,
#          0.0188187 +3.2731045e-08j, -0.00288674-2.9079552e-09j,
#          0.00976733+1.2856038e-08j,  0.05578775+5.7538553e-08j,
#          0.02866621+2.3269216e-08j, -0.02050511-1.6020055e-08j,
#         -0.4403097 -3.9348194e-07j,  0.11422289+2.1317959e-07j,
#          0.12032163+7.5878894e-08j,  0.09810348+8.7989882e-08j],
#        dtype=complex64),
#  array([ 0.02299318+2.9900327e-09j,  0.00219514-2.9004929e-10j,
#          0.06239389-3.4711396e-09j,  0.03376126+3.4944088e-09j,
#         -0.07541224-4.5690189e-09j, -0.04551023-1.9891651e-08j,
#          0.12240886+4.5648029e-08j, -0.00108047-9.5998116e-09j,
#          0.07132034+1.2886395e-08j,  0.0428678 +1.5533502e-08j,
#         -0.11024269-3.6606711e-08j,  0.00107969+8.8414662e-09j,
#         -0.01706369-3.4686249e-09j, -0.00219658+6.4705570e-09j,
#         -0.06442183-1.8651559e-08j, -0.03506771-3.6532066e-09j,
#         -0.10287388-8.4814662e-09j, -0.05997624-2.0435255e-08j,
#          0.09972763+1.2847316e-08j, -0.00217815-6.6600450e-09j,
#         -0.02563523-5.3342546e-08j,  0.00446216-9.0105576e-09j,
#          0.15102333+4.2039620e-08j,  0.08426481+3.4921662e-08j,
#          0.08377446-4.6345125e-08j,  0.01375833-3.9114123e-08j,
#          0.41123056+1.2852479e-07j,  0.22463915+8.8326658e-08j,
#         -0.43062085-1.8975950e-07j, -0.25811732-2.4636523e-07j,
#          0.6429105 +5.1115182e-07j, -0.00675683-7.0989195e-08j],
#        dtype=complex64),
#  array([-6.09660521e-04-2.5031039e-09j,  9.27584711e-03-1.1541613e-08j,
#         -1.03764892e-01-4.9066542e-09j,  4.69925441e-03+1.0122074e-08j,
#         -1.69662639e-01-1.8336156e-08j,  6.77732565e-03+1.9529903e-08j,
#          6.37012348e-03+1.9762989e-08j, -2.51168340e-01-5.4372610e-08j,
#         -9.13404953e-03+8.3768565e-09j,  5.36100008e-04+7.9484597e-09j,
#         -1.04901474e-03-5.3422822e-09j,  3.68009470e-02+9.8359267e-09j,
#          6.61844388e-04-4.7141695e-09j, -5.77231981e-02-1.7867137e-08j,
#         -2.74723679e-01-8.2563304e-08j,  1.21615566e-02+6.7884422e-08j,
#          1.41163301e-02-3.7326657e-08j, -9.18684527e-04-1.5018715e-08j,
#          2.35394761e-03+1.2423683e-08j, -8.33653733e-02-5.3945211e-08j,
#         -1.38853118e-03+9.6264579e-09j,  1.19858384e-01+4.2504691e-08j,
#          5.66253662e-01+1.7594917e-07j, -2.50641219e-02-1.4084628e-07j,
#          1.33097172e-03+9.7583008e-09j, -2.16009729e-02-5.4523582e-08j,
#          2.15554684e-01+2.0272690e-08j, -9.76987183e-03-4.1207784e-08j,
#          3.64918053e-01+8.9989001e-08j, -1.45721436e-02-7.5974000e-08j,
#         -1.37406290e-02-9.3441741e-08j,  5.41650355e-01+2.6565505e-07j],
#        dtype=complex64),
#  array([-0.08249494+8.52689475e-10j, -0.29543287-1.02961151e-08j,
#          0.15256272+4.28995506e-08j,  0.01053103-1.68537495e-09j,
#          0.22203878+1.14094064e-07j,  0.02884174+5.97293059e-09j,
#         -0.0335345 +5.89410210e-09j, -0.14508854-7.25181408e-08j,
#         -0.03856359+1.45708965e-08j, -0.01855465+1.15628840e-08j,
#         -0.08089891+1.98220089e-08j, -0.26032588-1.06999330e-07j,
#          0.16643843-1.17681296e-08j,  0.5595953 +2.06491777e-07j,
#         -0.07438509-6.39223785e-08j,  0.0145793 -4.02034184e-09j,
#         -0.05985516-2.01661710e-08j, -0.01424037+5.29476241e-10j,
#         -0.03235463-2.83493917e-09j, -0.09717453-4.56378757e-08j,
#          0.09484346-5.98242123e-09j,  0.32225353+9.93608467e-08j,
#         -0.0639843 -5.22549115e-08j,  0.00499313-3.51158658e-10j,
#          0.07577169-8.55663629e-09j,  0.27816108+9.17334049e-08j,
#         -0.18370152-7.77636302e-08j, -0.01636046+1.25925794e-08j,
#         -0.28036815-1.86274491e-07j, -0.0338899 +1.13163123e-08j,
#          0.05853263-1.44184567e-08j,  0.23650222+1.32140585e-07j],
#        dtype=complex64),
#  array([-4.3895811e-01-1.80659526e-07j,  3.7896946e-01+1.02280303e-07j,
#         -1.3462113e-01-8.39169445e-08j,  2.2561073e-01+9.93849625e-08j,
#          4.5444565e-03-2.67022635e-08j, -2.2871606e-04+3.07990611e-08j,
#         -6.0308989e-02-6.12236946e-08j,  5.4332644e-02+3.67869255e-08j,
#          8.3210588e-02+5.01102910e-08j, -1.3179319e-01-6.09846467e-08j,
#          1.9343494e-01+1.59608945e-07j, -1.6465099e-01-1.10471966e-07j,
#          1.4541081e-01+5.13127425e-08j, -1.2685984e-01-4.59921381e-08j,
#          3.1160071e-02+3.33729311e-08j, -5.6528591e-02-4.09867731e-08j,
#         -1.7733605e-01-1.02975370e-07j,  2.7384168e-01+1.38593606e-07j,
#         -3.4072670e-01-2.46028350e-07j,  2.8700000e-01+1.87826998e-07j,
#          1.4106011e-01+5.01941173e-08j, -1.1904000e-01-5.12399438e-08j,
#          7.1152687e-02+4.99969630e-08j, -1.1030146e-01-6.56877148e-08j,
#          1.1941465e-01+1.47193717e-07j, -1.0176219e-01-1.02872399e-07j,
#          5.0179407e-02+7.01815850e-08j, -7.9748660e-02-8.74154793e-08j,
#         -8.6721122e-02-8.44873540e-08j,  1.3312797e-01+1.06118428e-07j,
#         -1.5862450e-01-1.89596733e-07j,  1.3320284e-01+1.48226619e-07j],
#        dtype=complex64),
#  array([ 0.16020659-4.34303482e-09j, -0.14939062-1.81863835e-09j,
#         -0.25970617-3.87087056e-08j,  0.28636277+2.96641165e-08j,
#         -0.277434  -7.21952489e-08j,  0.31114638+6.48014549e-08j,
#          0.01661422-4.62723726e-08j, -0.02398074+3.09337373e-08j,
#         -0.05583584-2.40369893e-08j,  0.0667007 +2.68135718e-08j,
#         -0.11706349-4.64041534e-08j,  0.10083793+4.24618847e-08j,
#          0.04101045+1.92306882e-08j, -0.03117631-1.84965216e-08j,
#          0.14203157+6.26309742e-08j, -0.16096835-6.61860255e-08j,
#          0.3100287 +1.32159641e-07j, -0.35759926-1.41203415e-07j,
#          0.27352297+1.58473028e-07j, -0.22952679-1.38275226e-07j,
#         -0.20029747-1.01042644e-07j,  0.1696352 +9.15678626e-08j,
#         -0.18112206-1.17243012e-07j,  0.21028577+1.27243723e-07j,
#         -0.07401964-4.93526890e-08j,  0.06457631+4.24374633e-08j,
#         -0.01121873-2.49943088e-08j,  0.01511285+2.66655640e-08j,
#          0.11862753+9.29014945e-08j, -0.13560998-9.95818041e-08j,
#          0.06866412+7.96597632e-08j, -0.05623702-6.98517013e-08j],
#        dtype=complex64),
#  array([ 0.08170746+1.41911647e-08j,  0.31834924+5.43750431e-08j,
#         -0.2649353 -6.50966498e-08j, -0.2747062 -5.28852411e-08j,
#          0.03237533+3.85834475e-08j,  0.03961867+2.90455588e-08j,
#         -0.00757782-1.59671618e-08j, -0.04913954-3.93258865e-08j,
#         -0.08531702-1.34149918e-08j, -0.10705723-7.98466893e-09j,
#          0.01891413-9.85137039e-09j,  0.13398318+1.53363473e-08j,
# ...
#         -0.17013948+6.4834360e-11j,  0.03302384+1.3334978e-09j,
#          0.0800152 +2.3549898e-08j, -0.17711008-3.1415237e-08j,
#          0.3048008 +7.3633345e-08j, -0.05750311-1.2208822e-08j,
#         -0.13360442-4.6647383e-08j,  0.2922013 +6.4884631e-08j,
#         -0.08355425-3.5361634e-08j,  0.19338581+6.1680581e-08j,
#          0.12807593+9.2752392e-09j, -0.02882967-1.2700262e-08j,
#          0.49419516+1.3770753e-07j, -0.09142841-2.3335291e-08j,
#         -0.20601705-7.9249588e-08j,  0.44645318+1.1706386e-07j,
#         -0.0601799 -3.4857180e-08j,  0.14587235+7.3518486e-08j,
#          0.05355901-1.6901165e-08j, -0.01635284-3.8018388e-09j,
#          0.04916275+4.2757087e-08j, -0.10538343-9.3543136e-08j,
#         -0.12472019-1.3470719e-07j,  0.02259204+3.0756446e-08j,
#          0.17109701+8.0092640e-08j, -0.02997521-2.1898856e-08j,
#         -0.06146631-2.9441374e-08j,  0.12917529+1.5552885e-08j],
#        dtype=complex64),
#  array([-0.02221911-4.75520334e-09j,  0.21942902+1.02868265e-08j,
#          0.04256196+4.69562700e-09j,  0.13155186-4.29204494e-09j,
#          0.01685802-5.28339150e-09j,  0.05071626-1.65451191e-08j,
#         -0.00808234-3.15107584e-09j,  0.08247952-1.84335001e-08j,
#         -0.0952028 -1.93413925e-08j, -0.28301677-8.88544065e-08j,
#          0.04388838+9.16790412e-08j, -0.45495716-2.23362150e-07j,
#         -0.02845711-8.18997705e-08j,  0.28360912+1.94474865e-07j,
#          0.05584296-1.92534770e-08j,  0.17125666+7.28564800e-08j,
#          0.04938768+2.36071926e-08j,  0.14722176+8.55478248e-08j,
#         -0.02297613-5.61307907e-08j,  0.23730128+1.76238089e-07j,
#         -0.00351945-1.36561100e-08j,  0.03372671+3.01596650e-08j,
#          0.00620898-9.80023795e-09j,  0.01972878-1.57626245e-10j,
#         -0.05244485-1.43802424e-07j,  0.51965666+3.87651710e-07j,
#          0.10135432-2.20524932e-08j,  0.31236738+1.61433391e-07j,
#         -0.03854225-3.80026988e-09j, -0.11367507-1.05719259e-07j,
#          0.0173013 +7.92233692e-08j, -0.18130681-2.12470837e-07j],
#        dtype=complex64),
#  array([ 0.61780447+7.56812142e-08j, -0.17755182-3.01066621e-08j,
#         -0.2605028 -1.13276535e-07j,  0.3010684 +3.54131124e-08j,
#         -0.13740769-4.41046204e-08j,  0.24950758+4.41711165e-08j,
#         -0.3324952 -6.83203041e-08j,  0.05731077+5.45951018e-08j,
#         -0.01180397+6.56350085e-09j,  0.05834422+1.63193512e-08j,
#         -0.2964779 -1.19615947e-07j,  0.06635623+5.96891354e-08j,
#          0.2960845 +1.35491490e-07j, -0.07688287-5.63249287e-08j,
#         -0.06525895-2.84002262e-08j,  0.055952  -1.26099238e-08j,
#         -0.01938714-2.03356549e-08j,  0.04229429+2.90805371e-08j,
#         -0.09838078-7.65262556e-08j,  0.01988779+2.59349591e-08j,
#          0.13385166+1.03321362e-07j, -0.03689079-4.05900060e-08j,
#         -0.04499254-5.77893289e-08j,  0.04825864+1.75770403e-08j,
#         -0.00291709-2.10009503e-08j,  0.00186114+7.37925676e-09j,
#          0.00865401+2.06730615e-08j, -0.01242726-1.07253468e-08j,
#          0.00738273+1.15032135e-08j, -0.00880708-1.00949089e-08j,
#         -0.0155148 +1.06368221e-08j,  0.00457466+1.07866638e-09j],
#        dtype=complex64),
#  array([-8.4973276e-02-7.4810849e-08j, -1.5817843e-01-4.5953136e-08j,
#          3.2931048e-02-3.3170657e-08j, -4.0436257e-04+3.7662296e-09j,
#         -6.1865140e-02-8.6031235e-09j, -8.9226410e-02+1.2351424e-08j,
#         -2.3375273e-01-1.2111425e-07j, -4.0025881e-01-1.4937568e-07j,
#          5.6454957e-02-1.1222603e-08j,  7.2830550e-02+4.2998956e-09j,
#          1.7574583e-01+2.9197757e-08j,  2.9865840e-01+6.9714538e-08j,
#         -3.2028157e-01-1.4091016e-07j, -5.8995050e-01-2.1131636e-07j,
#          9.6774489e-02+4.9595322e-08j, -1.7331131e-02+1.2880054e-08j,
#         -2.6023604e-02+9.8238362e-10j, -3.4864023e-02-4.9373101e-09j,
#         -8.6659819e-02-2.4234859e-08j, -1.4768268e-01-4.7297341e-08j,
#          8.7827757e-02+4.6453572e-08j,  1.6154878e-01+6.7562041e-08j,
#         -2.5542062e-02-1.0750550e-08j,  5.3279093e-03-2.3600628e-09j,
#         -5.4072507e-04+2.0636284e-09j, -1.4825875e-04-1.9111253e-08j,
#         -3.5426349e-03+8.1430587e-09j, -2.1712175e-03-7.1840249e-09j,
#          3.9343148e-02-1.0239846e-08j,  5.5564649e-02-2.7795175e-09j,
#          1.4350137e-01+8.0554294e-08j,  2.4540783e-01+1.4268311e-07j],
#        dtype=complex64),
#  array([ 0.08137853+3.3587533e-08j,  0.01483236+5.0744902e-09j,
#          0.03441897-5.8386807e-10j,  0.19129845+4.3646413e-08j,
#          0.0379004 -1.6599215e-09j,  0.21015583+4.2926295e-08j,
#         -0.1442391 -6.4822807e-08j, -0.02649773+2.0051623e-09j,
#          0.02874858+6.8064443e-10j,  0.1592814 +4.3301835e-08j,
#         -0.17029619-8.6299586e-08j, -0.03125092+4.1523407e-10j,
#          0.10812746+6.5643299e-08j,  0.01976739+1.5468284e-09j,
#          0.01737576-6.7100174e-09j,  0.09671451+3.1876887e-08j,
#          0.06694672-4.2758685e-10j,  0.3709165 +8.9684768e-08j,
#         -0.39730844-2.0027228e-07j, -0.07290949+1.1996324e-09j,
#          0.25236017+1.5480222e-07j,  0.04613584+3.8740273e-09j,
#          0.04035673-1.8438165e-08j,  0.22463036+5.8171288e-08j,
#          0.15109167+9.4076071e-08j,  0.027538  +2.5082958e-09j,
#          0.06416559-2.2103496e-08j,  0.35662705+1.3246908e-07j,
#          0.07056718-1.8387276e-08j,  0.39129278+1.7813140e-07j,
#         -0.26799896-2.3769752e-07j, -0.04923357+4.9833231e-09j],
#        dtype=complex64),
#  array([ 0.01724677-8.2321687e-09j, -0.2226137 -3.5225021e-08j,
#          0.04979116+2.4039899e-08j,  0.3431791 +3.9297714e-08j,
#          0.13917156+6.2150555e-08j,  0.30337098+3.5591306e-08j,
#         -0.11492407+2.2692603e-09j, -0.41004223-6.1597149e-08j,
#          0.09103733+3.7795424e-08j,  0.16137603-1.4257669e-08j,
#         -0.08439666-2.9573464e-09j, -0.25623068-1.7564673e-08j,
#          0.04847735-2.2017019e-08j, -0.3265882 -9.6987762e-08j,
#          0.06554885+2.3001716e-08j,  0.5554024 +1.2129223e-07j,
#          0.00950466+5.8456529e-09j,  0.01675912+1.7713955e-09j,
#         -0.00883352-1.8631694e-09j, -0.02672265-6.6870851e-09j,
#          0.0051507 -2.0105730e-09j, -0.03453242-1.7254308e-08j,
#          0.00692289+4.5304631e-09j,  0.05878223+2.3360608e-08j,
#          0.00118617+1.3257062e-11j, -0.01578125-8.3642382e-10j,
#          0.00354153-4.9628368e-10j,  0.0242465 +2.2652724e-09j,
#          0.010044  +6.2335515e-09j,  0.02195259+3.7086101e-09j,
#         -0.00827955-5.7466465e-10j, -0.02961159-7.9333171e-09j],
#        dtype=complex64),
#  array([ 0.25456384+9.89970488e-08j,  0.3504529 +8.62719602e-08j,
#          0.3678624 +5.36284688e-08j, -0.15846224-3.33994024e-08j,
#         -0.2033231 -2.38557991e-08j,  0.04348088+1.76261317e-08j,
#         -0.02244875-2.95137834e-08j, -0.09463745-3.03873087e-08j,
#          0.00995045-2.41630662e-08j,  0.02709679+2.11061906e-08j,
#         -0.07726001-1.68543099e-08j, -0.06101156-2.19745182e-08j,
#         -0.16263859-1.21127727e-07j, -0.20055915-9.60823527e-08j,
#         -0.17243809-6.44430358e-08j,  0.09043322+7.13670474e-08j,
#         -0.02164181-1.17237615e-08j,  0.06689194+3.34847918e-08j,
#         -0.16933413-4.38749233e-08j, -0.14992706-3.59820334e-08j,
#         -0.29286662-1.15684941e-07j, -0.35345274-8.68213021e-08j,
#         -0.28987193-8.28151769e-08j,  0.15928079+1.23542804e-07j,
#         -0.1410613 -2.38095375e-08j, -0.18927795-1.94944523e-08j,
#         -0.19065611-5.58441862e-08j,  0.08553149+6.82166998e-08j,
#          0.08739289+6.02363883e-08j, -0.01253125-2.58062034e-08j,
#         -0.00686167+1.15294032e-08j,  0.02684594+2.66138436e-08j],
#        dtype=complex64),
#  array([ 0.03731515+2.1186592e-08j,  0.01053884+5.9050818e-09j,
#         -0.01324055-2.5561782e-09j, -0.01501834+5.2133647e-10j,
#         -0.04672432-1.0872704e-09j, -0.05981971-1.0431462e-08j,
#          0.07238681+4.8225299e-08j,  0.02286464+8.1555074e-09j,
#         -0.13190582-4.1041616e-08j, -0.18581513-7.5209478e-08j,
#          0.05711153+3.5691272e-08j,  0.02897424+1.4623637e-08j,
#         -0.22061706-1.2988977e-07j, -0.08352011-4.4394174e-08j,
#          0.2626503 +8.2029850e-08j,  0.3576957 +1.5798886e-07j,
#         -0.1256082 -4.7436188e-08j, -0.17967114-8.9217139e-08j,
#          0.03067836+3.4239111e-08j,  0.02186331+1.6430686e-08j,
#         -0.26256514-1.6887361e-07j, -0.09776984-5.7527576e-08j,
#          0.29841653+1.1880641e-07j,  0.40503496+2.1757631e-07j,
#          0.26103458+1.5664570e-07j,  0.08336475+3.9082394e-08j,
#         -0.17642333-6.1830768e-08j, -0.22728285-1.0851781e-07j,
#         -0.14133963-1.5524373e-08j, -0.17325304-5.7039397e-08j,
#          0.28589284+2.1935725e-07j,  0.08533423+2.5753057e-08j],
#        dtype=complex64),
#  array([-0.12780154-1.31024365e-08j,  0.10579082+1.67458634e-08j,
#         -0.23246768-8.04194968e-08j,  0.31704265+1.02050372e-07j,
#          0.3150646 +2.09893827e-07j, -0.464288  -2.72350263e-07j,
#          0.15564021+1.18107337e-07j, -0.19176869-1.11038474e-07j,
#         -0.13101189-6.58307968e-08j,  0.1764779 +8.43622203e-08j,
#         -0.07314128-3.67200492e-08j,  0.05654655+3.32326344e-08j,
#          0.11104007+8.72602115e-08j, -0.13280216-8.37949727e-08j,
#          0.22274184+1.86628284e-07j, -0.32625598-2.26699200e-07j,
#          0.13797385+6.94740265e-08j, -0.22681789-8.87741223e-08j,
#          0.05622659+3.85589871e-08j, -0.11684127-4.27846665e-08j,
#          0.02605553+3.63333470e-08j, -0.07949144-4.32130491e-08j,
#          0.07680915+8.11066201e-08j, -0.13659737-1.00492542e-07j,
#          0.00768287+1.18528787e-08j, -0.0483506 -1.25127979e-08j,
#          0.03529892+2.66920637e-08j, -0.0712261 -2.79768919e-08j,
#          0.12764797+1.64722550e-07j, -0.20513861-2.04367524e-07j,
#          0.0544076 +1.00760140e-07j, -0.10151736-9.68786367e-08j],
#        dtype=complex64),
#  array([-0.00339336-1.9961403e-08j,  0.19041285+3.3647439e-08j,
#          0.16317782+1.0877068e-08j,  0.02754173-2.2670122e-08j,
#          0.09694314-2.7947845e-08j,  0.10915941-1.1737930e-08j,
#         -0.08880195-1.2341883e-07j,  0.5206117 +1.7972334e-07j,
#         -0.04681523+3.2734995e-08j, -0.08737515-1.5617648e-08j,
#          0.07529907+6.3487583e-08j, -0.40361145-9.2519180e-08j,
#         -0.01716971-1.0807378e-08j, -0.02674789+2.5033914e-08j,
#         -0.10041058-3.7298573e-08j,  0.00364398+2.3902997e-08j,
#          0.03938678-4.2186393e-08j,  0.12311814+1.2323319e-08j,
#         -0.10974491-1.3846827e-07j,  0.5574029 +2.3755263e-07j,
#          0.04136455+1.8794831e-08j, -0.07082038-4.5106241e-08j,
#          0.11540635+5.1478391e-08j, -0.02731702-4.3190891e-08j,
#          0.01190814-9.1147170e-09j,  0.01618365-1.7246327e-08j,
#          0.06742615+1.1500748e-08j, -0.00285178-3.2269224e-08j,
#          0.03118423-4.2873975e-08j,  0.05907   +5.4093041e-09j,
#         -0.05096973-1.4559058e-07j,  0.2726636 +2.4585611e-07j],
#        dtype=complex64),
#  array([-0.17738311+1.1869892e-09j, -0.19418174-8.6735277e-09j,
#         -0.13891444-1.1304022e-08j, -0.24040294-7.0603186e-08j,
#         -0.17111962-8.0370501e-09j, -0.29627788-7.6901905e-08j,
#         -0.184832  -7.1752773e-09j, -0.20244664-3.0079491e-08j,
#          0.12394141+3.7558840e-09j,  0.21461442+4.8033954e-08j,
#          0.12880792-2.1980018e-09j,  0.14110307+1.3619545e-08j,
#          0.05694848-7.6898239e-09j,  0.06232116-1.4416414e-09j,
#          0.03971171-2.3913214e-09j,  0.06869825+3.1123683e-08j,
#         -0.24153762-1.6547261e-08j, -0.41826952-1.3248543e-07j,
#         -0.24435768-2.7791929e-08j, -0.26770937-6.1618792e-08j,
#         -0.01687974+1.5774690e-08j, -0.0184114 +1.7599437e-08j,
#          0.00273221+6.7639352e-09j,  0.00481373+4.2042650e-08j,
#         -0.09013937+5.8534275e-09j, -0.09865627-5.0863189e-09j,
#         -0.06593491+8.1894624e-10j, -0.11408092-5.2648023e-08j,
#         -0.15270741+1.0832560e-08j, -0.2644191 -7.1644635e-08j,
#         -0.16011783+1.7106634e-08j, -0.17539592-1.5797482e-08j],
#        dtype=complex64),
#  array([ 0.04260349+3.30903411e-08j, -0.06554715-2.87621518e-08j,
#         -0.02770401+2.23211103e-08j,  0.01468398-3.24187752e-08j,
#          0.0258222 +1.45536383e-08j, -0.01465433-3.59265258e-08j,
#         -0.03024904+4.38170318e-08j,  0.04716866-3.40596813e-08j,
#         -0.16974147-7.28435054e-08j,  0.09589396+2.70838232e-08j,
#          0.20310143+1.15138278e-07j, -0.31633297-1.45473805e-07j,
#         -0.2810644 -1.93657385e-07j,  0.4326928 +2.34175644e-07j,
#          0.18535167+1.11965655e-07j, -0.0986483 -4.04191169e-08j,
#          0.04685287+4.12778789e-09j, -0.03448185-3.42688402e-08j,
#          0.02226894+6.73680347e-08j, -0.02798754-5.74551997e-08j,
#          0.05897743+3.36811574e-08j, -0.08595546-1.09909655e-08j,
#          0.0084119 +4.50479796e-08j, -0.0118149 -5.29726414e-08j,
#          0.23282765+1.97504463e-07j, -0.3262901 -1.77120810e-07j,
#          0.1606814 +1.02132631e-07j, -0.13425975-1.44219598e-07j,
#          0.2152379 +1.91863705e-07j, -0.17482077-1.74128573e-07j,
#          0.26276246+2.37667010e-07j, -0.3647739 -2.42099958e-07j],
#        dtype=complex64),
#  array([ 0.0148885 +5.87406124e-09j,  0.12189488+1.21845316e-08j,
#          0.03363359-5.52404966e-09j,  0.00108294+5.12757392e-09j,
#         -0.55710995-1.30967791e-07j,  0.23845834+4.48012614e-08j,
#         -0.01133898-2.85126376e-08j,  0.48637283+1.89158044e-07j,
#         -0.2701357 -7.58132188e-08j,  0.11232402+2.77195227e-08j,
#         -0.00852763-1.42728345e-08j,  0.2035749 +8.97275712e-08j,
#          0.0076393 +8.20397883e-09j, -0.0609926 -4.92252497e-08j,
#          0.13061792+6.33198454e-08j, -0.05048012-3.21790701e-08j,
#         -0.26349694-1.00891896e-07j,  0.11283438+3.74694800e-08j,
#         -0.00531674-1.44205110e-08j,  0.23053324+1.21691926e-07j,
#          0.00703542-1.39714462e-10j,  0.0594878 +1.25231132e-08j,
#          0.01416112+7.86454546e-09j,  0.00129153-3.36247963e-09j,
#         -0.00494137+2.63667244e-09j, -0.09980053-5.97283574e-08j,
#          0.04329342+3.65732618e-08j, -0.02487599-1.43727839e-08j,
#          0.19245042+1.34478697e-07j, -0.08396002-6.10962445e-08j,
#          0.00246168+3.51833478e-08j, -0.18351234-1.41391254e-07j],
#        dtype=complex64),
#  array([ 0.0143964 -2.23353114e-09j,  0.02100447+4.46212045e-09j,
#         -0.08629681-6.20681035e-08j, -0.04925751-3.30147678e-08j,
#          0.29053164+1.25316589e-07j,  0.20415026+5.69701548e-08j,
#          0.10139012+1.07710907e-08j, -0.08175658-3.55212890e-08j,
#         -0.34216   -1.29579050e-07j, -0.21224533-6.32947064e-08j,
#         -0.00918387-1.87086400e-08j,  0.08816354+3.04117513e-08j,
#          0.3066648 +7.42425499e-08j, -0.12133145-8.29918250e-08j,
#          0.38615513+1.92499115e-07j,  0.3152969 +7.47059659e-08j,
#         -0.04323693-6.88428203e-09j, -0.04644702+9.51301038e-10j,
#         -0.07792029-5.30750244e-09j,  0.01679652+7.35180539e-09j,
#         -0.18661721-4.93128525e-08j,  0.05193641+2.92686195e-08j,
#         -0.14934571-5.80255737e-08j, -0.13933186-1.93930152e-08j,
#         -0.25881597-1.21275349e-07j,  0.08885394+5.65588714e-08j,
#         -0.27292442-2.22992171e-07j, -0.23360136-1.16673625e-07j,
#          0.13322505+1.67697195e-07j,  0.07049992+8.42154080e-08j,
#         -0.04390715-3.04706660e-08j, -0.03082917-4.22973727e-08j],
#        dtype=complex64),
#  array([-0.07096515+2.61520938e-09j,  0.2813672 -2.12934426e-09j,
#         -0.22828344-1.06800968e-08j, -0.07758339+1.78009696e-09j,
#         -0.03731376-1.45329668e-08j,  0.250791  +6.54587566e-08j,
#          0.08373857+2.15157208e-08j,  0.5155357 +1.16918912e-07j,
#         -0.14148358-1.96904733e-08j, -0.18517247-5.32054045e-08j,
#         -0.09358799-3.45248665e-08j, -0.06992791-5.01784214e-08j,
#          0.06992333-9.55466284e-09j,  0.32013124+7.27051273e-08j,
#          0.00877308-4.38599628e-08j,  0.18868184+5.62899665e-08j,
#         -0.06113097-4.12891277e-09j,  0.04521347+2.53129038e-08j,
#          0.00487491+4.82482232e-09j,  0.19294815+4.43123582e-08j,
#         -0.00715311-2.08752571e-08j,  0.22062464+4.04903062e-08j,
#         -0.09258138-4.87165224e-08j,  0.02830358+1.04168656e-08j,
#         -0.01427133-1.08345271e-08j,  0.30623797+1.00222046e-07j,
#         -0.13624647-6.49123990e-08j,  0.03130443+3.76902278e-08j,
#         -0.08199862-6.33622292e-08j,  0.07631972+3.93276736e-08j,
#          0.01221002-2.65849209e-08j,  0.28674293+1.13474101e-07j],
#        dtype=complex64)]

# %% [markdown]
# # Sample Circuit Qubit Density Matrices

# %%
density_matrices = quple.sample_density_matrices(cq, samples=200)
density_matrices
# Out:
# [array([[ 0.05089248+0.0000000e+00j, -0.0794462 -2.5384770e-09j,
#          -0.03763456+3.4360603e-10j, ..., -0.03418334+2.0987015e-08j,
#          -0.01556178+2.9844007e-09j,  0.02573353-6.8142114e-10j],
#         [-0.0794462 +2.5384770e-09j,  0.12402026+0.0000000e+00j,
#           0.05874979-2.4135698e-09j, ...,  0.05336223-3.4467018e-08j,
#           0.02429286-5.4350360e-09j, -0.04017157+2.3473068e-09j],
#         [-0.03763456-3.4360603e-10j,  0.05874979+2.4135698e-09j,
#           0.02783044+0.0000000e+00j, ...,  0.02527829-1.5288929e-08j,
#           0.0115078 -2.1018725e-09j, -0.01902973+3.3016301e-10j],
#         ...,
#         [-0.03418334-2.0987015e-08j,  0.05336223+3.4467018e-08j,
#           0.02527829+1.5288929e-08j, ...,  0.02296018+0.0000000e+00j,
#           0.01045249+4.4128021e-09j, -0.01728463-1.0154284e-08j],
#         [-0.01556178-2.9844007e-09j,  0.02429286+5.4350360e-09j,
#           0.0115078 +2.1018725e-09j, ...,  0.01045249-4.4128021e-09j,
#           0.00475844+0.0000000e+00j, -0.00786873-1.3006842e-09j],
#         [ 0.02573353+6.8142114e-10j, -0.04017157-2.3473068e-09j,
#          -0.01902973-3.3016301e-10j, ..., -0.01728463+1.0154284e-08j,
#          -0.00786873+1.3006842e-09j,  0.01301203+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 3.63426609e-03+0.0000000e+00j, -1.86075307e-02-5.6394489e-09j,
#           2.21563280e-02+6.9425798e-09j, ...,
#           1.30959344e-03-1.1400005e-09j, -1.07059117e-04-8.8852736e-10j,
#          -2.65835994e-03+1.4930057e-09j],
#         [-1.86075307e-02+5.6394489e-09j,  9.52710137e-02+0.0000000e+00j,
#          -1.13440946e-01-1.1652412e-09j, ...,
#          -6.70515001e-03+7.8689837e-09j,  5.48145268e-04+4.3831534e-09j,
#           1.36108669e-02-1.1769317e-08j],
#         [ 2.21563280e-02-6.9425798e-09j, -1.13440946e-01+1.1652412e-09j,
#           1.35076210e-01+0.0000000e+00j, ...,
#           7.98394531e-03-9.4517523e-09j, -6.52686635e-04-5.2123972e-09j,
#          -1.62067097e-02+1.4180414e-08j],
#         ...,
#         [ 1.30959344e-03+1.1400005e-09j, -6.70515001e-03-7.8689837e-09j,
#           7.98394531e-03+9.4517523e-09j, ...,
#           4.71906795e-04+0.0000000e+00j, -3.85783278e-05-3.5375972e-10j,
#          -9.57929413e-04-2.9587843e-10j],
#         [-1.07059117e-04+8.8852736e-10j,  5.48145268e-04-4.3831534e-09j,
#          -6.52686635e-04+5.2123972e-09j, ...,
#          -3.85783278e-05+3.5375972e-10j,  3.15377406e-06+0.0000000e+00j,
#           7.83106225e-05-6.9391320e-10j],
#         [-2.65835994e-03-1.4930057e-09j,  1.36108669e-02+1.1769317e-08j,
#          -1.62067097e-02-1.4180414e-08j, ...,
#          -9.57929413e-04+2.9587843e-10j,  7.83106225e-05+6.9391320e-10j,
#           1.94451283e-03+0.0000000e+00j]], dtype=complex64),
#  array([[ 4.0668034e-05+0.0000000e+00j, -1.2894848e-03-4.7383266e-09j,
#          -1.8966908e-03-6.4327002e-09j, ...,
#           7.9483354e-05+2.9766856e-11j,  2.5065741e-04+6.5086231e-10j,
#          -9.9153389e-05-3.2449918e-10j],
#         [-1.2894848e-03+4.7383266e-09j,  4.0886436e-02+0.0000000e+00j,
#           6.0139466e-02-1.7022519e-08j, ...,
#          -2.5202243e-03+8.3169542e-09j, -7.9477383e-03+8.5674099e-09j,
#           3.1439136e-03-1.2635094e-09j],
#         [-1.8966908e-03+6.4327002e-09j,  6.0139466e-02+1.7022519e-08j,
#           8.8458568e-02+0.0000000e+00j, ...,
#          -3.7069740e-03+1.1184068e-08j, -1.1690252e-02+9.2927870e-09j,
#           4.6243523e-03-5.4955751e-10j],
#         ...,
#         [ 7.9483354e-05-2.9766856e-11j, -2.5202243e-03-8.3169542e-09j,
#          -3.7069740e-03-1.1184068e-08j, ...,
#           1.5534568e-04+0.0000000e+00j,  4.8989558e-04+1.0886052e-09j,
#          -1.9378964e-04-5.6164007e-10j],
#         [ 2.5065741e-04-6.5086231e-10j, -7.9477383e-03-8.5674099e-09j,
#          -1.1690252e-02-9.2927870e-09j, ...,
#           4.8989558e-04-1.0886052e-09j,  1.5449268e-03+0.0000000e+00j,
#          -6.1113189e-04-4.1317261e-10j],
#         [-9.9153389e-05+3.2449918e-10j,  3.1439136e-03+1.2635094e-09j,
#           4.6243523e-03+5.4955751e-10j, ...,
#          -1.9378964e-04+5.6164007e-10j, -6.1113189e-04+4.1317261e-10j,
#           2.4174749e-04+0.0000000e+00j]], dtype=complex64),
#  array([[0.06686267+0.0000000e+00j, 0.08038421+1.4354347e-09j,
#          0.03282166+2.1245603e-09j, ..., 0.01010806-3.8049048e-09j,
#          0.00955721+9.8850528e-10j, 0.02577733-8.8365288e-09j],
#         [0.08038421-1.4354347e-09j, 0.09664019+0.0000000e+00j,
#          0.03945913+1.8495785e-09j, ..., 0.01215219-4.7913686e-09j,
#          0.01148995+9.8323127e-10j, 0.03099024-1.1176924e-08j],
#         [0.03282166-2.1245603e-09j, 0.03945913-1.8495785e-09j,
#          0.01611155+0.0000000e+00j, ..., 0.00496186-2.1889410e-09j,
#          0.00469146+1.8155895e-10j, 0.01265362-5.1567635e-09j],
#         ...,
#         [0.01010806+3.8049048e-09j, 0.01215219+4.7913686e-09j,
#          0.00496186+2.1889410e-09j, ..., 0.0015281 +0.0000000e+00j,
#          0.00144482+6.9330358e-10j, 0.00389692+1.3101709e-10j],
#         [0.00955721-9.8850528e-10j, 0.01148995-9.8323127e-10j,
#          0.00469146-1.8155895e-10j, ..., 0.00144482-6.9330358e-10j,
#          0.00136609+0.0000000e+00j, 0.00368456-1.6441695e-09j],
#         [0.02577733+8.8365288e-09j, 0.03099024+1.1176924e-08j,
#          0.01265362+5.1567635e-09j, ..., 0.00389692-1.3101709e-10j,
#          0.00368456+1.6441695e-09j, 0.00993785+0.0000000e+00j]],
#        dtype=complex64),
#  array([[1.2808028e-05+0.0000000e+00j, 3.0610344e-04+4.8832494e-10j,
#          1.4388049e-04+2.1112215e-10j, ..., 6.4420752e-04+1.1166539e-09j,
#          4.0216637e-05+1.8134641e-10j, 6.9256499e-04+7.1215744e-10j],
#         [3.0610344e-04-4.8832494e-10j, 7.3156711e-03+0.0000000e+00j,
#          3.4386490e-03-4.3997495e-10j, ..., 1.5396137e-02+2.1259332e-09j,
#          9.6115115e-04+2.8007416e-09j, 1.6551847e-02-9.3849666e-09j],
#         [1.4388049e-04-2.1112215e-10j, 3.4386490e-03+4.3997495e-10j,
#          1.6162983e-03+0.0000000e+00j, ..., 7.2367811e-03+1.9252169e-09j,
#          4.5177829e-04+1.3742621e-09j, 7.7800099e-03-3.4158458e-09j],
#         ...,
#         [6.4420752e-04-1.1166539e-09j, 1.5396137e-02-2.1259332e-09j,
#          7.2367811e-03-1.9252169e-09j, ..., 3.2401815e-02+0.0000000e+00j,
#          2.0227828e-03+5.6149676e-09j, 3.4834057e-02-2.4561022e-08j],
#         [4.0216637e-05-1.8134641e-10j, 9.6115115e-04-2.8007416e-09j,
#          4.5177829e-04-1.3742621e-09j, ..., 2.0227828e-03-5.6149676e-09j,
#          1.2627844e-04+0.0000000e+00j, 2.1746231e-03-7.5697528e-09j],
#         [6.9256499e-04-7.1215744e-10j, 1.6551847e-02+9.3849666e-09j,
#          7.7800099e-03+3.4158458e-09j, ..., 3.4834057e-02+2.4561022e-08j,
#          2.1746231e-03+7.5697528e-09j, 3.7448876e-02+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 0.0263339 +0.00000000e+00j, -0.01588072-2.40107667e-09j,
#          -0.01074835+1.03899978e-09j, ...,  0.00760655-1.18179440e-08j,
#          -0.05949854+3.18155386e-08j,  0.04465453-1.73022876e-08j],
#         [-0.01588072+2.40107667e-09j,  0.0095769 +0.00000000e+00j,
#           0.00648182-1.60658609e-09j, ..., -0.00458715+7.82038967e-09j,
#           0.03588073-2.46114027e-08j, -0.02692902+1.45057024e-08j],
#         [-0.01074835-1.03899978e-09j,  0.00648182+1.60658609e-09j,
#           0.00438701+0.00000000e+00j, ..., -0.00310466+4.52345450e-09j,
#           0.02428471-1.06382112e-08j, -0.01822603+5.30020117e-09j],
#         ...,
#         [ 0.00760655+1.18179440e-08j, -0.00458715-7.82038967e-09j,
#          -0.00310466-4.52345450e-09j, ...,  0.00219715+0.00000000e+00j,
#          -0.01718615-1.75114234e-08j,  0.01289846+1.50419837e-08j],
#         [-0.05949854-3.18155386e-08j,  0.03588073+2.46114027e-08j,
#           0.02428471+1.06382112e-08j, ..., -0.01718615+1.75114234e-08j,
#           0.1344304 +0.00000000e+00j, -0.10089199-1.48571715e-08j],
#         [ 0.04465453+1.73022876e-08j, -0.02692902-1.45057024e-08j,
#          -0.01822603-5.30020117e-09j, ...,  0.01289846-1.50419837e-08j,
#          -0.10089199+1.48571715e-08j,  0.07572092+0.00000000e+00j]],
#        dtype=complex64),
#  array([[ 3.8546441e-05+0.0000000e+00j, -1.5693321e-04+3.7566894e-10j,
#          -6.9281721e-04+1.8965463e-09j, ...,
#           3.0039335e-04-8.6856383e-10j, -1.1912469e-03+3.2090599e-09j,
#           3.8845644e-03-9.7641282e-09j],
#         [-1.5693321e-04-3.7566894e-10j,  6.3891843e-04+0.0000000e+00j,
#           2.8206501e-03-9.6925168e-10j, ...,
#          -1.2229844e-03+6.0856598e-10j,  4.8498954e-03-1.4552217e-09j,
#          -1.5815135e-02+1.8939721e-09j],
#         [-6.9281721e-04-1.8965463e-09j,  2.8206501e-03+9.6925168e-10j,
#           1.2452399e-02+0.0000000e+00j, ...,
#          -5.3991415e-03+8.3136120e-10j,  2.1410961e-02+9.3297992e-10j,
#          -6.9819495e-02-1.5630494e-08j],
#         ...,
#         [ 3.0039335e-04+8.6856383e-10j, -1.2229844e-03-6.0856598e-10j,
#          -5.3991415e-03-8.3136120e-10j, ...,
#           2.3409729e-03+0.0000000e+00j, -9.2834169e-03-1.8339872e-09j,
#           3.0272506e-02+1.1438480e-08j],
#         [-1.1912469e-03-3.2090599e-09j,  4.8498954e-03+1.4552217e-09j,
#           2.1410961e-02-9.3297992e-10j, ...,
#          -9.2834169e-03+1.8339872e-09j,  3.6814533e-02+0.0000000e+00j,
#          -1.2004936e-01-2.1644333e-08j],
#         [ 3.8845644e-03+9.7641282e-09j, -1.5815135e-02-1.8939721e-09j,
#          -6.9819495e-02+1.5630494e-08j, ...,
#           3.0272506e-02-1.1438480e-08j, -1.2004936e-01+2.1644333e-08j,
#           3.9147168e-01+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.00676161+0.00000000e+00j,  0.00794592+1.16059262e-09j,
#           0.0253163 +3.02218850e-09j, ...,  0.00560527-7.30991445e-09j,
#          -0.01931945+1.10534515e-08j,  0.01530756-9.06615494e-09j],
#         [ 0.00794592-1.16059262e-09j,  0.00933768+0.00000000e+00j,
#           0.02975054-7.93868082e-10j, ...,  0.00658706-9.55238644e-09j,
#          -0.02270331+1.63055773e-08j,  0.01798874-1.32815821e-08j],
#         [ 0.0253163 -3.02218850e-09j,  0.02975054+7.93868082e-10j,
#           0.09478739+0.00000000e+00j, ...,  0.02098685-2.98745846e-08j,
#          -0.07233442+5.00205815e-08j,  0.05731343-4.07867304e-08j],
#         ...,
#         [ 0.00560527+7.30991445e-09j,  0.00658706+9.55238644e-09j,
#           0.02098685+2.98745846e-08j, ...,  0.00464669+0.00000000e+00j,
#          -0.01601554-1.17229364e-08j,  0.01268975+9.03316355e-09j],
#         [-0.01931945-1.10534515e-08j, -0.02270331-1.63055773e-08j,
#          -0.07233442-5.00205815e-08j, ..., -0.01601554+1.17229364e-08j,
#           0.05520006+0.00000000e+00j, -0.04373719+8.80220341e-10j],
#         [ 0.01530756+9.06615494e-09j,  0.01798874+1.32815821e-08j,
#           0.05731343+4.07867304e-08j, ...,  0.01268975-9.03316355e-09j,
#          -0.04373719-8.80220341e-10j,  0.03465471+0.00000000e+00j]],
#        dtype=complex64),
#  array([[ 3.7873390e-01+0.00000000e+00j, -7.9670258e-02-7.22831572e-09j,
#           3.3221323e-02-9.76854775e-09j, ...,
#           9.9235633e-03-1.87517948e-08j, -1.8068338e-02+2.44232332e-08j,
#           4.0885801e-03-1.18930465e-08j],
#         [-7.9670258e-02+7.22831572e-09j,  1.6759392e-02+0.00000000e+00j,
#          -6.9884197e-03+2.68895106e-09j, ...,
#          -2.0875153e-03+4.13401358e-09j,  3.8008457e-03-5.48250112e-09j,
#          -8.6007151e-04+2.57984722e-09j],
#         [ 3.3221323e-02+9.76854775e-09j, -6.9884197e-03-2.68895106e-09j,
#           2.9140681e-03+0.00000000e+00j, ...,
#           8.7046315e-04-1.38889256e-09j, -1.5848967e-03+1.67629766e-09j,
#           3.5863716e-04-9.37764755e-10j],
#         ...,
#         [ 9.9235633e-03+1.87517948e-08j, -2.0875153e-03-4.13401358e-09j,
#           8.7046315e-04+1.38889256e-09j, ...,
#           2.6001662e-04+0.00000000e+00j, -4.7342552e-04-2.54659738e-10j,
#           1.0712874e-04-1.09187964e-10j],
#         [-1.8068338e-02-2.44232332e-08j,  3.8008457e-03+5.48250112e-09j,
#          -1.5848967e-03-1.67629766e-09j, ...,
#          -4.7342552e-04+2.54659738e-10j,  8.6199003e-04+0.00000000e+00j,
#          -1.9505476e-04+3.03725739e-10j],
#         [ 4.0885801e-03+1.18930465e-08j, -8.6007151e-04-2.57984722e-09j,
#           3.5863716e-04+9.37764755e-10j, ...,
#           1.0712874e-04+1.09187964e-10j, -1.9505476e-04-3.03725739e-10j,
#           4.4137822e-05+0.00000000e+00j]], dtype=complex64),
#  array([[ 2.1325307e-02+0.0000000e+00j,  7.3409816e-03-4.2290810e-11j,
#           2.6875041e-02-1.0039273e-09j, ...,
#          -9.9170813e-03+6.9871073e-09j, -3.4668334e-03+4.2631465e-10j,
#          -1.1877818e-03-1.5220247e-09j],
#         [ 7.3409816e-03+4.2290810e-11j,  2.5270451e-03+0.0000000e+00j,
#           9.2514111e-03-2.9229327e-10j, ...,
#          -3.4138365e-03+2.3855613e-09j, -1.1934160e-03+1.3987854e-10j,
#          -4.0887966e-04-5.2629434e-10j],
#         [ 2.6875041e-02+1.0039273e-09j,  9.2514111e-03+2.9229327e-10j,
#           3.3869047e-02+0.0000000e+00j, ...,
#          -1.2497919e-02+8.3385796e-09j, -4.3690479e-03+3.7405207e-10j,
#          -1.4968921e-03-1.9740360e-09j],
#         ...,
#         [-9.9170813e-03-6.9871073e-09j, -3.4138365e-03-2.3855613e-09j,
#          -1.2497919e-02-8.3385796e-09j, ...,
#           4.6118209e-03+0.0000000e+00j,  1.6122097e-03+9.3763430e-10j,
#           5.5236381e-04+1.0969690e-09j],
#         [-3.4668334e-03-4.2631465e-10j, -1.1934160e-03-1.3987854e-10j,
#          -4.3690479e-03-3.7405207e-10j, ...,
#           1.6122097e-03-9.3763430e-10j,  5.6359958e-04+0.0000000e+00j,
#           1.9309646e-04+2.7117897e-10j],
#         [-1.1877818e-03+1.5220247e-09j, -4.0887966e-04+5.2629434e-10j,
#          -1.4968921e-03+1.9740360e-09j, ...,
#           5.5236381e-04-1.0969690e-09j,  1.9309646e-04-2.7117897e-10j,
#           6.6157336e-05+0.0000000e+00j]], dtype=complex64),
#  array([[ 2.3389422e-05+0.00000000e+00j, -1.3263096e-03-5.83054272e-10j,
#           9.9484599e-04+3.05583392e-10j, ...,
#          -2.2958216e-06-1.61205684e-11j, -1.2986313e-05+1.13247196e-10j,
#           6.2810129e-04+9.80427406e-11j],
#         [-1.3263096e-03+5.83054272e-10j,  7.5209089e-02+0.00000000e+00j,
#          -5.6413267e-02+7.47136930e-09j, ...,
#           1.3018578e-04+8.56894833e-10j,  7.3639577e-04-6.74546685e-09j,
#          -3.5616819e-02+1.00978195e-08j],
#         [ 9.9484599e-04-3.05583392e-10j, -5.6413267e-02-7.47136930e-09j,
#           4.2314786e-02+0.00000000e+00j, ...,
#          -9.7650503e-05-6.55677457e-10j, -5.5235997e-04+4.98652408e-09j,
#           2.6715668e-02-4.03601064e-09j],
#         ...,
#         [-2.2958216e-06+1.61205684e-11j,  1.3018578e-04-8.56894833e-10j,
#          -9.7650503e-05+6.55677457e-10j, ...,
#           2.2534959e-07+0.00000000e+00j,  1.2746898e-06-2.00664242e-11j,
#          -6.1652165e-05+4.23279412e-10j],
#         [-1.2986313e-05-1.13247196e-10j,  7.3639577e-04+6.74546685e-09j,
#          -5.5235997e-04-4.98652408e-09j, ...,
#           1.2746898e-06+2.00664242e-11j,  7.2102812e-06+0.00000000e+00j,
#          -3.4873540e-04-3.09558401e-09j],
#         [ 6.2810129e-04-9.80427406e-11j, -3.5616819e-02-1.00978195e-08j,
#           2.6715668e-02+4.03601064e-09j, ...,
#          -6.1652165e-05-4.23279412e-10j, -3.4873540e-04+3.09558401e-09j,
#           1.6867079e-02+0.00000000e+00j]], dtype=complex64),
#  array([[ 7.91997300e-04+0.0000000e+00j,  1.29719987e-03-2.9525468e-10j,
#           7.33186607e-04+4.1134662e-11j, ...,
#           2.23155832e-03-1.9619619e-09j, -1.63411532e-04+5.0523941e-10j,
#           1.04125880e-04-9.4785964e-11j],
#         [ 1.29719987e-03+2.9525468e-10j,  2.12466298e-03+0.0000000e+00j,
#           1.20087480e-03+3.4070402e-10j, ...,
#           3.65503388e-03-2.3815465e-09j, -2.67649157e-04+7.6660417e-10j,
#           1.70546133e-04-1.1643055e-10j],
#         [ 7.33186607e-04-4.1134662e-11j,  1.20087480e-03-3.4070402e-10j,
#           6.78743003e-04+0.0000000e+00j, ...,
#           2.06585135e-03-1.9321764e-09j, -1.51277214e-04+4.7620952e-10j,
#           9.63938946e-05-9.3155601e-11j],
#         ...,
#         [ 2.23155832e-03+1.9619619e-09j,  3.65503388e-03+2.3815465e-09j,
#           2.06585135e-03+1.9321764e-09j, ...,
#           6.28771400e-03+0.0000000e+00j, -4.60433832e-04+1.0187711e-09j,
#           2.93388584e-04-9.1280594e-12j],
#         [-1.63411532e-04-5.0523941e-10j, -2.67649157e-04-7.6660417e-10j,
#          -1.51277214e-04-4.7620952e-10j, ...,
#          -4.60433832e-04-1.0187711e-09j,  3.37164383e-05+0.0000000e+00j,
#          -2.14841257e-05-4.6868058e-11j],
#         [ 1.04125880e-04+9.4785964e-11j,  1.70546133e-04+1.1643055e-10j,
#           9.63938946e-05+9.3155601e-11j, ...,
#           2.93388584e-04+9.1280594e-12j, -2.14841257e-05+4.6868058e-11j,
#           1.36896915e-05+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.00085641+0.0000000e+00j, -0.00100298+1.5885190e-09j,
#           0.00089527-1.7735859e-09j, ..., -0.00243207-9.5212682e-10j,
#          -0.00255195+8.6289487e-10j,  0.00509355-1.9701158e-09j],
#         [-0.00100298-1.5885190e-09j,  0.00117463+0.0000000e+00j,
#          -0.00104848+4.1652859e-10j, ...,  0.00284829+5.6261982e-09j,
#           0.00298868+3.7229075e-09j, -0.00596525-7.1404807e-09j],
#         [ 0.00089527+1.7735859e-09j, -0.00104848-4.1652859e-10j,
#           0.00093588+0.0000000e+00j, ..., -0.00254241-6.0320069e-09j,
#          -0.00266772-4.3828980e-09j,  0.00532463+8.4889535e-09j],
#         ...,
#         [-0.00243207+9.5212682e-10j,  0.00284829-5.6261982e-09j,
#          -0.00254241+6.0320069e-09j, ...,  0.00690667+0.0000000e+00j,
#           0.0072471 -5.2876277e-09j, -0.01446481+1.1257596e-08j],
#         [-0.00255195-8.6289487e-10j,  0.00298868-3.7229075e-09j,
#          -0.00266772+4.3828980e-09j, ...,  0.0072471 +5.2876277e-09j,
#           0.00760431+0.0000000e+00j, -0.01517777+7.3847151e-10j],
#         [ 0.00509355+1.9701158e-09j, -0.00596525+7.1404807e-09j,
#           0.00532463-8.4889535e-09j, ..., -0.01446481-1.1257596e-08j,
#          -0.01517777-7.3847151e-10j,  0.030294  +0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 0.00097611+0.0000000e+00j, -0.00115376-1.3337573e-09j,
#          -0.00165022-4.3417125e-10j, ..., -0.00538233-6.5164283e-09j,
#           0.00525106+3.9026351e-09j,  0.00426877+2.6552851e-09j],
#         [-0.00115376+1.3337573e-09j,  0.00136373+0.0000000e+00j,
#           0.00195055-1.7416670e-09j, ...,  0.00636188+3.4797543e-10j,
#          -0.00620672+2.5621469e-09j, -0.00504566+2.6943061e-09j],
#         [-0.00165022+4.3417125e-10j,  0.00195055+1.7416670e-09j,
#           0.00278987+0.0000000e+00j, ...,  0.00909938+8.6226546e-09j,
#          -0.00887746-4.2621555e-09j, -0.0072168 -2.5903009e-09j],
#         ...,
#         [-0.00538233+6.5164283e-09j,  0.00636188-3.4797543e-10j,
#           0.00909938-8.6226546e-09j, ...,  0.0296784 +0.0000000e+00j,
#          -0.02895459+1.3536244e-08j, -0.02353819+1.3856513e-08j],
#         [ 0.00525106-3.9026351e-09j, -0.00620672-2.5621469e-09j,
#          -0.00887746+4.2621555e-09j, ..., -0.02895459-1.3536244e-08j,
#           0.02824843+0.0000000e+00j,  0.02296413-2.7828628e-09j],
#         [ 0.00426877-2.6552851e-09j, -0.00504566-2.6943061e-09j,
#          -0.0072168 +2.5903009e-09j, ..., -0.02353819-1.3856513e-08j,
#           0.02296413+2.7828628e-09j,  0.01866834+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 1.6607697e-06+0.0000000e+00j,  1.0590884e-05-1.4877466e-13j,
#          -1.1423911e-05+3.4949394e-12j, ...,
#          -3.0919331e-05+1.1295146e-11j,  1.1085026e-04-6.0214389e-11j,
#           6.9708400e-04-8.9509150e-10j],
#         [ 1.0590884e-05+1.4877466e-13j,  6.7539055e-05+0.0000000e+00j,
#          -7.2851348e-05+2.1264181e-11j, ...,
#          -1.9717547e-04+6.9260403e-11j,  7.0690247e-04-3.7406264e-10j,
#           4.4453698e-03-5.6456364e-09j],
#         [-1.1423911e-05-3.4949394e-12j, -7.2851348e-05-2.1264181e-11j,
#           7.8581485e-05+0.0000000e+00j, ...,
#           2.1268433e-04-1.2628820e-11j, -7.6250400e-04+1.8092147e-10j,
#          -4.7950214e-03+4.6901021e-09j],
#         ...,
#         [-3.0919331e-05-1.1295146e-11j, -1.9717547e-04-6.9260403e-11j,
#           2.1268433e-04+1.2628820e-11j, ...,
#           5.7563977e-04+0.0000000e+00j, -2.0637515e-03+3.6713022e-10j,
#          -1.2977942e-02+1.1923365e-08j],
#         [ 1.1085026e-04+6.0214389e-11j,  7.0690247e-04+3.7406264e-10j,
#          -7.6250400e-04-1.8092147e-10j, ...,
#          -2.0637515e-03-3.6713022e-10j,  7.3988470e-03+0.0000000e+00j,
#           4.6527792e-02-3.4469942e-08j],
#         [ 6.9708400e-04+8.9509150e-10j,  4.4453698e-03+5.6456364e-09j,
#          -4.7950214e-03-4.6901021e-09j, ...,
#          -1.2977942e-02-1.1923365e-08j,  4.6527792e-02+3.4469942e-08j,
#           2.9259092e-01+0.0000000e+00j]], dtype=complex64),
#  array([[ 1.3867667e-02+0.0000000e+00j, -2.7976930e-04-1.6439930e-10j,
#          -1.3024666e-03+6.9244416e-10j, ...,
#           3.6010488e-03-7.8498452e-10j, -1.5471070e-02-1.1393931e-08j,
#           3.8264261e-04-2.3775151e-09j],
#         [-2.7976930e-04+1.6439930e-10j,  5.6441254e-06+0.0000000e+00j,
#           2.6276241e-05-2.9410079e-11j, ...,
#          -7.2648334e-05+5.8526392e-11j,  3.1211667e-04+4.6456179e-11j,
#          -7.7195145e-06+5.2500677e-11j],
#         [-1.3024666e-03-6.9244416e-10j,  2.6276241e-05+2.9410079e-11j,
#           1.2232910e-04+0.0000000e+00j, ...,
#          -3.3821451e-04-1.0608192e-10j,  1.4530600e-03+1.8426362e-09j,
#          -3.5938217e-05+2.0419264e-10j],
#         ...,
#         [ 3.6010488e-03+7.8498452e-10j, -7.2648334e-05-5.8526392e-11j,
#          -3.3821451e-04+1.0608192e-10j, ...,
#           9.3509263e-04+0.0000000e+00j, -4.0174080e-03-3.8344337e-09j,
#           9.9361685e-05-5.9571514e-10j],
#         [-1.5471070e-02+1.1393931e-08j,  3.1211667e-04-4.6456179e-11j,
#           1.4530600e-03-1.8426362e-09j, ...,
#          -4.0174080e-03+3.8344337e-09j,  1.7259860e-02+0.0000000e+00j,
#          -4.2688439e-04+2.9667935e-09j],
#         [ 3.8264261e-04+2.3775151e-09j, -7.7195145e-06-5.2500677e-11j,
#          -3.5938217e-05-2.0419264e-10j, ...,
#           9.9361685e-05+5.9571514e-10j, -4.2688439e-04-2.9667935e-09j,
#           1.0558039e-05+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.0122506 +0.0000000e+00j,  0.03564898+8.0342675e-09j,
#           0.01079953+3.4261982e-09j, ..., -0.00205489-3.0696676e-10j,
#          -0.00363713-2.4289288e-09j, -0.02053545+1.4176025e-09j],
#         [ 0.03564898-8.0342675e-09j,  0.1037377 +0.0000000e+00j,
#           0.0314264 +2.8875409e-09j, ..., -0.00597968+4.5438422e-10j,
#          -0.01058398-4.6827995e-09j, -0.0597577 +1.7592878e-08j],
#         [ 0.01079953-3.4261982e-09j,  0.0314264 -2.8875409e-09j,
#           0.00952034+0.0000000e+00j, ..., -0.00181149+3.0409614e-10j,
#          -0.00320632-1.1240066e-09j, -0.01810305+6.9929595e-09j],
#         ...,
#         [-0.00205489+3.0696676e-10j, -0.00597968-4.5438422e-10j,
#          -0.00181149-3.0409614e-10j, ...,  0.00034468+0.0000000e+00j,
#           0.00061008+3.1628658e-10j,  0.00344457-7.5234807e-10j],
#         [-0.00363713+2.4289288e-09j, -0.01058398+4.6827995e-09j,
#          -0.00320632+1.1240066e-09j, ...,  0.00061008-3.1628658e-10j,
#           0.00107984+0.0000000e+00j,  0.00609686-4.4924446e-09j],
#         [-0.02053545-1.4176025e-09j, -0.0597577 -1.7592878e-08j,
#          -0.01810305-6.9929595e-09j, ...,  0.00344457+7.5234807e-10j,
#           0.00609686+4.4924446e-09j,  0.03442319+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 0.00296337+0.0000000e+00j, -0.00385575+9.3028008e-10j,
#          -0.01031886-1.2425543e-09j, ...,  0.00206904-1.3299278e-10j,
#           0.00104982-2.1039753e-11j, -0.00127094+1.3167528e-10j],
#         [-0.00385575-9.3028008e-10j,  0.00501687+0.0000000e+00j,
#           0.01342626+4.8560986e-09j, ..., -0.0026921 -4.7648374e-10j,
#          -0.00136597-3.0219188e-10j,  0.00165367+2.2765434e-10j],
#         [-0.01031886+1.2425543e-09j,  0.01342626-4.8560986e-09j,
#           0.0359317 +0.0000000e+00j, ..., -0.00720467+1.3306564e-09j,
#          -0.00365563+5.1345933e-10j,  0.00442559-9.9142294e-10j],
#         ...,
#         [ 0.00206904+1.3299278e-10j, -0.0026921 +4.7648374e-10j,
#          -0.00720467-1.3306564e-09j, ...,  0.00144461+0.0000000e+00j,
#           0.00073299+3.2424896e-11j, -0.00088738+3.4897807e-11j],
#         [ 0.00104982+2.1039753e-11j, -0.00136597+3.0219188e-10j,
#          -0.00365563-5.1345933e-10j, ...,  0.00073299-3.2424896e-11j,
#           0.00037192+0.0000000e+00j, -0.00045025+3.7624598e-11j],
#         [-0.00127094-1.3167528e-10j,  0.00165367-2.2765434e-10j,
#           0.00442559+9.9142294e-10j, ..., -0.00088738-3.4897807e-11j,
#          -0.00045025-3.7624598e-11j,  0.00054509+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 6.5413506e-06+0.0000000e+00j, -7.0346054e-05+3.7056771e-11j,
#           8.6038788e-05-8.7937213e-11j, ...,
#          -1.0371043e-04+2.3398822e-10j,  1.0445460e-04-3.2103731e-10j,
#          -4.1338892e-04+8.8383845e-10j],
#         [-7.0346054e-05-3.7056771e-11j,  7.5650541e-04+0.0000000e+00j,
#          -9.2526595e-04+4.5827175e-10j, ...,
#           1.1153078e-03-1.9288025e-09j, -1.1233106e-03+2.8607174e-09j,
#           4.4456078e-03-7.1629991e-09j],
#         [ 8.6038788e-05+8.7937213e-11j, -9.2526595e-04-4.5827175e-10j,
#           1.1316735e-03+0.0000000e+00j, ...,
#          -1.3641097e-03+1.6834528e-09j,  1.3738978e-03-2.8184108e-09j,
#          -5.4373299e-03+6.0678786e-09j],
#         ...,
#         [-1.0371043e-04-2.3398822e-10j,  1.1153078e-03+1.9288025e-09j,
#          -1.3641097e-03-1.6834528e-09j, ...,
#           1.6442862e-03+0.0000000e+00j, -1.6560848e-03+1.3535082e-09j,
#           6.5541114e-03+7.7428464e-10j],
#         [ 1.0445460e-04+3.2103731e-10j, -1.1233106e-03-2.8607174e-09j,
#           1.3738978e-03+2.8184108e-09j, ...,
#          -1.6560848e-03-1.3535082e-09j,  1.6679680e-03+0.0000000e+00j,
#          -6.6011404e-03-6.1749121e-09j],
#         [-4.1338892e-04-8.8383845e-10j,  4.4456078e-03+7.1629991e-09j,
#          -5.4373299e-03-6.0678786e-09j, ...,
#           6.5541114e-03-7.7428464e-10j, -6.6011404e-03+6.1749121e-09j,
#           2.6124634e-02+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.00159977+0.0000000e+00j, -0.00214048-1.3476997e-12j,
#          -0.00071746-4.1896869e-10j, ...,  0.00077067-2.0810313e-09j,
#          -0.00577233+8.3048244e-09j,  0.00728047-9.4138883e-09j],
#         [-0.00214048+1.3476997e-12j,  0.00286393+0.0000000e+00j,
#           0.00095995+5.5997040e-10j, ..., -0.00103114+2.7850433e-09j,
#           0.00772331-1.1116613e-08j, -0.00974117+1.2601798e-08j],
#         [-0.00071746+4.1896869e-10j,  0.00095995-5.5997040e-10j,
#           0.00032176+0.0000000e+00j, ..., -0.00034562+1.1351208e-09j,
#           0.00258874-5.2362292e-09j, -0.0032651 +6.1285856e-09j],
#         ...,
#         [ 0.00077067+2.0810313e-09j, -0.00103114-2.7850433e-09j,
#          -0.00034562-1.1351208e-09j, ...,  0.00037126+0.0000000e+00j,
#          -0.00278073-3.5080876e-09j,  0.00350725+4.9356403e-09j],
#         [-0.00577233-8.3048244e-09j,  0.00772331+1.1116613e-08j,
#           0.00258874+5.2362292e-09j, ..., -0.00278073+3.5080876e-09j,
#           0.02082781+0.0000000e+00j, -0.0262695 -3.8273731e-09j],
#         [ 0.00728047+9.4138883e-09j, -0.00974117-1.2601798e-08j,
#          -0.0032651 -6.1285856e-09j, ...,  0.00350725-4.9356403e-09j,
#          -0.0262695 +3.8273731e-09j,  0.03313293+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 0.00068548+0.0000000e+00j, -0.00571712+3.9549040e-09j,
#          -0.0108076 +5.7383134e-09j, ...,  0.00042288+2.1557844e-10j,
#           0.00042116-8.3546386e-10j, -0.00229879+1.2223017e-09j],
#         [-0.00571712-3.9549040e-09j,  0.04768283+0.0000000e+00j,
#           0.09013928+1.4495612e-08j, ..., -0.003527  -4.2378527e-09j,
#          -0.00351265+4.5381414e-09j,  0.01917271+3.0685721e-09j],
#         [-0.0108076 -5.7383134e-09j,  0.09013928-1.4495612e-08j,
#           0.17039864+0.0000000e+00j, ..., -0.00666741-6.9389978e-09j,
#          -0.00664028+9.6467163e-09j,  0.03624394-2.7709390e-11j],
#         ...,
#         [ 0.00042288-2.1557844e-10j, -0.003527  +4.2378527e-09j,
#          -0.00666741+6.9389978e-09j, ...,  0.00026088+0.0000000e+00j,
#           0.00025982-6.4786593e-10j, -0.00141816+1.4770152e-09j],
#         [ 0.00042116+8.3546386e-10j, -0.00351265-4.5381414e-09j,
#          -0.00664028-9.6467163e-09j, ...,  0.00025982+6.4786593e-10j,
#           0.00025877+0.0000000e+00j, -0.00141239-2.0507855e-09j],
#         [-0.00229879-1.2223017e-09j,  0.01917271-3.0685721e-09j,
#           0.03624394+2.7709390e-11j, ..., -0.00141816-1.4770152e-09j,
#          -0.00141239+2.0507855e-09j,  0.00770912+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 4.0063700e-03+0.0000000e+00j,  9.8451730e-03+8.4619889e-10j,
#           1.1542303e-02+1.0912987e-09j, ...,
#           1.7210701e-03-1.5020002e-10j,  8.3122002e-05+1.6793039e-10j,
#          -8.0781372e-04-5.5969673e-10j],
#         [ 9.8451730e-03-8.4619889e-10j,  2.4193328e-02+0.0000000e+00j,
#           2.8363822e-02+2.4384672e-10j, ...,
#           4.2293230e-03-7.3261147e-10j,  2.0426232e-04+3.9511228e-10j,
#          -1.9851050e-03-1.2047664e-09j],
#         [ 1.1542303e-02-1.0912987e-09j,  2.8363822e-02-2.4384672e-10j,
#           3.3253234e-02+0.0000000e+00j, ...,
#           4.9583819e-03-9.0152824e-10j,  2.3947346e-04+4.6116372e-10j,
#          -2.3273013e-03-1.3924384e-09j],
#         ...,
#         [ 1.7210701e-03+1.5020002e-10j,  4.2293230e-03+7.3261147e-10j,
#           4.9583819e-03+9.0152824e-10j, ...,
#           7.3934317e-04+0.0000000e+00j,  3.5707832e-05+7.5256384e-11j,
#          -3.4702336e-04-2.7072161e-10j],
#         [ 8.3122002e-05-1.6793039e-10j,  2.0426232e-04-3.9511228e-10j,
#           2.3947346e-04-4.6116372e-10j, ...,
#           3.5707832e-05-7.5256384e-11j,  1.7245703e-06+0.0000000e+00j,
#          -1.6760083e-05+2.2247908e-11j],
#         [-8.0781372e-04+5.5969673e-10j, -1.9851050e-03+1.2047664e-09j,
#          -2.3273013e-03+1.3924384e-09j, ...,
#          -3.4702336e-04+2.7072161e-10j, -1.6760083e-05-2.2247908e-11j,
#           1.6288136e-04+0.0000000e+00j]], dtype=complex64),
#  array([[ 7.3609728e-04+0.0000000e+00j, -4.5334739e-03+2.9109537e-09j,
#          -1.3756893e-04+5.8589733e-10j, ...,
#          -5.7174391e-03+5.9697980e-09j,  4.2551439e-03-5.9359837e-09j,
#          -1.1213086e-02+1.2545025e-08j],
#         [-4.5334739e-03-2.9109537e-09j,  2.7920745e-02+0.0000000e+00j,
#           8.4725919e-04-3.0643958e-09j, ...,
#           3.5212550e-02-1.4156718e-08j, -2.6206568e-02+1.9731225e-08j,
#           6.9059119e-02-3.2919246e-08j],
#         [-1.3756893e-04-5.8589733e-10j,  8.4725919e-04+3.0643958e-09j,
#           2.5710207e-05+0.0000000e+00j, ...,
#           1.0685300e-03+3.4351080e-09j, -7.9524220e-04-2.2775122e-09j,
#           2.0956092e-03+6.5805317e-09j],
#         ...,
#         [-5.7174391e-03-5.9697980e-09j,  3.5212550e-02+1.4156718e-08j,
#           1.0685300e-03-3.4351080e-09j, ...,
#           4.4408686e-02+0.0000000e+00j, -3.3050694e-02+1.1596672e-08j,
#           8.7094650e-02-6.5012635e-09j],
#         [ 4.2551439e-03+5.9359837e-09j, -2.6206568e-02-1.9731225e-08j,
#          -7.9524220e-04+2.2775122e-09j, ...,
#          -3.3050694e-02-1.1596672e-08j,  2.4597630e-02+0.0000000e+00j,
#          -6.4819276e-02-1.7904984e-08j],
#         [-1.1213086e-02-1.2545025e-08j,  6.9059119e-02+3.2919246e-08j,
#           2.0956092e-03-6.5805317e-09j, ...,
#           8.7094650e-02+6.5012635e-09j, -6.4819276e-02+1.7904984e-08j,
#           1.7081068e-01+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.03323128+0.0000000e+00j,  0.02321297+5.1148636e-09j,
#           0.00600524-4.4085828e-09j, ..., -0.02251104+3.1860345e-09j,
#          -0.07716265+3.3884049e-08j, -0.05588131+9.1056931e-09j],
#         [ 0.02321297-5.1148636e-09j,  0.0162149 +0.0000000e+00j,
#           0.00419482-4.0038253e-09j, ..., -0.01572458+5.6903668e-09j,
#          -0.05390023+3.5545593e-08j, -0.03903463+1.4961667e-08j],
#         [ 0.00600524+4.4085828e-09j,  0.00419482+4.0038253e-09j,
#           0.00108521+0.0000000e+00j, ..., -0.00406798-2.4106463e-09j,
#          -0.01394409-4.1134776e-09j, -0.01009833-5.7679239e-09j],
#         ...,
#         [-0.02251104-3.1860345e-09j, -0.01572458-5.6903668e-09j,
#          -0.00406798+2.4106463e-09j, ...,  0.01524909+0.0000000e+00j,
#           0.05227037-1.5555290e-08j,  0.03785428-8.1064755e-10j],
#         [-0.07716265-3.3884049e-08j, -0.05390023-3.5545593e-08j,
#          -0.01394409+4.1134776e-09j, ...,  0.05227037+1.5555290e-08j,
#           0.17917076+0.0000000e+00j,  0.12975574+3.5835676e-08j],
#         [-0.05588131-9.1056931e-09j, -0.03903463-1.4961667e-08j,
#          -0.01009833+5.7679239e-09j, ...,  0.03785428+8.1064755e-10j,
#           0.12975574-3.5835676e-08j,  0.0939693 +0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 1.6233781e-02+0.00000000e+00j,  5.7529770e-03-5.18137422e-10j,
#           3.9105313e-03-1.04857734e-10j, ...,
#          -5.4990891e-03-1.26962139e-08j, -4.6433035e-02+8.59554916e-09j,
#          -1.0725807e-03-1.54228843e-08j],
#         [ 5.7529770e-03+5.18137422e-10j,  2.0387578e-03+0.00000000e+00j,
#           1.3858260e-03+8.76535511e-11j, ...,
#          -1.9487840e-03-4.67483874e-09j, -1.6455080e-02+1.56410263e-09j,
#          -3.8010444e-04-5.49984325e-09j],
#         [ 3.9105313e-03+1.04857734e-10j,  1.3858260e-03-8.76535511e-11j,
#           9.4200205e-04+0.00000000e+00j, ...,
#          -1.3246674e-03-3.09389203e-09j, -1.1185184e-02+1.77064718e-09j,
#          -2.5837237e-04-3.72212394e-09j],
#         ...,
#         [-5.4990891e-03+1.26962139e-08j, -1.9487840e-03+4.67483874e-09j,
#          -1.3246674e-03+3.09389203e-09j, ...,
#           1.8627810e-03+0.00000000e+00j,  1.5728891e-02-3.92263146e-08j,
#           3.6332980e-04+4.38555281e-09j],
#         [-4.6433035e-02-8.59554916e-09j, -1.6455080e-02-1.56410263e-09j,
#          -1.1185184e-02-1.77064718e-09j, ...,
#           1.5728891e-02+3.92263146e-08j,  1.3281113e-01+0.00000000e+00j,
#           3.0678730e-03+4.46815669e-08j],
#         [-1.0725807e-03+1.54228843e-08j, -3.8010444e-04+5.49984325e-09j,
#          -2.5837237e-04+3.72212394e-09j, ...,
#           3.6332980e-04-4.38555281e-09j,  3.0678730e-03-4.46815669e-08j,
#           7.0866379e-05+0.00000000e+00j]], dtype=complex64),
#  array([[ 0.11164805+0.00000000e+00j,  0.05966474+2.20959677e-08j,
#           0.0704129 +2.29737616e-08j, ..., -0.06906358+8.11992606e-09j,
#          -0.04800107+1.13658665e-08j, -0.00682201-3.31142083e-08j],
#         [ 0.05966474-2.20959677e-08j,  0.03188485+0.00000000e+00j,
#           0.03762867-1.65804614e-09j, ..., -0.03690759+1.80074817e-08j,
#          -0.02565178+1.55736846e-08j, -0.00364569-1.63461138e-08j],
#         [ 0.0704129 -2.29737616e-08j,  0.03762867+1.65804614e-09j,
#           0.04440719+0.00000000e+00j, ..., -0.04355622+1.93321590e-08j,
#          -0.03027276+1.70452488e-08j, -0.00430243-1.94803231e-08j],
#         ...,
#         [-0.06906358-8.11992606e-09j, -0.03690759-1.80074817e-08j,
#          -0.04355622-1.93321590e-08j, ...,  0.04272155+0.00000000e+00j,
#           0.02969264-3.53971430e-09j,  0.00421998+2.09800373e-08j],
#         [-0.04800107-1.13658665e-08j, -0.02565178-1.55736846e-08j,
#          -0.03027276-1.70452488e-08j, ...,  0.02969264+3.53971430e-09j,
#           0.0206372 +0.00000000e+00j,  0.002933  +1.49313450e-08j],
#         [-0.00682201+3.31142083e-08j, -0.00364569+1.63461138e-08j,
#          -0.00430243+1.94803231e-08j, ...,  0.00421998-2.09800373e-08j,
#           0.002933  -1.49313450e-08j,  0.00041684+0.00000000e+00j]],
#        dtype=complex64),
#  array([[ 4.2142456e-05+0.0000000e+00j,  5.5300385e-05+5.7624780e-11j,
#          -3.4251899e-04+4.4147519e-11j, ...,
#           1.9718583e-03-2.2437621e-09j,  7.3878153e-04-9.2278329e-10j,
#          -3.4913857e-04+2.4531338e-10j],
#         [ 5.5300385e-05-5.7624780e-11j,  7.2566545e-05+0.0000000e+00j,
#          -4.4946198e-04+5.2628535e-10j, ...,
#           2.5875217e-03-5.6406013e-09j,  9.6944760e-04-2.2210949e-09j,
#          -4.5814837e-04+7.9931173e-10j],
#         [-3.4251899e-04-4.4147519e-11j, -4.4946198e-04-5.2628535e-10j,
#           2.7838734e-03+0.0000000e+00j, ...,
#          -1.6026568e-02+1.6170828e-08j, -6.0045552e-03+6.7261250e-09j,
#           2.8376749e-03-1.6280703e-09j],
#         ...,
#         [ 1.9718583e-03+2.2437621e-09j,  2.5875217e-03+5.6406013e-09j,
#          -1.6026568e-02-1.6170828e-08j, ...,
#           9.2263848e-02+0.0000000e+00j,  3.4567814e-02-3.8428709e-09j,
#          -1.6336299e-02-7.1106601e-09j],
#         [ 7.3878153e-04+9.2278329e-10j,  9.6944760e-04+2.2210949e-09j,
#          -6.0045552e-03-6.7261250e-09j, ...,
#           3.4567814e-02+3.8428709e-09j,  1.2951267e-02+0.0000000e+00j,
#          -6.1206007e-03-3.3445191e-09j],
#         [-3.4913857e-04-2.4531338e-10j, -4.5814837e-04-7.9931173e-10j,
#           2.8376749e-03+1.6280703e-09j, ...,
#          -1.6336299e-02+7.1106601e-09j, -6.1206007e-03+3.3445191e-09j,
#           2.8925166e-03+0.0000000e+00j]], dtype=complex64),
#  array([[ 3.4100347e-04+0.0000000e+00j, -9.6675125e-05+3.6458822e-11j,
#           7.0702581e-04-2.9857375e-10j, ...,
#          -8.6296042e-03+2.7298594e-09j,  3.3910819e-03-1.5992985e-09j,
#          -1.4984125e-03+1.7919621e-09j],
#         [-9.6675125e-05-3.6458822e-11j,  2.7407581e-05+0.0000000e+00j,
#          -2.0044316e-04+9.0536606e-12j, ...,
#           2.4465092e-03+1.4872481e-10j, -9.6137816e-04+9.0842278e-11j,
#           4.2480274e-04-3.4782000e-10j],
#         [ 7.0702581e-04+2.9857375e-10j, -2.0044316e-04-9.0536606e-12j,
#           1.4659251e-03+0.0000000e+00j, ...,
#          -1.7892351e-02-1.8958524e-09j,  7.0309625e-03-3.4679193e-10j,
#          -3.1067610e-03+2.4034272e-09j],
#         ...,
#         [-8.6296042e-03-2.7298594e-09j,  2.4465092e-03-1.4872481e-10j,
#          -1.7892351e-02+1.8958524e-09j, ...,
#           2.1838512e-01+0.0000000e+00j, -8.5816428e-02+1.3325781e-08j,
#           3.7919577e-02-3.3352947e-08j],
#         [ 3.3910819e-03+1.5992985e-09j, -9.6137816e-04-9.0842278e-11j,
#           7.0309625e-03+3.4679193e-10j, ...,
#          -8.5816428e-02-1.3325781e-08j,  3.3722349e-02+0.0000000e+00j,
#          -1.4900845e-02+1.0792508e-08j],
#         [-1.4984125e-03-1.7919621e-09j,  4.2480274e-04+3.4782000e-10j,
#          -3.1067610e-03-2.4034272e-09j, ...,
#           3.7919577e-02+3.3352947e-08j, -1.4900845e-02-1.0792508e-08j,
#           6.5842140e-03+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.15455818+0.00000000e+00j, -0.14894243+4.95985297e-09j,
#           0.05887406+5.20244381e-09j, ...,  0.03465425-4.80581530e-09j,
#           0.02534837-1.28771855e-08j, -0.04806579+3.45182265e-08j],
#         [-0.14894243-4.95985297e-09j,  0.14353073+0.00000000e+00j,
#          -0.05673491-6.90271662e-09j, ..., -0.03339512+3.51912632e-09j,
#          -0.02442735+1.15958603e-08j,  0.04631936-3.17215729e-08j],
#         [ 0.05887406-5.20244381e-09j, -0.05673491+6.90271662e-09j,
#           0.02242621+0.00000000e+00j, ...,  0.01320044-2.99708924e-09j,
#           0.00965566-5.75838532e-09j, -0.01830914+1.47665267e-08j],
#         ...,
#         [ 0.03465425+4.80581530e-09j, -0.03339512-3.51912632e-09j,
#           0.01320044+2.99708924e-09j, ...,  0.00777   +0.00000000e+00j,
#           0.00568348-2.09907780e-09j, -0.01077707+6.24494900e-09j],
#         [ 0.02534837+1.28771855e-08j, -0.02442735-1.15958603e-08j,
#           0.00965566+5.75838532e-09j, ...,  0.00568348+2.09907780e-09j,
#           0.00415727+0.00000000e+00j, -0.00788305+1.65651803e-09j],
#         [-0.04806579-3.45182265e-08j,  0.04631936+3.17215729e-08j,
#          -0.01830914-1.47665267e-08j, ..., -0.01077707-6.24494900e-09j,
#          -0.00788305-1.65651803e-09j,  0.0149479 +0.00000000e+00j]],
#        dtype=complex64),
#  array([[ 6.6400997e-02+0.0000000e+00j, -9.4476640e-03-3.3939775e-09j,
#           1.4620082e-02-1.7567562e-08j, ...,
#          -5.7259202e-03+2.6966254e-09j, -5.5717276e-03+5.6231992e-09j,
#          -1.3832917e-04-3.9965666e-09j],
#         [-9.4476640e-03+3.3939775e-09j,  1.3442324e-03+0.0000000e+00j,
#          -2.0801742e-03+3.2468288e-09j, ...,
#           8.1469526e-04-6.7635220e-10j,  7.9275644e-04-1.0848696e-09j,
#           1.9681745e-05+5.6156890e-10j],
#         [ 1.4620082e-02+1.7567562e-08j, -2.0801742e-03-3.2468288e-09j,
#           3.2190303e-03+0.0000000e+00j, ...,
#          -1.2607255e-03-9.2115443e-10j, -1.2267756e-03-2.3599089e-10j,
#          -3.0457131e-05-9.1655616e-10j],
#         ...,
#         [-5.7259202e-03-2.6966254e-09j,  8.1469526e-04+6.7635220e-10j,
#          -1.2607255e-03+9.2115443e-10j, ...,
#           4.9376010e-04+0.0000000e+00j,  4.8046373e-04-2.5862759e-10j,
#           1.1928462e-05+3.5025147e-10j],
#         [-5.5717276e-03-5.6231992e-09j,  7.9275644e-04+1.0848696e-09j,
#          -1.2267756e-03+2.3599089e-10j, ...,
#           4.8046373e-04+2.5862759e-10j,  4.6752539e-04+0.0000000e+00j,
#           1.1607242e-05+3.4706762e-10j],
#         [-1.3832917e-04+3.9965666e-09j,  1.9681745e-05-5.6156890e-10j,
#          -3.0457131e-05+9.1655616e-10j, ...,
#           1.1928462e-05-3.5025147e-10j,  1.1607242e-05-3.4706762e-10j,
#           2.8817274e-07+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.05606118+0.00000000e+00j,  0.01676149-1.00500808e-09j,
#          -0.05916352-2.48703813e-09j, ..., -0.02842999+1.13757261e-08j,
#           0.01564031-3.40508954e-09j,  0.02289229-9.28741883e-09j],
#         [ 0.01676149+1.00500808e-09j,  0.00501144+0.00000000e+00j,
#          -0.01768904-1.80421189e-09j, ..., -0.00850016+2.89151436e-09j,
#           0.00467623-7.37688910e-10j,  0.00684446-2.36641462e-09j],
#         [-0.05916352+2.48703813e-09j, -0.01768904+1.80421189e-09j,
#           0.06243753+0.00000000e+00j, ...,  0.03000327-1.32664795e-08j,
#          -0.01650582+4.28737179e-09j, -0.02415911+1.08169385e-08j],
#         ...,
#         [-0.02842999-1.13757261e-08j, -0.00850016-2.89151436e-09j,
#           0.03000327+1.32664795e-08j, ...,  0.01441755+0.00000000e+00j,
#          -0.00793159-1.44687018e-09j, -0.01160924+6.46593890e-11j],
#         [ 0.01564031+3.40508954e-09j,  0.00467623+7.37688910e-10j,
#          -0.01650582-4.28737179e-09j, ..., -0.00793159+1.44687018e-09j,
#           0.00436344+0.00000000e+00j,  0.00638664-1.20061405e-09j],
#         [ 0.02289229+9.28741883e-09j,  0.00684446+2.36641462e-09j,
#          -0.02415911-1.08169385e-08j, ..., -0.01160924-6.46593890e-11j,
#           0.00638664+1.20061405e-09j,  0.00934794+0.00000000e+00j]],
#        dtype=complex64),
#  array([[ 3.9565554e-03+0.0000000e+00j, -1.7892737e-02-1.6397617e-09j,
#           1.0865150e-02+3.4778727e-09j, ...,
#          -1.5375046e-04-4.6174503e-10j, -7.0402474e-04+3.0716971e-10j,
#           1.5992115e-03+5.6967525e-10j],
#         [-1.7892737e-02+1.6397617e-09j,  8.0916360e-02+0.0000000e+00j,
#          -4.9135488e-02-1.1225018e-08j, ...,
#           6.9530599e-04+2.0244300e-09j,  3.1838124e-03-1.6808914e-09j,
#          -7.2321170e-03-1.9134636e-09j],
#         [ 1.0865150e-02-3.4778727e-09j, -4.9135488e-02+1.1225018e-08j,
#           2.9836934e-02+0.0000000e+00j, ...,
#          -4.2221620e-04-1.1328553e-09j, -1.9333318e-03+1.4623714e-09j,
#           4.3916162e-03+1.5866147e-10j],
#         ...,
#         [-1.5375046e-04+4.6174503e-10j,  6.9530599e-04-2.0244300e-09j,
#          -4.2221620e-04+1.1328553e-09j, ...,
#           5.9746931e-06+0.0000000e+00j,  2.7358174e-05-9.4098875e-11j,
#          -6.2144842e-05+1.6449665e-10j],
#         [-7.0402474e-04-3.0716971e-10j,  3.1838124e-03+1.6808914e-09j,
#          -1.9333318e-03-1.4623714e-09j, ...,
#           2.7358174e-05+9.4098875e-11j,  1.2527332e-04+0.0000000e+00j,
#          -2.8456177e-04-2.2552314e-10j],
#         [ 1.5992115e-03-5.6967525e-10j, -7.2321170e-03+1.9134636e-09j,
#           4.3916162e-03-1.5866147e-10j, ...,
#          -6.2144842e-05-1.6449665e-10j, -2.8456177e-04+2.2552314e-10j,
#           6.4638990e-04+0.0000000e+00j]], dtype=complex64),
#  array([[2.0047803e-03+0.00000000e+00j, 7.1104779e-04-5.29190414e-10j,
#          2.0020212e-04+2.54295085e-10j, ...,
#          1.9266027e-04+2.50182897e-09j, 3.2965015e-04+2.62265876e-09j,
#          1.4099690e-04-1.05791466e-10j],
#         [7.1104779e-04+5.29190414e-10j, 2.5219168e-04+0.00000000e+00j,
#          7.1006914e-05+1.43038581e-10j, ...,
#          6.8331996e-05+9.38194411e-10j, 1.1691904e-04+1.01721032e-09j,
#          5.0008231e-05-3.03568802e-13j],
#         [2.0020212e-04-2.54295085e-10j, 7.1006914e-05-1.43038581e-10j,
#          1.9992658e-05+0.00000000e+00j, ...,
#          1.9239511e-05+2.25400698e-10j, 3.2919645e-05+2.20090640e-10j,
#          1.4080284e-05-2.84492464e-11j],
#         ...,
#         [1.9266027e-04-2.50182897e-09j, 6.8331996e-05-9.38194411e-10j,
#          1.9239511e-05-2.25400698e-10j, ...,
#          1.8514735e-05+0.00000000e+00j, 3.1679519e-05-1.59342206e-10j,
#          1.3549862e-05-1.86121077e-10j],
#         [3.2965015e-04-2.62265876e-09j, 1.1691904e-04-1.01721032e-09j,
#          3.2919645e-05-2.20090640e-10j, ...,
#          3.1679519e-05+1.59342206e-10j, 5.4205047e-05+0.00000000e+00j,
#          2.3184406e-05-2.01847997e-10j],
#         [1.4099690e-04+1.05791466e-10j, 5.0008231e-05+3.03568802e-13j,
#          1.4080284e-05+2.84492464e-11j, ...,
#          1.3549862e-05+1.86121077e-10j, 2.3184406e-05+2.01847997e-10j,
#          9.9163590e-06+0.00000000e+00j]], dtype=complex64),
#  array([[ 2.8647503e-03+0.0000000e+00j, -2.6929822e-05-9.1099253e-11j,
#           2.3962189e-04-3.0167957e-09j, ...,
#           8.0156093e-03-7.2532647e-11j,  3.2348022e-02-9.5304573e-09j,
#          -4.0510847e-04+7.0715309e-09j],
#         [-2.6929822e-05+9.1099253e-11j,  2.5315131e-07+0.0000000e+00j,
#          -2.2525435e-06+3.5979102e-11j, ...,
#          -7.5349999e-05+2.5557878e-10j, -3.0408462e-04+1.1182595e-09j,
#           3.8081848e-06-7.9357750e-11j],
#         [ 2.3962189e-04+3.0167957e-09j, -2.2525435e-06-3.5979102e-11j,
#           2.0043160e-05+0.0000000e+00j, ...,
#           6.7046523e-04+8.4349683e-09j,  2.7057487e-03+3.3267707e-08j,
#          -3.3885277e-05+1.6488835e-10j],
#         ...,
#         [ 8.0156093e-03+7.2532647e-11j, -7.5349999e-05-2.5557878e-10j,
#           6.7046523e-04-8.4349683e-09j, ...,
#           2.2427782e-02+0.0000000e+00j,  9.0510204e-02-2.5847324e-08j,
#          -1.1334989e-03+1.9775980e-08j],
#         [ 3.2348022e-02+9.5304573e-09j, -3.0408462e-04-1.1182595e-09j,
#           2.7057487e-03-3.3267707e-08j, ...,
#           9.0510204e-02+2.5847324e-08j,  3.6526555e-01+0.0000000e+00j,
#          -4.5743803e-03+7.8502190e-08j],
#         [-4.0510847e-04-7.0715309e-09j,  3.8081848e-06+7.9357750e-11j,
#          -3.3885277e-05-1.6488835e-10j, ...,
#          -1.1334989e-03-1.9775980e-08j, -4.5743803e-03-7.8502190e-08j,
#           5.7286972e-05+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.00240595+0.00000000e+00j, -0.00130574-5.75341885e-10j,
#           0.00368361+7.22130689e-12j, ..., -0.01418713+9.13732912e-09j,
#           0.00135431-7.00231340e-09j, -0.02270472+1.68025434e-08j],
#         [-0.00130574+5.75341885e-10j,  0.00070864+0.00000000e+00j,
#          -0.00199914+8.76952067e-10j, ...,  0.00769953-8.35154346e-09j,
#          -0.000735  +4.12410017e-09j,  0.01232213-1.45483785e-08j],
#         [ 0.00368361-7.22130689e-12j, -0.00199914-8.76952067e-10j,
#           0.00563975+0.00000000e+00j, ..., -0.02172106+1.40321941e-08j,
#           0.0020735 -1.07248823e-08j, -0.03476182+2.57935024e-08j],
#         ...,
#         [-0.01418713-9.13732912e-09j,  0.00769953+8.35154346e-09j,
#          -0.02172106-1.40321941e-08j, ...,  0.08365694+0.00000000e+00j,
#          -0.00798594+3.61469716e-08j,  0.13388236-1.28512170e-08j],
#         [ 0.00135431+7.00231340e-09j, -0.000735  -4.12410017e-09j,
#           0.0020735 +1.07248823e-08j, ..., -0.00798594-3.61469716e-08j,
#           0.00076234+0.00000000e+00j, -0.01278048-5.66218823e-08j],
#         [-0.02270472-1.68025434e-08j,  0.01232213+1.45483785e-08j,
#          -0.03476182-2.57935024e-08j, ...,  0.13388236+1.28512170e-08j,
#          -0.01278048+5.66218823e-08j,  0.21426183+0.00000000e+00j]],
#        dtype=complex64),
#  array([[ 0.00165384+0.0000000e+00j,  0.00119168+6.6928352e-11j,
#          -0.01096513-1.4322925e-09j, ...,  0.00171919-3.1709764e-09j,
#           0.00296568-2.2803757e-09j,  0.00066558-2.2743107e-09j],
#         [ 0.00119168-6.6928352e-11j,  0.00085867+0.0000000e+00j,
#          -0.00790098-5.8830429e-10j, ...,  0.00123877-2.3544380e-09j,
#           0.00213694-1.7631541e-09j,  0.00047958-1.6657022e-09j],
#         [-0.01096513+1.4322925e-09j, -0.00790098+5.8830429e-10j,
#           0.07269994+0.0000000e+00j, ..., -0.01139843+2.2512795e-08j,
#          -0.01966276+1.7687526e-08j, -0.00441284+1.5655335e-08j],
#         ...,
#         [ 0.00171919+3.1709764e-09j,  0.00123877+2.3544380e-09j,
#          -0.01139843-2.2512795e-08j, ...,  0.00178713+0.0000000e+00j,
#           0.00308287+3.3157328e-09j,  0.00069188-1.0880451e-09j],
#         [ 0.00296568+2.2803757e-09j,  0.00213694+1.7631541e-09j,
#          -0.01966276-1.7687526e-08j, ...,  0.00308287-3.3157328e-09j,
#           0.00531808+0.0000000e+00j,  0.00119352-3.1605907e-09j],
# ...
#           0.00164768+1.8435520e-09j, ...,  0.00108889+0.0000000e+00j,
#           0.00442358+1.6562192e-09j, -0.00242292-1.8756954e-09j],
#         [ 0.00211704+1.0003269e-09j,  0.00165133+1.5648367e-09j,
#           0.00669365+4.9832156e-09j, ...,  0.00442358-1.6562192e-09j,
#           0.01797064+0.0000000e+00j, -0.00984304-3.9346437e-09j],
#         [-0.00115957-8.4384624e-11j, -0.00090448-4.9555082e-10j,
#          -0.00366631-1.2638877e-09j, ..., -0.00242292+1.8756954e-09j,
#          -0.00984304+3.9346437e-09j,  0.00539132+0.0000000e+00j]],
#        dtype=complex64),
#  array([[0.01659279+0.0000000e+00j, 0.0226644 +4.4783910e-09j,
#          0.01561248+5.0010236e-09j, ..., 0.01016991-3.0740761e-09j,
#          0.00785713-2.6036553e-09j, 0.01075391-3.8752912e-09j],
#         [0.0226644 -4.4783910e-09j, 0.03095772+0.0000000e+00j,
#          0.02132537+2.6171854e-09j, ..., 0.01389127-6.9437949e-09j,
#          0.01073219-5.6770171e-09j, 0.01468896-8.1958103e-09j],
#         [0.01561248-5.0010236e-09j, 0.02132537-2.6171854e-09j,
#          0.01469008+0.0000000e+00j, ..., 0.00956907-5.9576424e-09j,
#          0.00739292-4.8179465e-09j, 0.01011856-6.8875368e-09j],
#         ...,
#         [0.01016991+3.0740761e-09j, 0.01389127+6.9437949e-09j,
#          0.00956907+5.9576424e-09j, ..., 0.00623326+0.0000000e+00j,
#          0.00481572-1.4015367e-10j, 0.00659119-3.8287906e-10j],
#         [0.00785713+2.6036553e-09j, 0.01073219+5.6770171e-09j,
#          0.00739292+4.8179465e-09j, ..., 0.00481572+1.4015367e-10j,
#          0.00372056+0.0000000e+00j, 0.00509226-1.4760504e-10j],
#         [0.01075391+3.8752912e-09j, 0.01468896+8.1958103e-09j,
#          0.01011856+6.8875368e-09j, ..., 0.00659119+3.8287906e-10j,
#          0.00509226+1.4760504e-10j, 0.00696969+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 0.02969854+0.0000000e+00j, -0.00954124-2.2338080e-09j,
#          -0.03138037+3.3101966e-09j, ..., -0.00539909-2.1541227e-09j,
#          -0.01456219+2.2798186e-09j,  0.00985994-1.6715345e-09j],
#         [-0.00954124+2.2338080e-09j,  0.00306531+0.0000000e+00j,
#           0.01008156-3.4237746e-09j, ...,  0.00173456+2.8595598e-10j,
#           0.00467839-1.8277473e-09j, -0.0031677 +1.2786395e-09j],
#         [-0.03138037-3.3101966e-09j,  0.01008156+3.4237746e-09j,
#           0.03315744+0.0000000e+00j, ...,  0.00570484+2.8778930e-09j,
#           0.01538684-7.8582474e-10j, -0.01041831+6.6720574e-10j],
#         ...,
#         [-0.00539909+2.1541227e-09j,  0.00173456-2.8595598e-10j,
#           0.00570484-2.8778930e-09j, ...,  0.00098154+0.0000000e+00j,
#           0.00264735-1.4707012e-09j, -0.0017925 +1.0190496e-09j],
#         [-0.01456219-2.2798186e-09j,  0.00467839+1.8277473e-09j,
#           0.01538684+7.8582474e-10j, ...,  0.00264735+1.4707012e-09j,
#           0.00714033+0.0000000e+00j, -0.00483466+6.2707617e-11j],
#         [ 0.00985994+1.6715345e-09j, -0.0031677 -1.2786395e-09j,
#          -0.01041831-6.6720574e-10j, ..., -0.0017925 -1.0190496e-09j,
#          -0.00483466-6.2707617e-11j,  0.00327351+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 4.8906775e-05+0.00000000e+00j, -9.9346826e-06+3.71097493e-11j,
#           2.2628707e-05-1.00081506e-10j, ...,
#          -6.4298342e-04+4.17749479e-09j, -4.8272107e-03+4.04944451e-08j,
#           4.1190645e-04-4.19603641e-09j],
#         [-9.9346826e-06-3.71097493e-11j,  2.0180828e-06+0.00000000e+00j,
#          -4.5966849e-06+3.15973289e-12j, ...,
#           1.3061251e-04-3.60709351e-10j,  9.8057592e-04-4.56302640e-09j,
#          -8.3672661e-05+5.39813638e-10j],
#         [ 2.2628707e-05+1.00081506e-10j, -4.5966849e-06-3.15973289e-12j,
#           1.0470091e-05+0.00000000e+00j, ...,
#          -2.9750241e-04+6.17103979e-10j, -2.2335052e-03+8.85812845e-09j,
#           1.9058526e-04-1.09855258e-09j],
#         ...,
#         [-6.4298342e-04-4.17749479e-09j,  1.3061251e-04+3.60709351e-10j,
#          -2.9750241e-04-6.17103979e-10j, ...,
#           8.4533831e-03+0.00000000e+00j,  6.3463934e-02-1.20057194e-07j,
#          -5.4153851e-03+1.99817869e-08j],
#         [-4.8272107e-03-4.04944451e-08j,  9.8057592e-04+4.56302640e-09j,
#          -2.2335052e-03-8.85812845e-09j, ...,
#           6.3463934e-02+1.20057194e-07j,  4.7645673e-01+0.00000000e+00j,
#          -4.0656108e-02+7.31029033e-08j],
#         [ 4.1190645e-04+4.19603641e-09j, -8.3672661e-05-5.39813638e-10j,
#           1.9058526e-04+1.09855258e-09j, ...,
#          -5.4153851e-03-1.99817869e-08j, -4.0656108e-02-7.31029033e-08j,
#           3.4691906e-03+0.00000000e+00j]], dtype=complex64),
#  array([[ 0.01896249+0.0000000e+00j, -0.01087693+1.0862446e-09j,
#          -0.00506914+1.1645052e-09j, ...,  0.02708504-1.4868581e-08j,
#           0.01071911-2.7774323e-09j, -0.00579212-3.0915634e-09j],
#         [-0.01087693-1.0862446e-09j,  0.00623903+0.0000000e+00j,
#           0.00290767-3.7758274e-10j, ..., -0.01553604+6.9771184e-09j,
#          -0.00614851+9.7910968e-10j,  0.00332238+2.1051239e-09j],
#         [-0.00506914-1.1645052e-09j,  0.00290767+3.7758274e-10j,
#           0.00135511+0.0000000e+00j, ..., -0.0072405 +2.3114222e-09j,
#          -0.00286548+8.4205309e-11j,  0.00154838+1.1821519e-09j],
#         ...,
#         [ 0.02708504+1.4868581e-08j, -0.01553604-6.9771184e-09j,
#          -0.0072405 -2.3114222e-09j, ...,  0.03868686+0.0000000e+00j,
#           0.01531062+4.4377675e-09j, -0.00827317-8.9574632e-09j],
#         [ 0.01071911+2.7774323e-09j, -0.00614851-9.7910968e-10j,
#          -0.00286548-8.4205309e-11j, ...,  0.01531062-4.4377675e-09j,
#           0.0060593 +0.0000000e+00j, -0.00327417-2.5959699e-09j],
#         [-0.00579212+3.0915634e-09j,  0.00332238-2.1051239e-09j,
#           0.00154838-1.1821519e-09j, ..., -0.00827317+8.9574632e-09j,
#          -0.00327417+2.5959699e-09j,  0.00176921+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 1.4497690e-04+0.0000000e+00j, -1.8208771e-03+1.7521957e-09j,
#           4.6481122e-03-5.5801115e-09j, ...,
#           3.3146606e-04-1.3280326e-09j, -2.8827306e-05+9.4067948e-11j,
#          -2.8722320e-04+7.5122020e-10j],
#         [-1.8208771e-03-1.7521957e-09j,  2.2869803e-02+0.0000000e+00j,
#          -5.8379233e-02+1.3907698e-08j, ...,
#          -4.1631386e-03+1.2673678e-08j,  3.6206443e-04-8.3306440e-10j,
#           3.6074582e-03-5.9637664e-09j],
#         [ 4.6481122e-03+5.5801115e-09j, -5.8379233e-02-1.3907698e-08j,
#           1.4902337e-01+0.0000000e+00j, ...,
#           1.0627150e-02-2.9820107e-08j, -9.2423375e-04+1.9063644e-09j,
#          -9.2086783e-03+1.3029786e-08j],
#         ...,
#         [ 3.3146606e-04+1.3280326e-09j, -4.1631386e-03-1.2673678e-08j,
#           1.0627150e-02+2.9820107e-08j, ...,
#           7.5784302e-04+0.0000000e+00j, -6.5908935e-05-4.8995863e-11j,
#          -6.5668899e-04-9.1350938e-10j],
#         [-2.8827306e-05-9.4067948e-11j,  3.6206443e-04+8.3306440e-10j,
#          -9.2423375e-04-1.9063644e-09j, ...,
#          -6.5908935e-05+4.8995863e-11j,  5.7320412e-06+0.0000000e+00j,
#           5.7111658e-05+3.6991021e-11j],
#         [-2.8722320e-04-7.5122020e-10j,  3.6074582e-03+5.9637664e-09j,
#          -9.2086783e-03-1.3029786e-08j, ...,
#          -6.5668899e-04+9.1350938e-10j,  5.7111658e-05-3.6991021e-11j,
#           5.6903664e-04+0.0000000e+00j]], dtype=complex64),
#  array([[ 2.1456964e-02+0.0000000e+00j,  1.6977075e-03-4.8486086e-09j,
#           1.6627304e-02+5.7912963e-09j, ...,
#          -2.3218267e-02-1.6857999e-09j, -5.5655342e-04+1.3415991e-10j,
#           5.4010586e-03+1.7612192e-09j],
#         [ 1.6977075e-03+4.8486086e-09j,  1.3432516e-04+0.0000000e+00j,
#           1.3155774e-03+4.2154711e-09j, ...,
#          -1.8370643e-03-5.3799907e-09j, -4.4035347e-05-1.1514888e-10j,
#           4.2733992e-04+1.3598220e-09j],
#         [ 1.6627304e-02-5.7912963e-09j,  1.3155774e-03-4.2154711e-09j,
#           1.2884732e-02+0.0000000e+00j, ...,
#          -1.7992161e-02+4.9603264e-09j, -4.3128111e-04+2.5417776e-10j,
#           4.1853567e-03-9.2967717e-11j],
#         ...,
#         [-2.3218267e-02+1.6857999e-09j, -1.8370643e-03+5.3799907e-09j,
#          -1.7992161e-02-4.9603264e-09j, ...,
#           2.5124144e-02+0.0000000e+00j,  6.0223829e-04-1.8889895e-10j,
#          -5.8444063e-03-1.4814466e-09j],
#         [-5.5655342e-04-1.3415991e-10j, -4.4035347e-05+1.1514888e-10j,
#          -4.3128111e-04-2.5417776e-10j, ...,
#           6.0223829e-04+1.8889895e-10j,  1.4435952e-05+0.0000000e+00j,
#          -1.4009334e-04-7.9452903e-11j],
#         [ 5.4010586e-03-1.7612192e-09j,  4.2733992e-04-1.3598220e-09j,
#           4.1853567e-03+9.2967717e-11j, ...,
#          -5.8444063e-03+1.4814466e-09j, -1.4009334e-04+7.9452903e-11j,
#           1.3595322e-03+0.0000000e+00j]], dtype=complex64),
#  array([[ 0.02467425+0.0000000e+00j,  0.05539334+5.0256759e-09j,
#           0.03329547+7.8326412e-10j, ..., -0.01248184+9.3085095e-09j,
#           0.01071898-4.9977436e-09j,  0.00727886+3.6316958e-09j],
#         [ 0.05539334-5.0256759e-09j,  0.12435724+0.0000000e+00j,
#           0.07474785-5.0232378e-09j, ..., -0.02802155+2.3439785e-08j,
#           0.02406395-1.3403115e-08j,  0.01634093+6.6705401e-09j],
#         [ 0.03329547-7.8326412e-10j,  0.07474785+5.0232378e-09j,
#           0.04492895+0.0000000e+00j, ..., -0.01684301+1.2957143e-08j,
#           0.0144642 -7.0842283e-09j,  0.0098221 +4.6695545e-09j],
#         ...,
#         [-0.01248184-9.3085095e-09j, -0.02802155-2.3439785e-08j,
#          -0.01684301-1.2957143e-08j, ...,  0.00631413+0.0000000e+00j,
#          -0.00542236-1.5156143e-09j, -0.00368212-4.5831410e-09j],
#         [ 0.01071898+4.9977436e-09j,  0.02406395+1.3403115e-08j,
#           0.0144642 +7.0842283e-09j, ..., -0.00542236+1.5156143e-09j,
#           0.00465653+0.0000000e+00j,  0.00316208+3.0520046e-09j],
#         [ 0.00727886-3.6316958e-09j,  0.01634093-6.6705401e-09j,
#           0.0098221 -4.6695545e-09j, ..., -0.00368212+4.5831410e-09j,
#           0.00316208-3.0520046e-09j,  0.00214725+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 0.03591007+0.00000000e+00j, -0.03003332-5.45630208e-10j,
#           0.04493239+1.99990424e-09j, ..., -0.00219329+1.30851445e-08j,
#           0.06256894-2.50938275e-08j, -0.04999305+2.46357068e-08j],
#         [-0.03003332+5.45630208e-10j,  0.02511831+0.00000000e+00j,
#          -0.03757912-9.89897053e-10j, ...,  0.00183435-1.09770619e-08j,
#          -0.05232942+2.19378720e-08j,  0.0418116 -2.13636362e-08j],
#         [ 0.04493239-1.99990424e-09j, -0.03757912+9.89897053e-10j,
#           0.05622155+0.00000000e+00j, ..., -0.00274434+1.64949050e-08j,
#           0.07828925-3.48831861e-08j, -0.06255369+3.36095844e-08j],
#         ...,
#         [-0.00219329-1.30851445e-08j,  0.00183435+1.09770619e-08j,
#          -0.00274434-1.64949050e-08j, ...,  0.00013396+0.00000000e+00j,
#          -0.00382153-2.12666187e-08j,  0.00305343+1.67121144e-08j],
#         [ 0.06256894+2.50938275e-08j, -0.05232942-2.19378720e-08j,
#           0.07828925+3.48831861e-08j, ..., -0.00382153+2.12666187e-08j,
#           0.1090188 +0.00000000e+00j, -0.08710683+7.98976529e-09j],
#         [-0.04999305-2.46357068e-08j,  0.0418116 +2.13636362e-08j,
#          -0.06255369-3.36095844e-08j, ...,  0.00305343-1.67121144e-08j,
#          -0.08710683-7.98976529e-09j,  0.06959901+0.00000000e+00j]],
#        dtype=complex64),
#  array([[ 0.00496996+0.0000000e+00j, -0.00526266-3.8274708e-09j,
#          -0.00296151-4.0953245e-09j, ...,  0.00403675-1.5206099e-09j,
#          -0.018617  -8.5463370e-09j, -0.01243646-1.0081539e-08j],
#         [-0.00526266+3.8274708e-09j,  0.0055726 +0.0000000e+00j,
#           0.00313592+2.0557920e-09j, ..., -0.00427449+4.7189475e-09j,
#           0.01971342-5.2876770e-09j,  0.01316889+1.0976975e-09j],
#         [-0.00296151+4.0953245e-09j,  0.00313592-2.0557920e-09j,
#           0.00176471+0.0000000e+00j, ..., -0.00240542+4.2324459e-09j,
#           0.01109353-1.0248085e-08j,  0.00741066-4.2404293e-09j],
#         ...,
#         [ 0.00403675+1.5206099e-09j, -0.00427449-4.7189475e-09j,
#          -0.00240542-4.2324459e-09j, ...,  0.00327877+0.0000000e+00j,
#          -0.01512127-1.2637643e-08j, -0.01010126-1.1993581e-08j],
#         [-0.018617  +8.5463370e-09j,  0.01971342+5.2876770e-09j,
#           0.01109353+1.0248085e-08j, ..., -0.01512127+1.2637643e-08j,
#           0.0697375 +0.0000000e+00j,  0.04658579+1.6378758e-08j],
#         [-0.01243646+1.0081539e-08j,  0.01316889-1.0976975e-09j,
#           0.00741066+4.2404293e-09j, ..., -0.01010126+1.1993581e-08j,
#           0.04658579-1.6378758e-08j,  0.03112007+0.0000000e+00j]],
#        dtype=complex64),
#  array([[0.00171301+0.0000000e+00j, 0.00236018-5.4586141e-10j,
#          0.00110906+6.8403944e-10j, ..., 0.01180472-6.5161556e-09j,
#          0.00905892-4.6427977e-09j, 0.00341847-9.2440966e-10j],
#         [0.00236018+5.4586141e-10j, 0.00325185+0.0000000e+00j,
#          0.00152806+1.2958761e-09j, ..., 0.01626449-5.2162870e-09j,
#          0.01248134-3.5101471e-09j, 0.00470995-1.8433266e-10j],
#         [0.00110906-6.8403944e-10j, 0.00152806-1.2958761e-09j,
#          0.00071805+0.0000000e+00j, ..., 0.00764278-8.9326413e-09j,
#          0.00586506-6.6233143e-09j, 0.00221323-1.9635562e-09j],
#         ...,
#         [0.01180472+6.5161556e-09j, 0.01626449+5.2162870e-09j,
#          0.00764278+8.9326413e-09j, ..., 0.08134876+0.0000000e+00j,
#          0.06242691+2.4649154e-09j, 0.02355736+6.6332695e-09j],
#         [0.00905892+4.6427977e-09j, 0.01248134+3.5101471e-09j,
#          0.00586506+6.6233143e-09j, ..., 0.06242691-2.4649154e-09j,
#          0.04790631+0.0000000e+00j, 0.01807789+4.3765591e-09j],
#         [0.00341847+9.2440966e-10j, 0.00470995+1.8433266e-10j,
#          0.00221323+1.9635562e-09j, ..., 0.02355736-6.6332695e-09j,
#          0.01807789-4.3765591e-09j, 0.00682185+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 0.0044189 +0.0000000e+00j, -0.00260896-1.1935532e-10j,
#          -0.00560748+5.6676230e-10j, ..., -0.01854608+1.4008503e-08j,
#          -0.01331304+9.0476791e-09j,  0.00571447-4.4508828e-09j],
#         [-0.00260896+1.1935532e-10j,  0.00154036+0.0000000e+00j,
#           0.00331071-4.8608079e-10j, ...,  0.01094978-8.7716865e-09j,
#           0.00786014-5.7014233e-09j, -0.00337388+2.7821927e-09j],
#         [-0.00560748-5.6676230e-10j,  0.00331071+4.8608079e-10j,
#           0.00711575+0.0000000e+00j, ...,  0.02353452-1.5397749e-08j,
#           0.01689392-9.7737693e-09j, -0.00725152+4.9151301e-09j],
#         ...,
#         [-0.01854608-1.4008503e-08j,  0.01094978+8.7716865e-09j,
#           0.02353452+1.5397749e-08j, ...,  0.07783774+0.0000000e+00j,
#           0.05587469+4.2310759e-09j, -0.02398359+5.6467364e-10j],
#         [-0.01331304-9.0476791e-09j,  0.00786014+5.7014233e-09j,
#           0.01689392+9.7737693e-09j, ...,  0.05587469-4.2310759e-09j,
#           0.04010884+0.0000000e+00j, -0.01721627+1.7090347e-09j],
#         [ 0.00571447+4.4508828e-09j, -0.00337388-2.7821927e-09j,
#          -0.00725152-4.9151301e-09j, ..., -0.02398359-5.6467364e-10j,
#          -0.01721627-1.7090347e-09j,  0.00738989+0.0000000e+00j]],
#        dtype=complex64),
#  array([[ 0.00291801+0.0000000e+00j,  0.00187662+2.2090037e-10j,
#           0.00884051-5.3947175e-10j, ...,  0.00785723-4.0139154e-09j,
#          -0.00328494+3.5256629e-09j,  0.00744513-5.1495128e-09j],
#         [ 0.00187662-2.2090037e-10j,  0.00120688+0.0000000e+00j,
#           0.00568547-1.0161907e-09j, ...,  0.00505311-3.1762217e-09j,
#          -0.00211259+2.5160856e-09j,  0.00478808-3.8753445e-09j],
#         [ 0.00884051+5.3947175e-10j,  0.00568547+1.0161907e-09j,
#           0.02678355+0.0000000e+00j, ...,  0.02380457-1.0708092e-08j,
#          -0.00995217+1.0074174e-08j,  0.02255604-1.4224728e-08j],
#         ...,
#         [ 0.00785723+4.0139154e-09j,  0.00505311+3.1762217e-09j,
#           0.02380457+1.0708092e-08j, ...,  0.02115692+0.0000000e+00j,
#          -0.00884525+4.9747921e-09j,  0.02004726-3.6246659e-09j],
#         [-0.00328494-3.5256629e-09j, -0.00211259-2.5160856e-09j,
#          -0.00995217-1.0074174e-08j, ..., -0.00884525-4.9747921e-09j,
#           0.00369801+0.0000000e+00j, -0.00838132-3.1984753e-09j],
#         [ 0.00744513+5.1495128e-09j,  0.00478808+3.8753445e-09j,
#           0.02255604+1.4224728e-08j, ...,  0.02004726+3.6246659e-09j,
#          -0.00838132+3.1984753e-09j,  0.0189958 +0.0000000e+00j]],
#        dtype=complex64)]

# %% [markdown]
# ## Meyer Wallach measure of a Quantum State

# %%
Meyer_Wallach_measure = quple.Meyer_Wallach_measure(final_states[0])
Meyer_Wallach_measure
# Out:
# 0.49311002492904665

# %% [markdown]
# ## Meyer Wallach measure of a Bell State

# %%
bell_circuit = quple.bell_circuit
final_state = quple.sample_final_states(bell_circuit)[0]
Meyer_Wallach_measure = quple.Meyer_Wallach_measure(final_state)
Meyer_Wallach_measure
# Out:
# 0.9999998807907104

# %% [markdown]
# # The von Neumann entropy of PQC
# - Parameters are filled with randomized values between 0 and 2pi and the circuit is sampled many times

# %%
quple.circuit_von_neumann_entropy(cq, samples=200)
# Out:
# 1.829272825133572e-06

# %% [markdown]
# ## The Entangling measure of PQC
# - This is the mean Meyer Wallach measure of all the final states sampled from the circuit
# - Parameters are filled with randomized values between 0 and 2pi and the circuit is sampled many times

# %%
quple.circuit_entangling_measure(cq, samples=200)
# Out:
# 0.6007279518660508

# %% [markdown]
# ## The Expressibility measure of PQC
# - This is the Kullback Leibler divergence between the fidelity pdf of PQC and the Haar fidelity pdf
# - Parameters are filled with randomized values between 0 and 2pi and the circuit is sampled many times

# %%
quple.circuit_expressibility_measure(cq, samples=3000, bins=100)
# Out:
# 2.6920102250585356

# %% [markdown]
# ##  Plotting the fidelity pdf of PQC and Haar

# %%
quple.circuit_fidelity_plot(cq, samples=3000, bins=100)
# Out:
# <module 'matplotlib.pyplot' from '/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Reproducing results from the paper page 5:
# ## https://arxiv.org/pdf/1905.10876.pdf

# %%
import sympy as sp
# circuit A
cq_A = quple.QuantumCircuit(n_qubit=1)
cq_A.H(0)
cq_A.RZ(sp.Symbol('x'),0)
cq_A
# Out:
# (0, 0): ───H───Rz(x)───

# %%
# circuit B
cq_B = quple.QuantumCircuit(n_qubit=1)
cq_B.H(0)
cq_B.RZ(sp.Symbol('x_0'),0)
cq_B.RX(sp.Symbol('x_1'),0)
cq_B
# Out:
# (0, 0): ───H───Rz(x_0)───Rx(x_1)───

# %%
quple.circuit_fidelity_plot(cq_A, samples=3000, bins=100)
# Out:
# <module 'matplotlib.pyplot' from '/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
quple.circuit_fidelity_plot(cq_B, samples=3000, bins=100)
# Out:
# <module 'matplotlib.pyplot' from '/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Merging Parameterised Circuits

# %%
import quple
# Merging multiple parameterised circuit
# Sometimes you want to create a very customized parameterised circuit which cannot be created from a single 
# ParametereisedCircuit class but can be created from combining mutliple instances with a different construction
# If you simple append the circuits the parameters will not get updated
# This feature will upate the parameters for you

# %%
# Create various parameterised circuit
cq_1 = quple.ParameterisedCircuit(n_qubit=3, rotation_blocks=['RX','RZ'], copies=1, entanglement_blocks=['CNOT'], final_rotation_layer=False)
cq_1
# Out:
# (0, 0): ───Rx(pi*<θ_0/pi>)───Rz(pi*<θ_3/pi>)───@───@───────
#                                                │   │
# (0, 1): ───Rx(pi*<θ_1/pi>)───Rz(pi*<θ_4/pi>)───X───┼───@───
#                                                    │   │
# (0, 2): ───Rx(pi*<θ_2/pi>)───Rz(pi*<θ_5/pi>)───────X───X───

# %%
cq_2 = quple.ParameterisedCircuit(n_qubit=3, rotation_blocks=['RX','RY','RZ'], copies=2, entanglement_blocks=['CNOT'], final_rotation_layer=False)
cq_2
# Out:
# (0, 0): ───Rx(pi*<θ_0/pi>)───Ry(pi*<θ_3/pi>)───Rz(pi*<θ_6/pi>)───@───@───────Rx(pi*<θ_9/pi>)────Ry(pi*<θ_12/pi>)───Rz(pi*<θ_15/pi>)───@───@───────
#                                                                  │   │                                                                │   │
# (0, 1): ───Rx(pi*<θ_1/pi>)───Ry(pi*<θ_4/pi>)───Rz(pi*<θ_7/pi>)───X───┼───@───Rx(pi*<θ_10/pi>)───Ry(pi*<θ_13/pi>)───Rz(pi*<θ_16/pi>)───X───┼───@───
#                                                                      │   │                                                                │   │
# (0, 2): ───Rx(pi*<θ_2/pi>)───Ry(pi*<θ_5/pi>)───Rz(pi*<θ_8/pi>)───────X───X───Rx(pi*<θ_11/pi>)───Ry(pi*<θ_14/pi>)───Rz(pi*<θ_17/pi>)───────X───X───

# %%
cq_3 = quple.ParameterisedCircuit(n_qubit=3, rotation_blocks=['RX','RY'], copies=1, final_rotation_layer=False)
cq_3
# Out:
# (0, 0): ───Rx(pi*<θ_0/pi>)───Ry(pi*<θ_3/pi>)───
#
# (0, 1): ───Rx(pi*<θ_1/pi>)───Ry(pi*<θ_4/pi>)───
#
# (0, 2): ───Rx(pi*<θ_2/pi>)───Ry(pi*<θ_5/pi>)───

# %%
combined_cq = quple.merge_pqc([cq_1,cq_2,cq_3])
combined_cq
# Out:
# (0, 0): ───Rx(pi*θ_0)───Rz(pi*θ_3)───@───@───────Rx(pi*θ_6)───Ry(pi*θ_9)────Rz(pi*θ_12)───@───@───────Rx(pi*θ_15)───Ry(pi*θ_18)───Rz(pi*θ_21)───@───@───────Rx(pi*θ_24)───Ry(pi*θ_27)───
#                                      │   │                                                │   │                                                 │   │
# (0, 1): ───Rx(pi*θ_1)───Rz(pi*θ_4)───X───┼───@───Rx(pi*θ_7)───Ry(pi*θ_10)───Rz(pi*θ_13)───X───┼───@───Rx(pi*θ_16)───Ry(pi*θ_19)───Rz(pi*θ_22)───X───┼───@───Rx(pi*θ_25)───Ry(pi*θ_28)───
#                                          │   │                                                │   │                                                 │   │
# (0, 2): ───Rx(pi*θ_2)───Rz(pi*θ_5)───────X───X───Rx(pi*θ_8)───Ry(pi*θ_11)───Rz(pi*θ_14)───────X───X───Rx(pi*θ_17)───Ry(pi*θ_20)───Rz(pi*θ_23)───────X───X───Rx(pi*θ_26)───Ry(pi*θ_29)───

# %% [markdown]
# ## Some features for the QuantumCircuit class
# - create circuit from cirq.Circuit
# - display the symbols inside the circuit
# - display the qubits insie the circuit
# - get circuits with parameter symbols resolved

# %%
# create circuit from cirq.Circuit
import cirq
import numpy as np
import sympy as sp
qubits = cirq.GridQubit.rect(1, 5)
cq = cirq.Circuit()
symbols = sp.symarray('x',5)
cq.append([cirq.H(qubits[i]) for i in range(5)])
cq.append([cirq.rz(symbols[i]*sp.pi)(qubits[i]) for i in range(5)])

# %%
cq
# Out:
# (0, 0): ───H───Rz(pi*x_0)───
#
# (0, 1): ───H───Rz(pi*x_1)───
#
# (0, 2): ───H───Rz(pi*x_2)───
#
# (0, 3): ───H───Rz(pi*x_3)───
#
# (0, 4): ───H───Rz(pi*x_4)───

# %%
# convert the circuit to a QuantumCircuit instance in quple
converted_cq = quple.QuantumCircuit.from_cirq(cq)
type(converted_cq)
# Out:
# quple.circuit.quantum_circuit.QuantumCircuit

# %%
# display the symbols inside the circuit
converted_cq.symbols
# Out:
# ['x_0', 'x_1', 'x_2', 'x_3', 'x_4']

# %%
# display the qubits involved in the circuit
converted_cq.qubits
# Out:
# [cirq.GridQubit(0, 0),
#  cirq.GridQubit(0, 1),
#  cirq.GridQubit(0, 2),
#  cirq.GridQubit(0, 3),
#  cirq.GridQubit(0, 4)]

# %%
# get circuits with parameter symbols resolved
# first generated some random data
data = np.random.rand(5,5)
data
# Out:
# array([[0.16394948, 0.08169893, 0.41441427, 0.48408606, 0.3561498 ],
#        [0.77925613, 0.81630096, 0.08046924, 0.16766831, 0.75225363],
#        [0.52170242, 0.33224539, 0.41292554, 0.99536633, 0.65058346],
#        [0.00598574, 0.68947571, 0.91644006, 0.75376438, 0.8900781 ],
#        [0.71727339, 0.46664922, 0.00558367, 0.6048665 , 0.35671169]])

# %%
# get the resolved circuits
resolved_circuits = converted_cq.resolve_parameters(data)

# %%
resolved_circuits[0]
# Out:
# (0, 0): ───H───Rz(0.164π)───
#
# (0, 1): ───H───Rz(0.082π)───
#
# (0, 2): ───H───Rz(0.414π)───
#
# (0, 3): ───H───Rz(0.484π)───
#
# (0, 4): ───H───Rz(0.356π)───

# %% [markdown]
# # New Encoding Maps
# - self_product (default)
# - cosine_product
# - modified_cosine_product
# - distance_measure
# - one_norm_distance
# - two_norm_distance
# - arithmetic_mean
#
# Encoding maps are used to encode parameters as rotation angles in an encoding circuit

# %%
# prepare the symbols
symbols = sp.symarray('x',5)
symbols
# Out:
# array([x_0, x_1, x_2, x_3, x_4], dtype=object)

# %%
# self_product encoding map
# from https://arxiv.org/pdf/1906.10467.pdf
from quple.data_encoding.encoding_maps import self_product
encoded_value = self_product(symbols)
encoded_value
# Out:
# x_0*x_1*x_2*x_3*x_4

# %%
symbols
# Out:
# array([x_0, x_1, x_2, x_3, x_4], dtype=object)

# %%
# cosine_product encoding map
from quple.data_encoding.encoding_maps import cosine_product
encoded_value = cosine_product(symbols)
encoded_value
# Out:
# cos(pi*x_0)*cos(pi*x_1)*cos(pi*x_2)*cos(pi*x_3)*cos(pi*x_4)

# %%
# modified_cosine_product encoding map
# from https://arxiv.org/pdf/1906.10467.pdf
from quple.data_encoding.encoding_maps import modified_cosine_product
encoded_value = modified_cosine_product(symbols)
encoded_value
# Out:
# cos(x_0)*cos(x_1)*cos(x_2)*cos(x_3)*cos(x_4)

# %%
# distance_measure encoding map
from quple.data_encoding.encoding_maps import distance_measure
encoded_value = distance_measure(symbols)
encoded_value
# Out:
# (-x_0 + x_4)*(x_0 - x_1)*(x_1 - x_2)*(x_2 - x_3)*(x_3 - x_4)/32

# %%
# one_norm_distance encoding map
from quple.data_encoding.encoding_maps import one_norm_distance
encoded_value = one_norm_distance(symbols)
encoded_value
# Out:
# Abs(x_0 - x_1)/10 + Abs(x_0 - x_4)/10 + Abs(x_1 - x_2)/10 + Abs(x_2 - x_3)/10 + Abs(x_3 - x_4)/10

# %%
# two_norm_distance encoding map
from quple.data_encoding.encoding_maps import two_norm_distance
encoded_value = two_norm_distance(symbols)
encoded_value
# Out:
# 0.447213595499958*((-x_0 + x_4)**2 + (x_0 - x_1)**2 + (x_1 - x_2)**2 + (x_2 - x_3)**2 + (x_3 - x_4)**2)**0.5

# %%
# arithmetic_mean encoding map
from quple.data_encoding.encoding_maps import arithmetic_mean
encoded_value = arithmetic_mean(symbols)
encoded_value
# Out:
# x_0/5 + x_1/5 + x_2/5 + x_3/5 + x_4/5

# %%
# Let's try out a second order expansion encoding circuit with the various encoding maps
from quple.data_encoding.second_order_expansion import SecondOrderExpansion

# %%
# self_product
cq = SecondOrderExpansion(feature_dimension=5, encoding_map=self_product)
cq
# Out:
#                                                                                                 ┌──┐                                                         ┌─────────────────────┐                                      ┌──┐                          ┌─────────────────────┐                                                                                                                                                          ┌──┐                                                         ┌─────────────────────┐                                      ┌──┐                          ┌─────────────────────┐
# (0, 0): ───H───Rz(pi*<1.0*x_0>)───@──────────────────────────@───@──────────────────────────@────@────────────────────────────@───@───────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_0>)───@──────────────────────────@───@──────────────────────────@────@────────────────────────────@───@───────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                   │                          │   │                          │    │                            │   │                           │                                                                                                                                                                                                            │                          │   │                          │    │                            │   │                           │
# (0, 1): ───H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<1.0*x_0*x_1>)───X───┼──────────────────────────┼────┼@───────────────────────────┼───┼───────────────────────────┼────────────────────────@───@──────────────────────────@────@─────────────────────────────@──────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<1.0*x_0*x_1>)───X───┼──────────────────────────┼────┼@───────────────────────────┼───┼───────────────────────────┼────────────────────────@───@──────────────────────────@────@─────────────────────────────@──────────────────────────────────────────────────────────────────────────────────────────
#                                                                  │                          │    ││                           │   │                           │                        │   │                          │    │                             │                                                                                                                                                │                          │    ││                           │   │                           │                        │   │                          │    │                             │
# (0, 2): ───H───Rz(pi*<1.0*x_2>)──────────────────────────────────X───Rz(pi*<1.0*x_0*x_2>)───X────┼X───────────────────────────┼───┼───────────────────────────┼Rz(pi*<1.0*x_1*x_2>)────X───┼──────────────────────────┼────┼@────────────────────────────┼────────────────────────@───@──────────────────────────@──────────────────────────────────H───Rz(pi*<1.0*x_2>)──────────────────────────────────X───Rz(pi*<1.0*x_0*x_2>)───X────┼X───────────────────────────┼───┼───────────────────────────┼Rz(pi*<1.0*x_1*x_2>)────X───┼──────────────────────────┼────┼@────────────────────────────┼────────────────────────@───@──────────────────────────@──────────────────────────────────
#                                                                                                  │                            │   │                           │                            │                          │    ││                            │                        │   │                          │                                                                                                                        │                            │   │                           │                            │                          │    ││                            │                        │   │                          │
# (0, 3): ───H───Rz(pi*<1.0*x_3>)──────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*x_0*x_3>)───X───┼───────────────────────────┼────────────────────────────X───Rz(pi*<1.0*x_1*x_3>)───X────┼X────────────────────────────┼Rz(pi*<1.0*x_2*x_3>)────X───┼──────────────────────────┼───@──────────────────────────@───H───Rz(pi*<1.0*x_3>)──────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*x_0*x_3>)───X───┼───────────────────────────┼────────────────────────────X───Rz(pi*<1.0*x_1*x_3>)───X────┼X────────────────────────────┼Rz(pi*<1.0*x_2*x_3>)────X───┼──────────────────────────┼───@──────────────────────────@───
#                                                                                                                                   │                           │                                                            │                             │                            │                          │   │                          │                                                                                                                          │                           │                                                            │                             │                            │                          │   │                          │
# (0, 4): ───H───Rz(pi*<1.0*x_4>)───────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*x_0*x_4>)────X────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*x_1*x_4>)────X────────────────────────────X───Rz(pi*<1.0*x_2*x_4>)───X───X───Rz(pi*<1.0*x_3*x_4>)───X───H───Rz(pi*<1.0*x_4>)───────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*x_0*x_4>)────X────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*x_1*x_4>)────X────────────────────────────X───Rz(pi*<1.0*x_2*x_4>)───X───X───Rz(pi*<1.0*x_3*x_4>)───X───
#                                                                                                 └──┘                                                         └─────────────────────┘                                      └──┘                          └─────────────────────┘                                                                                                                                                          └──┘                                                         └─────────────────────┘                                      └──┘                          └─────────────────────┘

# %%
# cosine_product
cq = SecondOrderExpansion(feature_dimension=5, encoding_map=cosine_product)
cq
# Out:
#                                                                                                                                         ┌──┐                                                                                         ┌─────────────────────────────────────┐                                                      ┌──┐                                          ┌─────────────────────────────────────┐                                                                                                                                                                                                                                  ┌──┐                                                                                         ┌─────────────────────────────────────┐                                                      ┌──┐                                          ┌─────────────────────────────────────┐
# (0, 0): ───H───Rz(pi*<1.0*cos(pi*x_0)>)───@──────────────────────────────────────────@───@──────────────────────────────────────────@────@────────────────────────────────────────────@───@───────────────────────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*cos(pi*x_0)>)───@──────────────────────────────────────────@───@──────────────────────────────────────────@────@────────────────────────────────────────────@───@───────────────────────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                           │                                          │   │                                          │    │                                            │   │                                           │                                                                                                                                                                                                                                                                                                                    │                                          │   │                                          │    │                                            │   │                                           │
# (0, 1): ───H───Rz(pi*<1.0*cos(pi*x_1)>)───X───Rz(pi*<1.0*cos(pi*x_0)*cos(pi*x_1)>)───X───┼──────────────────────────────────────────┼────┼@───────────────────────────────────────────┼───┼───────────────────────────────────────────┼────────────────────────────────────────@───@──────────────────────────────────────────@────@─────────────────────────────────────────────@──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*cos(pi*x_1)>)───X───Rz(pi*<1.0*cos(pi*x_0)*cos(pi*x_1)>)───X───┼──────────────────────────────────────────┼────┼@───────────────────────────────────────────┼───┼───────────────────────────────────────────┼────────────────────────────────────────@───@──────────────────────────────────────────@────@─────────────────────────────────────────────@──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                          │                                          │    ││                                           │   │                                           │                                        │   │                                          │    │                                             │                                                                                                                                                                                                                        │                                          │    ││                                           │   │                                           │                                        │   │                                          │    │                                             │
# (0, 2): ───H───Rz(pi*<1.0*cos(pi*x_2)>)──────────────────────────────────────────────────X───Rz(pi*<1.0*cos(pi*x_0)*cos(pi*x_2)>)───X────┼X───────────────────────────────────────────┼───┼───────────────────────────────────────────┼Rz(pi*<1.0*cos(pi*x_1)*cos(pi*x_2)>)────X───┼──────────────────────────────────────────┼────┼@────────────────────────────────────────────┼────────────────────────────────────────@───@──────────────────────────────────────────@──────────────────────────────────────────────────H───Rz(pi*<1.0*cos(pi*x_2)>)──────────────────────────────────────────────────X───Rz(pi*<1.0*cos(pi*x_0)*cos(pi*x_2)>)───X────┼X───────────────────────────────────────────┼───┼───────────────────────────────────────────┼Rz(pi*<1.0*cos(pi*x_1)*cos(pi*x_2)>)────X───┼──────────────────────────────────────────┼────┼@────────────────────────────────────────────┼────────────────────────────────────────@───@──────────────────────────────────────────@──────────────────────────────────────────────────
#                                                                                                                                          │                                            │   │                                           │                                            │                                          │    ││                                            │                                        │   │                                          │                                                                                                                                                                                │                                            │   │                                           │                                            │                                          │    ││                                            │                                        │   │                                          │
# (0, 3): ───H───Rz(pi*<1.0*cos(pi*x_3)>)──────────────────────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*cos(pi*x_0)*cos(pi*x_3)>)───X───┼───────────────────────────────────────────┼────────────────────────────────────────────X───Rz(pi*<1.0*cos(pi*x_1)*cos(pi*x_3)>)───X────┼X────────────────────────────────────────────┼Rz(pi*<1.0*cos(pi*x_2)*cos(pi*x_3)>)────X───┼──────────────────────────────────────────┼───@──────────────────────────────────────────@───H───Rz(pi*<1.0*cos(pi*x_3)>)──────────────────────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*cos(pi*x_0)*cos(pi*x_3)>)───X───┼───────────────────────────────────────────┼────────────────────────────────────────────X───Rz(pi*<1.0*cos(pi*x_1)*cos(pi*x_3)>)───X────┼X────────────────────────────────────────────┼Rz(pi*<1.0*cos(pi*x_2)*cos(pi*x_3)>)────X───┼──────────────────────────────────────────┼───@──────────────────────────────────────────@───
#                                                                                                                                                                                           │                                           │                                                                                            │                                             │                                            │                                          │   │                                          │                                                                                                                                                                                  │                                           │                                                                                            │                                             │                                            │                                          │   │                                          │
# (0, 4): ───H───Rz(pi*<1.0*cos(pi*x_4)>)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*cos(pi*x_0)*cos(pi*x_4)>)────X────────────────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*cos(pi*x_1)*cos(pi*x_4)>)────X────────────────────────────────────────────X───Rz(pi*<1.0*cos(pi*x_2)*cos(pi*x_4)>)───X───X───Rz(pi*<1.0*cos(pi*x_3)*cos(pi*x_4)>)───X───H───Rz(pi*<1.0*cos(pi*x_4)>)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*cos(pi*x_0)*cos(pi*x_4)>)────X────────────────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*cos(pi*x_1)*cos(pi*x_4)>)────X────────────────────────────────────────────X───Rz(pi*<1.0*cos(pi*x_2)*cos(pi*x_4)>)───X───X───Rz(pi*<1.0*cos(pi*x_3)*cos(pi*x_4)>)───X───
#                                                                                                                                         └──┘                                                                                         └─────────────────────────────────────┘                                                      └──┘                                          └─────────────────────────────────────┘                                                                                                                                                                                                                                  └──┘                                                                                         └─────────────────────────────────────┘                                                      └──┘                                          └─────────────────────────────────────┘

# %%
# modified_cosine_product
cq = SecondOrderExpansion(feature_dimension=5, encoding_map=modified_cosine_product)
cq
# Out:
#                                                                                                                          ┌──┐                                                                             ┌───────────────────────────────┐                                                ┌──┐                                    ┌───────────────────────────────┐                                                                                                                                                                                                       ┌──┐                                                                             ┌───────────────────────────────┐                                                ┌──┐                                    ┌───────────────────────────────┐
# (0, 0): ───H───Rz(pi*<1.0*cos(x_0)>)───@────────────────────────────────────@───@────────────────────────────────────@────@──────────────────────────────────────@───@─────────────────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*cos(x_0)>)───@────────────────────────────────────@───@────────────────────────────────────@────@──────────────────────────────────────@───@─────────────────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                        │                                    │   │                                    │    │                                      │   │                                     │                                                                                                                                                                                                                                                                             │                                    │   │                                    │    │                                      │   │                                     │
# (0, 1): ───H───Rz(pi*<1.0*cos(x_1)>)───X───Rz(pi*<1.0*cos(x_0)*cos(x_1)>)───X───┼────────────────────────────────────┼────┼@─────────────────────────────────────┼───┼─────────────────────────────────────┼──────────────────────────────────@───@────────────────────────────────────@────@───────────────────────────────────────@────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*cos(x_1)>)───X───Rz(pi*<1.0*cos(x_0)*cos(x_1)>)───X───┼────────────────────────────────────┼────┼@─────────────────────────────────────┼───┼─────────────────────────────────────┼──────────────────────────────────@───@────────────────────────────────────@────@───────────────────────────────────────@────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                 │                                    │    ││                                     │   │                                     │                                  │   │                                    │    │                                       │                                                                                                                                                                                             │                                    │    ││                                     │   │                                     │                                  │   │                                    │    │                                       │
# (0, 2): ───H───Rz(pi*<1.0*cos(x_2)>)────────────────────────────────────────────X───Rz(pi*<1.0*cos(x_0)*cos(x_2)>)───X────┼X─────────────────────────────────────┼───┼─────────────────────────────────────┼Rz(pi*<1.0*cos(x_1)*cos(x_2)>)────X───┼────────────────────────────────────┼────┼@──────────────────────────────────────┼──────────────────────────────────@───@────────────────────────────────────@────────────────────────────────────────────H───Rz(pi*<1.0*cos(x_2)>)────────────────────────────────────────────X───Rz(pi*<1.0*cos(x_0)*cos(x_2)>)───X────┼X─────────────────────────────────────┼───┼─────────────────────────────────────┼Rz(pi*<1.0*cos(x_1)*cos(x_2)>)────X───┼────────────────────────────────────┼────┼@──────────────────────────────────────┼──────────────────────────────────@───@────────────────────────────────────@────────────────────────────────────────────
#                                                                                                                           │                                      │   │                                     │                                      │                                    │    ││                                      │                                  │   │                                    │                                                                                                                                                           │                                      │   │                                     │                                      │                                    │    ││                                      │                                  │   │                                    │
# (0, 3): ───H───Rz(pi*<1.0*cos(x_3)>)──────────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*cos(x_0)*cos(x_3)>)───X───┼─────────────────────────────────────┼──────────────────────────────────────X───Rz(pi*<1.0*cos(x_1)*cos(x_3)>)───X────┼X──────────────────────────────────────┼Rz(pi*<1.0*cos(x_2)*cos(x_3)>)────X───┼────────────────────────────────────┼───@────────────────────────────────────@───H───Rz(pi*<1.0*cos(x_3)>)──────────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*cos(x_0)*cos(x_3)>)───X───┼─────────────────────────────────────┼──────────────────────────────────────X───Rz(pi*<1.0*cos(x_1)*cos(x_3)>)───X────┼X──────────────────────────────────────┼Rz(pi*<1.0*cos(x_2)*cos(x_3)>)────X───┼────────────────────────────────────┼───@────────────────────────────────────@───
#                                                                                                                                                                      │                                     │                                                                                │                                       │                                      │                                    │   │                                    │                                                                                                                                                             │                                     │                                                                                │                                       │                                      │                                    │   │                                    │
# (0, 4): ───H───Rz(pi*<1.0*cos(x_4)>)─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*cos(x_0)*cos(x_4)>)────X────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*cos(x_1)*cos(x_4)>)────X──────────────────────────────────────X───Rz(pi*<1.0*cos(x_2)*cos(x_4)>)───X───X───Rz(pi*<1.0*cos(x_3)*cos(x_4)>)───X───H───Rz(pi*<1.0*cos(x_4)>)─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*cos(x_0)*cos(x_4)>)────X────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*cos(x_1)*cos(x_4)>)────X──────────────────────────────────────X───Rz(pi*<1.0*cos(x_2)*cos(x_4)>)───X───X───Rz(pi*<1.0*cos(x_3)*cos(x_4)>)───X───
#                                                                                                                          └──┘                                                                             └───────────────────────────────┘                                                └──┘                                    └───────────────────────────────┘                                                                                                                                                                                                       └──┘                                                                             └───────────────────────────────┘                                                └──┘                                    └───────────────────────────────┘

# %%
# distance_measure
cq = SecondOrderExpansion(feature_dimension=5, encoding_map=distance_measure)
cq
# Out:
#                                                                                                             ┌──┐                                                                     ┌───────────────────────────┐                                            ┌──┐                                ┌───────────────────────────┐                                                                                                                                                                                  ┌──┐                                                                     ┌───────────────────────────┐                                            ┌──┐                                ┌───────────────────────────┐
# (0, 0): ───H───Rz(pi*<1.0*x_0>)───@────────────────────────────────@───@────────────────────────────────@────@──────────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_0>)───@────────────────────────────────@───@────────────────────────────────@────@──────────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                   │                                │   │                                │    │                                  │   │                                 │                                                                                                                                                                                                                                                │                                │   │                                │    │                                  │   │                                 │
# (0, 1): ───H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<0.5*x_0 - 0.5*x_1>)───X───┼────────────────────────────────┼────┼@─────────────────────────────────┼───┼─────────────────────────────────┼──────────────────────────────@───@────────────────────────────────@────@───────────────────────────────────@────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<0.5*x_0 - 0.5*x_1>)───X───┼────────────────────────────────┼────┼@─────────────────────────────────┼───┼─────────────────────────────────┼──────────────────────────────@───@────────────────────────────────@────@───────────────────────────────────@────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                        │                                │    ││                                 │   │                                 │                              │   │                                │    │                                   │                                                                                                                                                                        │                                │    ││                                 │   │                                 │                              │   │                                │    │                                   │
# (0, 2): ───H───Rz(pi*<1.0*x_2>)────────────────────────────────────────X───Rz(pi*<0.5*x_0 - 0.5*x_2>)───X────┼X─────────────────────────────────┼───┼─────────────────────────────────┼Rz(pi*<0.5*x_1 - 0.5*x_2>)────X───┼────────────────────────────────┼────┼@──────────────────────────────────┼──────────────────────────────@───@────────────────────────────────@────────────────────────────────────────H───Rz(pi*<1.0*x_2>)────────────────────────────────────────X───Rz(pi*<0.5*x_0 - 0.5*x_2>)───X────┼X─────────────────────────────────┼───┼─────────────────────────────────┼Rz(pi*<0.5*x_1 - 0.5*x_2>)────X───┼────────────────────────────────┼────┼@──────────────────────────────────┼──────────────────────────────@───@────────────────────────────────@────────────────────────────────────────
#                                                                                                              │                                  │   │                                 │                                  │                                │    ││                                  │                              │   │                                │                                                                                                                                          │                                  │   │                                 │                                  │                                │    ││                                  │                              │   │                                │
# (0, 3): ───H───Rz(pi*<1.0*x_3>)──────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<0.5*x_0 - 0.5*x_3>)───X───┼─────────────────────────────────┼──────────────────────────────────X───Rz(pi*<0.5*x_1 - 0.5*x_3>)───X────┼X──────────────────────────────────┼Rz(pi*<0.5*x_2 - 0.5*x_3>)────X───┼────────────────────────────────┼───@────────────────────────────────@───H───Rz(pi*<1.0*x_3>)──────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<0.5*x_0 - 0.5*x_3>)───X───┼─────────────────────────────────┼──────────────────────────────────X───Rz(pi*<0.5*x_1 - 0.5*x_3>)───X────┼X──────────────────────────────────┼Rz(pi*<0.5*x_2 - 0.5*x_3>)────X───┼────────────────────────────────┼───@────────────────────────────────@───
#                                                                                                                                                     │                                 │                                                                        │                                   │                                  │                                │   │                                │                                                                                                                                            │                                 │                                                                        │                                   │                                  │                                │   │                                │
# (0, 4): ───H───Rz(pi*<1.0*x_4>)─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<0.5*x_0 - 0.5*x_4>)────X────────────────────────────────────────────────────────────────────────X─────Rz(pi*<0.5*x_1 - 0.5*x_4>)────X──────────────────────────────────X───Rz(pi*<0.5*x_2 - 0.5*x_4>)───X───X───Rz(pi*<0.5*x_3 - 0.5*x_4>)───X───H───Rz(pi*<1.0*x_4>)─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<0.5*x_0 - 0.5*x_4>)────X────────────────────────────────────────────────────────────────────────X─────Rz(pi*<0.5*x_1 - 0.5*x_4>)────X──────────────────────────────────X───Rz(pi*<0.5*x_2 - 0.5*x_4>)───X───X───Rz(pi*<0.5*x_3 - 0.5*x_4>)───X───
#                                                                                                             └──┘                                                                     └───────────────────────────┘                                            └──┘                                └───────────────────────────┘                                                                                                                                                                                  └──┘                                                                     └───────────────────────────┘                                            └──┘                                └───────────────────────────┘

# %%
# one_norm_distance
cq = SecondOrderExpansion(feature_dimension=5, encoding_map=one_norm_distance)
cq
# Out:
#                                                                                                               ┌──┐                                                                       ┌────────────────────────────┐                                             ┌──┐                                 ┌────────────────────────────┐                                                                                                                                                                                      ┌──┐                                                                       ┌────────────────────────────┐                                             ┌──┐                                 ┌────────────────────────────┐
# (0, 0): ───H───Rz(pi*<1.0*x_0>)───@─────────────────────────────────@───@─────────────────────────────────@────@───────────────────────────────────@───@──────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_0>)───@─────────────────────────────────@───@─────────────────────────────────@────@───────────────────────────────────@───@──────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                   │                                 │   │                                 │    │                                   │   │                                  │                                                                                                                                                                                                                                                      │                                 │   │                                 │    │                                   │   │                                  │
# (0, 1): ───H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<1.0*Abs(x_0 - x_1)>)───X───┼─────────────────────────────────┼────┼@──────────────────────────────────┼───┼──────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@────@────────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<1.0*Abs(x_0 - x_1)>)───X───┼─────────────────────────────────┼────┼@──────────────────────────────────┼───┼──────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@────@────────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                         │                                 │    ││                                  │   │                                  │                               │   │                                 │    │                                    │                                                                                                                                                                            │                                 │    ││                                  │   │                                  │                               │   │                                 │    │                                    │
# (0, 2): ───H───Rz(pi*<1.0*x_2>)─────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_2)>)───X────┼X──────────────────────────────────┼───┼──────────────────────────────────┼Rz(pi*<1.0*Abs(x_1 - x_2)>)────X───┼─────────────────────────────────┼────┼@───────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────H───Rz(pi*<1.0*x_2>)─────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_2)>)───X────┼X──────────────────────────────────┼───┼──────────────────────────────────┼Rz(pi*<1.0*Abs(x_1 - x_2)>)────X───┼─────────────────────────────────┼────┼@───────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────
#                                                                                                                │                                   │   │                                  │                                   │                                 │    ││                                   │                               │   │                                 │                                                                                                                                             │                                   │   │                                  │                                   │                                 │    ││                                   │                               │   │                                 │
# (0, 3): ───H───Rz(pi*<1.0*x_3>)────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_0 - x_3)>)───X───┼──────────────────────────────────┼───────────────────────────────────X───Rz(pi*<1.0*Abs(x_1 - x_3)>)───X────┼X───────────────────────────────────┼Rz(pi*<1.0*Abs(x_2 - x_3)>)────X───┼─────────────────────────────────┼───@─────────────────────────────────@───H───Rz(pi*<1.0*x_3>)────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_0 - x_3)>)───X───┼──────────────────────────────────┼───────────────────────────────────X───Rz(pi*<1.0*Abs(x_1 - x_3)>)───X────┼X───────────────────────────────────┼Rz(pi*<1.0*Abs(x_2 - x_3)>)────X───┼─────────────────────────────────┼───@─────────────────────────────────@───
#                                                                                                                                                        │                                  │                                                                          │                                    │                                   │                                 │   │                                 │                                                                                                                                               │                                  │                                                                          │                                    │                                   │                                 │   │                                 │
# (0, 4): ───H───Rz(pi*<1.0*x_4>)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_4)>)────X──────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_1 - x_4)>)────X───────────────────────────────────X───Rz(pi*<1.0*Abs(x_2 - x_4)>)───X───X───Rz(pi*<1.0*Abs(x_3 - x_4)>)───X───H───Rz(pi*<1.0*x_4>)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_4)>)────X──────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_1 - x_4)>)────X───────────────────────────────────X───Rz(pi*<1.0*Abs(x_2 - x_4)>)───X───X───Rz(pi*<1.0*Abs(x_3 - x_4)>)───X───
#                                                                                                               └──┘                                                                       └────────────────────────────┘                                             └──┘                                 └────────────────────────────┘                                                                                                                                                                                      └──┘                                                                       └────────────────────────────┘                                             └──┘                                 └────────────────────────────┘

# %%
# one_norm_distance
cq = SecondOrderExpansion(feature_dimension=5, encoding_map=one_norm_distance)
cq
# Out:
#                                                                                                               ┌──┐                                                                       ┌────────────────────────────┐                                             ┌──┐                                 ┌────────────────────────────┐                                                                                                                                                                                      ┌──┐                                                                       ┌────────────────────────────┐                                             ┌──┐                                 ┌────────────────────────────┐
# (0, 0): ───H───Rz(pi*<1.0*x_0>)───@─────────────────────────────────@───@─────────────────────────────────@────@───────────────────────────────────@───@──────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_0>)───@─────────────────────────────────@───@─────────────────────────────────@────@───────────────────────────────────@───@──────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                   │                                 │   │                                 │    │                                   │   │                                  │                                                                                                                                                                                                                                                      │                                 │   │                                 │    │                                   │   │                                  │
# (0, 1): ───H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<1.0*Abs(x_0 - x_1)>)───X───┼─────────────────────────────────┼────┼@──────────────────────────────────┼───┼──────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@────@────────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<1.0*Abs(x_0 - x_1)>)───X───┼─────────────────────────────────┼────┼@──────────────────────────────────┼───┼──────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@────@────────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                         │                                 │    ││                                  │   │                                  │                               │   │                                 │    │                                    │                                                                                                                                                                            │                                 │    ││                                  │   │                                  │                               │   │                                 │    │                                    │
# (0, 2): ───H───Rz(pi*<1.0*x_2>)─────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_2)>)───X────┼X──────────────────────────────────┼───┼──────────────────────────────────┼Rz(pi*<1.0*Abs(x_1 - x_2)>)────X───┼─────────────────────────────────┼────┼@───────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────H───Rz(pi*<1.0*x_2>)─────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_2)>)───X────┼X──────────────────────────────────┼───┼──────────────────────────────────┼Rz(pi*<1.0*Abs(x_1 - x_2)>)────X───┼─────────────────────────────────┼────┼@───────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────
#                                                                                                                │                                   │   │                                  │                                   │                                 │    ││                                   │                               │   │                                 │                                                                                                                                             │                                   │   │                                  │                                   │                                 │    ││                                   │                               │   │                                 │
# (0, 3): ───H───Rz(pi*<1.0*x_3>)────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_0 - x_3)>)───X───┼──────────────────────────────────┼───────────────────────────────────X───Rz(pi*<1.0*Abs(x_1 - x_3)>)───X────┼X───────────────────────────────────┼Rz(pi*<1.0*Abs(x_2 - x_3)>)────X───┼─────────────────────────────────┼───@─────────────────────────────────@───H───Rz(pi*<1.0*x_3>)────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_0 - x_3)>)───X───┼──────────────────────────────────┼───────────────────────────────────X───Rz(pi*<1.0*Abs(x_1 - x_3)>)───X────┼X───────────────────────────────────┼Rz(pi*<1.0*Abs(x_2 - x_3)>)────X───┼─────────────────────────────────┼───@─────────────────────────────────@───
#                                                                                                                                                        │                                  │                                                                          │                                    │                                   │                                 │   │                                 │                                                                                                                                               │                                  │                                                                          │                                    │                                   │                                 │   │                                 │
# (0, 4): ───H───Rz(pi*<1.0*x_4>)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_4)>)────X──────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_1 - x_4)>)────X───────────────────────────────────X───Rz(pi*<1.0*Abs(x_2 - x_4)>)───X───X───Rz(pi*<1.0*Abs(x_3 - x_4)>)───X───H───Rz(pi*<1.0*x_4>)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_4)>)────X──────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_1 - x_4)>)────X───────────────────────────────────X───Rz(pi*<1.0*Abs(x_2 - x_4)>)───X───X───Rz(pi*<1.0*Abs(x_3 - x_4)>)───X───
#                                                                                                               └──┘                                                                       └────────────────────────────┘                                             └──┘                                 └────────────────────────────┘                                                                                                                                                                                      └──┘                                                                       └────────────────────────────┘                                             └──┘                                 └────────────────────────────┘

# %%
# two_norm_distance
cq = SecondOrderExpansion(feature_dimension=5, encoding_map=two_norm_distance)
cq
# Out:
#                                                                                                               ┌──┐                                                                       ┌────────────────────────────┐                                             ┌──┐                                 ┌────────────────────────────┐                                                                                                                                                                                      ┌──┐                                                                       ┌────────────────────────────┐                                             ┌──┐                                 ┌────────────────────────────┐
# (0, 0): ───H───Rz(pi*<1.0*x_0>)───@─────────────────────────────────@───@─────────────────────────────────@────@───────────────────────────────────@───@──────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_0>)───@─────────────────────────────────@───@─────────────────────────────────@────@───────────────────────────────────@───@──────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                   │                                 │   │                                 │    │                                   │   │                                  │                                                                                                                                                                                                                                                      │                                 │   │                                 │    │                                   │   │                                  │
# (0, 1): ───H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<1.0*Abs(x_0 - x_1)>)───X───┼─────────────────────────────────┼────┼@──────────────────────────────────┼───┼──────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@────@────────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<1.0*Abs(x_0 - x_1)>)───X───┼─────────────────────────────────┼────┼@──────────────────────────────────┼───┼──────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@────@────────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                         │                                 │    ││                                  │   │                                  │                               │   │                                 │    │                                    │                                                                                                                                                                            │                                 │    ││                                  │   │                                  │                               │   │                                 │    │                                    │
# (0, 2): ───H───Rz(pi*<1.0*x_2>)─────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_2)>)───X────┼X──────────────────────────────────┼───┼──────────────────────────────────┼Rz(pi*<1.0*Abs(x_1 - x_2)>)────X───┼─────────────────────────────────┼────┼@───────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────H───Rz(pi*<1.0*x_2>)─────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_2)>)───X────┼X──────────────────────────────────┼───┼──────────────────────────────────┼Rz(pi*<1.0*Abs(x_1 - x_2)>)────X───┼─────────────────────────────────┼────┼@───────────────────────────────────┼───────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────
#                                                                                                                │                                   │   │                                  │                                   │                                 │    ││                                   │                               │   │                                 │                                                                                                                                             │                                   │   │                                  │                                   │                                 │    ││                                   │                               │   │                                 │
# (0, 3): ───H───Rz(pi*<1.0*x_3>)────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_0 - x_3)>)───X───┼──────────────────────────────────┼───────────────────────────────────X───Rz(pi*<1.0*Abs(x_1 - x_3)>)───X────┼X───────────────────────────────────┼Rz(pi*<1.0*Abs(x_2 - x_3)>)────X───┼─────────────────────────────────┼───@─────────────────────────────────@───H───Rz(pi*<1.0*x_3>)────────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_0 - x_3)>)───X───┼──────────────────────────────────┼───────────────────────────────────X───Rz(pi*<1.0*Abs(x_1 - x_3)>)───X────┼X───────────────────────────────────┼Rz(pi*<1.0*Abs(x_2 - x_3)>)────X───┼─────────────────────────────────┼───@─────────────────────────────────@───
#                                                                                                                                                        │                                  │                                                                          │                                    │                                   │                                 │   │                                 │                                                                                                                                               │                                  │                                                                          │                                    │                                   │                                 │   │                                 │
# (0, 4): ───H───Rz(pi*<1.0*x_4>)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_4)>)────X──────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_1 - x_4)>)────X───────────────────────────────────X───Rz(pi*<1.0*Abs(x_2 - x_4)>)───X───X───Rz(pi*<1.0*Abs(x_3 - x_4)>)───X───H───Rz(pi*<1.0*x_4>)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<1.0*Abs(x_0 - x_4)>)────X──────────────────────────────────────────────────────────────────────────X─────Rz(pi*<1.0*Abs(x_1 - x_4)>)────X───────────────────────────────────X───Rz(pi*<1.0*Abs(x_2 - x_4)>)───X───X───Rz(pi*<1.0*Abs(x_3 - x_4)>)───X───
#                                                                                                               └──┘                                                                       └────────────────────────────┘                                             └──┘                                 └────────────────────────────┘                                                                                                                                                                                      └──┘                                                                       └────────────────────────────┘                                             └──┘                                 └────────────────────────────┘

# %%
# arithmetic_mean
cq = SecondOrderExpansion(feature_dimension=5, encoding_map=arithmetic_mean)
cq
# Out:
#                                                                                                             ┌──┐                                                                     ┌───────────────────────────┐                                            ┌──┐                                ┌───────────────────────────┐                                                                                                                                                                                  ┌──┐                                                                     ┌───────────────────────────┐                                            ┌──┐                                ┌───────────────────────────┐
# (0, 0): ───H───Rz(pi*<1.0*x_0>)───@────────────────────────────────@───@────────────────────────────────@────@──────────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_0>)───@────────────────────────────────@───@────────────────────────────────@────@──────────────────────────────────@───@─────────────────────────────────@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                   │                                │   │                                │    │                                  │   │                                 │                                                                                                                                                                                                                                                │                                │   │                                │    │                                  │   │                                 │
# (0, 1): ───H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<0.5*x_0 + 0.5*x_1>)───X───┼────────────────────────────────┼────┼@─────────────────────────────────┼───┼─────────────────────────────────┼──────────────────────────────@───@────────────────────────────────@────@───────────────────────────────────@────────────────────────────────────────────────────────────────────────────────────────────────────────────H───Rz(pi*<1.0*x_1>)───X───Rz(pi*<0.5*x_0 + 0.5*x_1>)───X───┼────────────────────────────────┼────┼@─────────────────────────────────┼───┼─────────────────────────────────┼──────────────────────────────@───@────────────────────────────────@────@───────────────────────────────────@────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                        │                                │    ││                                 │   │                                 │                              │   │                                │    │                                   │                                                                                                                                                                        │                                │    ││                                 │   │                                 │                              │   │                                │    │                                   │
# (0, 2): ───H───Rz(pi*<1.0*x_2>)────────────────────────────────────────X───Rz(pi*<0.5*x_0 + 0.5*x_2>)───X────┼X─────────────────────────────────┼───┼─────────────────────────────────┼Rz(pi*<0.5*x_1 + 0.5*x_2>)────X───┼────────────────────────────────┼────┼@──────────────────────────────────┼──────────────────────────────@───@────────────────────────────────@────────────────────────────────────────H───Rz(pi*<1.0*x_2>)────────────────────────────────────────X───Rz(pi*<0.5*x_0 + 0.5*x_2>)───X────┼X─────────────────────────────────┼───┼─────────────────────────────────┼Rz(pi*<0.5*x_1 + 0.5*x_2>)────X───┼────────────────────────────────┼────┼@──────────────────────────────────┼──────────────────────────────@───@────────────────────────────────@────────────────────────────────────────
#                                                                                                              │                                  │   │                                 │                                  │                                │    ││                                  │                              │   │                                │                                                                                                                                          │                                  │   │                                 │                                  │                                │    ││                                  │                              │   │                                │
# (0, 3): ───H───Rz(pi*<1.0*x_3>)──────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<0.5*x_0 + 0.5*x_3>)───X───┼─────────────────────────────────┼──────────────────────────────────X───Rz(pi*<0.5*x_1 + 0.5*x_3>)───X────┼X──────────────────────────────────┼Rz(pi*<0.5*x_2 + 0.5*x_3>)────X───┼────────────────────────────────┼───@────────────────────────────────@───H───Rz(pi*<1.0*x_3>)──────────────────────────────────────────────────────────────────────────────X─────Rz(pi*<0.5*x_0 + 0.5*x_3>)───X───┼─────────────────────────────────┼──────────────────────────────────X───Rz(pi*<0.5*x_1 + 0.5*x_3>)───X────┼X──────────────────────────────────┼Rz(pi*<0.5*x_2 + 0.5*x_3>)────X───┼────────────────────────────────┼───@────────────────────────────────@───
#                                                                                                                                                     │                                 │                                                                        │                                   │                                  │                                │   │                                │                                                                                                                                            │                                 │                                                                        │                                   │                                  │                                │   │                                │
# (0, 4): ───H───Rz(pi*<1.0*x_4>)─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<0.5*x_0 + 0.5*x_4>)────X────────────────────────────────────────────────────────────────────────X─────Rz(pi*<0.5*x_1 + 0.5*x_4>)────X──────────────────────────────────X───Rz(pi*<0.5*x_2 + 0.5*x_4>)───X───X───Rz(pi*<0.5*x_3 + 0.5*x_4>)───X───H───Rz(pi*<1.0*x_4>)─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(pi*<0.5*x_0 + 0.5*x_4>)────X────────────────────────────────────────────────────────────────────────X─────Rz(pi*<0.5*x_1 + 0.5*x_4>)────X──────────────────────────────────X───Rz(pi*<0.5*x_2 + 0.5*x_4>)───X───X───Rz(pi*<0.5*x_3 + 0.5*x_4>)───X───
#                                                                                                             └──┘                                                                     └───────────────────────────┘                                            └──┘                                └───────────────────────────┘                                                                                                                                                                                  └──┘                                                                     └───────────────────────────┘                                            └──┘                                └───────────────────────────┘

# %% [markdown]
# # Data Preparation
# - train_val_test_split
# - prepare_train_val_test

# %%
# prepare some data
x = np.random.rand(10000, 10)*100*np.pi*np.random.rand()
x
# Out:
# array([[157.79001311,  70.04929402,  71.55883396, ..., 171.43148218,
#         115.76225797, 229.14548923],
#        [ 89.44028036, 104.9196503 ,  15.91713856, ...,  12.76373688,
#          89.55617693, 140.80399175],
#        [211.84945037, 275.72773228, 169.95900704, ..., 234.53571164,
#         114.40073047, 168.41078689],
#        ...,
#        [ 64.09828913, 211.50417713,  14.56973993, ...,  93.30176262,
#         256.56919173, 111.59967609],
#        [255.86275273,  10.96735271, 144.33861285, ..., 211.59685015,
#         199.16905836, 164.76812045],
#        [ 33.48571404,  66.98772972, 188.04611811, ..., 153.66665153,
#         171.52597537, 243.47291875]])

# %%
y = np.random.choice([0.0, 1.0], 10000)
y
# Out:
# array([0., 1., 0., ..., 1., 0., 1.])

# %%
from quple.components.data_preparation import train_val_test_split
# split data into training, validation and test set with shuffling and random state = 1
x_train, x_val, x_test, y_train, y_val, y_test = train_val_test_split(x, y, train_size=1000, val_size=1000, test_size=1000, shuffle=True, random_state=1)

# %%
print('x_train:\n',x_train)
print('x_val:\n',x_val)
print('x_test:\n',x_test)
print('x_train_shape:\n',x_train.shape)
print('x_val.shape:\n',x_val.shape)
print('x_test.shape:\n',x_test.shape)
# Out:
# x_train:
#  [[219.21887634  33.15887656  36.1754538  ...  56.15324241 200.9842209
#   273.95614268]
#  [ 71.92414731 193.42190739 193.04927405 ... 212.1005148  119.1732603
#   211.72017146]
#  [ 66.58651841 113.69501657 215.52635998 ...  53.06684233 194.30253389
#    81.01245488]
#  ...
#  [108.37903712  68.43270912 142.95163497 ... 219.99870539 225.29318159
#     4.12243588]
#  [ 87.59693194 176.82231774 247.12747437 ...  82.95632015 269.43212575
#    49.21080851]
#  [ 83.05830581  95.84480877 186.21160934 ...  88.05487166 234.82028805
#    51.40324513]]
# x_val:
#  [[172.33776738 108.00834738 236.32597642 ...  71.68178543  34.60855876
#   114.37674893]
#  [106.23846574 177.59532102 164.91371452 ... 261.34252214 230.21942805
#   214.3846508 ]
#  [ 42.45725653   3.70938521 163.11767851 ...  56.74193614  56.87160318
#   274.33756001]
#  ...
#  [ 23.73895505  55.96228742 124.20263425 ... 117.7458726  210.87301437
#   257.54450666]
#  [165.03912989   7.71052492  10.24761475 ... 126.2461195  160.04599341
#   264.77959208]
#  [  7.60945045 264.43170266 176.65673805 ...  74.61144174 280.58099599
#    34.45376838]]
# x_test:
#  [[235.53101942 151.47512073  43.35620065 ... 282.02488722 273.37220708
#   135.73495524]
#  [119.38269915  28.19376006  75.25810548 ... 213.61373671 205.56707584
#   182.49651538]
#  [ 79.19656061 135.39517943 220.76527471 ... 116.9649252  164.05240103
#    70.04397326]
#  ...
#  [219.52117225  70.23467837  70.60980848 ... 274.66944723 113.18571368
#   134.52231223]
#  [122.53425788 223.07338077  41.33976851 ... 230.61091349   3.7712983
#   115.54717267]
#  [219.2227877  122.63940692 283.30745446 ...  55.82840246 216.02772391
#    16.00059736]]
# x_train_shape:
#  (1000, 10)
# x_val.shape:
#  (1000, 10)
# x_test.shape:
#  (1000, 10)

# %%
# on top of train val test split, apply data preprocessing to the datasets

# prepare data preprocessors from sklearn
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
# Apply 3 data preprocessors
# 1. PCA to reduce the dimension to 5 to fit the 5 qubit circuit
# 2. StandardScaler to standardize features by removing the mean and scaling to unit variance
# 3. MinMaxScaler to bound the data in the range [-1,+1]
preprocessors = [PCA(n_components=5, random_state=3), StandardScaler(), MinMaxScaler((-1,1))]

# %%
from quple.components.data_preparation import prepare_train_val_test
# obtain the train, val, test datasets with the preprocessors applied
x_train, x_val, x_test, y_train, y_val, y_test = prepare_train_val_test(x, y, train_size=1000, val_size=1000, test_size=1000, preprocessors=preprocessors, random_state=1)

# %%
print('x_train:\n',x_train)
print('x_val:\n',x_val)
print('x_test:\n',x_test)
print('x_train_shape:\n',x_train.shape)
print('x_val.shape:\n',x_val.shape)
print('x_test.shape:\n',x_test.shape)
# Out:
# x_train:
#  [[-0.07455046 -0.39284526  0.27437889 -0.94007422 -0.41180185]
#  [-0.10003017  0.04320058 -0.15905658  0.11854155  0.02923276]
#  [-0.22877319  0.15616646 -0.22927625  0.37641033  0.22751985]
#  ...
#  [ 0.62056589 -0.32941636 -0.26678905  0.23852285 -0.34540379]
#  [-0.16618916 -0.23081362 -0.47128323  0.58546947  0.06406358]
#  [ 0.34496044 -0.67725575 -0.17415756  0.10337359  0.31951833]]
# x_val:
#  [[-0.11657211  0.66206459  0.14273131  0.19249593  0.126921  ]
#  [-0.43711241  0.35440125 -0.71756878 -0.01984083 -0.12598538]
#  [ 0.17592374 -0.1034906   0.25898319 -0.69614865  0.26454743]
#  ...
#  [ 0.00109932 -0.41830543 -0.23786575 -0.66882243  0.34847173]
#  [-0.69741426 -0.18281685 -0.1630699  -0.6457326  -0.00269232]
#  [ 0.25131258 -0.45135426 -0.10810843  0.46988086 -0.1852126 ]]
# x_test:
#  [[-0.276386   -0.38096259 -0.43870381 -0.09696832  0.06071903]
#  [ 0.23083781 -0.41452088 -0.42731898 -0.67432446 -0.4115954 ]
#  [ 0.15848221 -0.09737157 -0.27822728  0.25902719 -0.13725644]
#  ...
#  [-0.00865328  0.24815099  0.03576477  0.01529799 -0.13230641]
#  [-0.15755126 -0.15032501 -0.09028129 -0.00930096 -0.79722104]
#  [ 0.07885293 -0.37952911 -0.04366002  0.6274123   0.59498161]]
# x_train_shape:
#  (1000, 5)
# x_val.shape:
#  (1000, 5)
# x_test.shape:
#  (1000, 5)
