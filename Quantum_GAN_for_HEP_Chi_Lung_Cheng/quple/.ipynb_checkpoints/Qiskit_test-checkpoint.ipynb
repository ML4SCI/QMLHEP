# %%
#/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/qiskit
from qiskit.circuit.library import PauliFeatureMap

# %%
prep = PauliFeatureMap(4, reps=1, paulis=['ZZ'])

# %%
prep._build()
print(prep)
# Out:
#      ┌───┐                                                                    »
# q_0: ┤ H ├──■─────────────────────────────────────────────────────────────────»
#      ├───┤┌─┴─┐┌─────────────────────────────────────────────────────────────┐»
# q_1: ┤ H ├┤ X ├┤ U1(2.0*(3.14159265358979 - x[0])*(3.14159265358979 - x[1])) ├»
#      ├───┤└───┘└─────────────────────────────────────────────────────────────┘»
# q_2: ┤ H ├────────────────────────────────────────────────────────────────────»
#      ├───┤                                                                    »
# q_3: ┤ H ├────────────────────────────────────────────────────────────────────»
#      └───┘                                                                    »
# «                                                                              »
# «q_0: ──■────■─────────────────────────────────────────────────────────────────»
# «     ┌─┴─┐  │                                                                 »
# ...
