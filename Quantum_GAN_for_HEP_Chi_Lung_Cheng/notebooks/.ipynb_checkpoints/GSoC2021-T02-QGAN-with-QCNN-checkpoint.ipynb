# %%
import os
import glob
import operator
import numpy as np
import pandas
import h5py
import tensorflow as tf
import tensorflow_quantum as tfq

# %%
# for reproducibility
tf.random.set_seed(2021)
np.random.seed(2021)

# %% [markdown]
# # Section 1 - Data Preprocessing

# %% [markdown]
# ## 1.1 Load Photon-Electron data

# %%
# use the cern afs public path or your own path containing the training data
data_dir = "/afs/cern.ch/work/c/chlcheng/public/GSoC2021/data"
photon_path = os.path.join(data_dir, "photon.hdf5")
electron_path = os.path.join(data_dir, "electron.hdf5")

# %%
# load photon data
with h5py.File(photon_path, "r") as f:
    px = np.asarray(f['X'][()], dtype=np.float32)[:,:,:,0]
    py = np.asarray(f['y'][()], dtype=np.float32)

# load electron data
with h5py.File(electron_path, "r") as f:
    ex = np.asarray(f['X'][()], dtype=np.float32)[:,:,:,0]
    ey = np.asarray(f['y'][()], dtype=np.float32)

# %% [markdown]
# ## 1.2 Image Visualization

# %%
particle_label_map = {
    0: 'photon',
    1: 'electron'
}
import matplotlib.pyplot as plt
def vitualize_image(img, labels, name=None):
    columns = 8
    size = img.shape[0]
    rows = ( size // columns ) + 1
    fig = plt.figure(figsize=(20, rows*3))
    plt.subplots_adjust(hspace=0.3)
    for i in range(img.shape[0]):
        ax = fig.add_subplot(rows, columns, i+1)
        ax.set_title('Image {}: {}'.format(i+1, particle_label_map[labels[i]]))
        plt.imshow(img[i])
    if name is not None:
        plt.savefig(name, bbox_inches="tight")
    return plt

# %%
# let's just visualize the photon image
vitualize_image(px[:16], py[:16], name="images/cnn_raw_image_photon.pdf")
# Out:
# <module 'matplotlib.pyplot' from '/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## 1.3 Prepare Training Dataset
#
# - Let's just train on the photon data first and split the data into 75% train and 25% test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(px, py, train_size=0.75, test_size=0.25, random_state=2021)

# %% [markdown]
# ## 1.4 Image Cropping
#
# Note that the image is
# 1. Mostly empty except at the center
# 2. All jets are centered and aligned in the same direction (horizontally)
#
# That means we can crop out the central region of the image without losing much information about the jet. And we don't need to rotate the image.
#
# So by inspection, it should be safe to **crop out the central (8x8) grid**.

# %%
def crop_image(img, dimension):
    start = tuple(map(lambda a, da: a//2-da//2, img.shape, dimension))
    end = tuple(map(operator.add, start, dimension))
    slices = tuple(map(slice, start, end))
    return img[slices]

# %%
crop_size = (8, 8)
x_train_cropped = np.array([crop_image(i, crop_size) for i in x_train])
x_test_cropped = np.array([crop_image(i, crop_size) for i in x_test])

# %%
vitualize_image(x_train_cropped[:16], y_train[:16],  name="images/cnn_cropped_image_photon.pdf")
# Out:
# <module 'matplotlib.pyplot' from '/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## 1.6 Rescale data to the range appropriate for quantum data encoding
#
# - Usually classical data is encoded as the rotation angle of a gate operation in a quantum circuit which has a valid range of $[-\pi,+\pi]$. However, from past experience a smaller range will suffice and even show better performance than the valid range itself. So for this task, we will be **rescaling our data to a unit range (i.e. $[0, +1]$)** following the range used by  the`tensorflow_quantum` tutorial for MNIST classification (https://www.tensorflow.org/quantum/tutorials/mnist). Alternative, one may also use another common range $[-1, +1]$ for example from https://arxiv.org/abs/1906.10467.

# %%
def rescale_data(*data, val_range = (0, 1.)):
    min_value = np.min([np.min(d) for d in data])
    max_value = np.max([np.max(d) for d in data])
    range_min = val_range[0]
    range_max = val_range[1]
    rescaled_data = tuple([(((d-min_value)/(max_value-min_value))*(range_max-range_min))+range_min for d in data])
    return rescaled_data
x_train_rescaled, x_test_rescaled = rescale_data(x_train_cropped, x_test_cropped, val_range=(-1, 1))

# %%
vitualize_image(x_train_rescaled[:16], y_train[:16],  name="images/cnn_rescaled_image_photon.pdf")
# Out:
# <module 'matplotlib.pyplot' from '/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
image_shape = x_train_rescaled.shape[1:]
image_shape
# Out:
# (8, 8)

# %% [markdown]
# # Section 2 - QGAN with Classical Generator and QCNN Discriminator

# %% [markdown]
# ## 2.1 Create classical generator model

# %%
def create_classical_generator():
    model = tf.keras.Sequential()
    # foundation for 2x2 image
    n_nodes = 32 * 2 * 2
    model.add(tf.keras.layers.Dense(n_nodes, use_bias=False, input_shape=(100,)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Reshape((2, 2, 32)))

    model.add(tf.keras.layers.Conv2DTranspose(32, (2,2), strides=(1,1), padding="same", use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    # upsample to 4x4
    model.add(tf.keras.layers.Conv2DTranspose(16, (2,2), strides=(2,2), padding="same", use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())    
    # upsample to 8x8
    model.add(tf.keras.layers.Conv2DTranspose(1, (3,3), strides=(2,2), padding="same", use_bias=False, activation='tanh'))
    model.add(tf.keras.layers.Reshape((8, 8)))
    return model

# %%
classical_generator = create_classical_generator()

# %% [markdown]
# ## 2.2 Create QCNN discriminator
#
# - We will use a 3x3 quantum filter in terms of a 9 qubit PQC

# %%
n_qubit = feature_dimension = 9

# %% [markdown]
# ### Data Encoding Circuit for the 3 x 3 data window
#
# - Just some normal circuit choice taken from the QSVM paper I involved in
# - qubit (0, 0) represents top left pixel and qubit (0, 9) represents bottom right pixel

# %%
## deprecated
#from quple.data_encoding import  EncodingCircuit
#from quple import PauliBlock
#from quple.data_encoding import polynomial
#degree = 3

from quple.data_encoding import FirstOrderPauliZEncoding
# create a data circuit for encoding the 3x3 data window
'''
data_circuit = EncodingCircuit(feature_dimension=n_qubit, 
                                copies=2,
                                rotation_blocks=['H',PauliBlock('Z', polynomial(1)),
                                                   PauliBlock('Y',polynomial(1))],
                                entanglement_blocks=[PauliBlock('ZZ',polynomial(1))],
                                entangle_strategy='alternate_linear')
'''
data_circuit = FirstOrderPauliZEncoding(feature_dimension=n_qubit, copies=3, parameter_scale=1)
data_circuit
# Out:
# (0, 0): ───H───Rz(pi*<x_0/pi>)───H───Rz(pi*<x_0/pi>)───H───Rz(pi*<x_0/pi>)───
#
# (0, 1): ───H───Rz(pi*<x_1/pi>)───H───Rz(pi*<x_1/pi>)───H───Rz(pi*<x_1/pi>)───
#
# (0, 2): ───H───Rz(pi*<x_2/pi>)───H───Rz(pi*<x_2/pi>)───H───Rz(pi*<x_2/pi>)───
#
# (0, 3): ───H───Rz(pi*<x_3/pi>)───H───Rz(pi*<x_3/pi>)───H───Rz(pi*<x_3/pi>)───
#
# (0, 4): ───H───Rz(pi*<x_4/pi>)───H───Rz(pi*<x_4/pi>)───H───Rz(pi*<x_4/pi>)───
#
# (0, 5): ───H───Rz(pi*<x_5/pi>)───H───Rz(pi*<x_5/pi>)───H───Rz(pi*<x_5/pi>)───
#
# (0, 6): ───H───Rz(pi*<x_6/pi>)───H───Rz(pi*<x_6/pi>)───H───Rz(pi*<x_6/pi>)───
#
# (0, 7): ───H───Rz(pi*<x_7/pi>)───H───Rz(pi*<x_7/pi>)───H───Rz(pi*<x_7/pi>)───
#
# (0, 8): ───H───Rz(pi*<x_8/pi>)───H───Rz(pi*<x_8/pi>)───H───Rz(pi*<x_8/pi>)───

# %% [markdown]
# ### Kernel Circuit for the Quantum Filter
#
# - Just some random 3x3 = 9 qubit PQC with entanglement

# %%
from quple import ParameterisedCircuit

# %%
kernel_circuit = ParameterisedCircuit(n_qubit=n_qubit, copies=3, 
                                      rotation_blocks=["RZ", "RY"],
                                      entanglement_blocks=["XX"],
                                      entangle_strategy="alternate_linear")
kernel_circuit
# Out:
# (0, 0): ───Rz(θ_0)───Ry(θ_9)────XX──────────Rz(θ_26)────Ry(θ_35)──────────────XX──────────Rz(θ_52)────Ry(θ_61)──────────────XX──────────────────────
#                                 │                                             │                                             │
# (0, 1): ───Rz(θ_1)───Ry(θ_10)───XX^(θ_18)───XX──────────Rz(θ_27)───Ry(θ_36)───XX^(θ_44)───XX──────────Rz(θ_53)───Ry(θ_62)───XX^(θ_70)───XX──────────
#                                             │                                             │                                             │
# (0, 2): ───Rz(θ_2)───Ry(θ_11)───XX──────────XX^(θ_22)───Rz(θ_28)───Ry(θ_37)───XX──────────XX^(θ_48)───Rz(θ_54)───Ry(θ_63)───XX──────────XX^(θ_74)───
#                                 │                                             │                                             │
# (0, 3): ───Rz(θ_3)───Ry(θ_12)───XX^(θ_19)───XX──────────Rz(θ_29)───Ry(θ_38)───XX^(θ_45)───XX──────────Rz(θ_55)───Ry(θ_64)───XX^(θ_71)───XX──────────
#                                             │                                             │                                             │
# (0, 4): ───Rz(θ_4)───Ry(θ_13)───XX──────────XX^(θ_23)───Rz(θ_30)───Ry(θ_39)───XX──────────XX^(θ_49)───Rz(θ_56)───Ry(θ_65)───XX──────────XX^(θ_75)───
#                                 │                                             │                                             │
# (0, 5): ───Rz(θ_5)───Ry(θ_14)───XX^(θ_20)───XX──────────Rz(θ_31)───Ry(θ_40)───XX^(θ_46)───XX──────────Rz(θ_57)───Ry(θ_66)───XX^(θ_72)───XX──────────
#                                             │                                             │                                             │
# (0, 6): ───Rz(θ_6)───Ry(θ_15)───XX──────────XX^(θ_24)───Rz(θ_32)───Ry(θ_41)───XX──────────XX^(θ_50)───Rz(θ_58)───Ry(θ_67)───XX──────────XX^(θ_76)───
#                                 │                                             │                                             │
# (0, 7): ───Rz(θ_7)───Ry(θ_16)───XX^(θ_21)───XX──────────Rz(θ_33)───Ry(θ_42)───XX^(θ_47)───XX──────────Rz(θ_59)───Ry(θ_68)───XX^(θ_73)───XX──────────
#                                             │                                             │                                             │
# (0, 8): ───Rz(θ_8)───Ry(θ_17)───────────────XX^(θ_25)───Rz(θ_34)───Ry(θ_43)───────────────XX^(θ_51)───Rz(θ_60)───Ry(θ_69)───────────────XX^(θ_77)───

# %% [markdown]
# - after 2 convolution with strides = (2, 2), the image dimension will be (2, 2) so we can just use a 4 qubit PQC for the final output

# %%
from quple.data_encoding import  EncodingCircuit
from quple import PauliBlock
from quple.data_encoding.encoding_maps import polynomial
degree = 3
# create a data circuit for encoding the 3x3 data window
'''
output_data_circuit = EncodingCircuit(feature_dimension=4, 
                                copies=2,
                                rotation_blocks=['H',PauliBlock('Z', polynomial(1)),
                                                   PauliBlock('Y',polynomial(1))],
                                entanglement_blocks=[PauliBlock('ZZ',polynomial(1))],
                                entangle_strategy='alternate_linear')
'''
output_data_circuit = FirstOrderPauliZEncoding(feature_dimension=4, copies=3, parameter_scale=1)
output_data_circuit
# Out:
# (0, 0): ───H───Rz(pi*<x_0/pi>)───H───Rz(pi*<x_0/pi>)───H───Rz(pi*<x_0/pi>)───
#
# (0, 1): ───H───Rz(pi*<x_1/pi>)───H───Rz(pi*<x_1/pi>)───H───Rz(pi*<x_1/pi>)───
#
# (0, 2): ───H───Rz(pi*<x_2/pi>)───H───Rz(pi*<x_2/pi>)───H───Rz(pi*<x_2/pi>)───
#
# (0, 3): ───H───Rz(pi*<x_3/pi>)───H───Rz(pi*<x_3/pi>)───H───Rz(pi*<x_3/pi>)───

# %%
output_model_circuit = ParameterisedCircuit(n_qubit=4, copies=3, 
                                      rotation_blocks=["RZ", "RY"],
                                      entanglement_blocks=["XX"])
output_model_circuit
# Out:
#                                                      ┌──────────────────┐                                                              ┌──────────────────┐                                                              ┌──────────────────┐
# (0, 0): ───Rz(θ_0)───Ry(θ_4)───XX─────────XX──────────XX────────────────────────────────Rz(θ_14)────Ry(θ_18)───XX──────────XX───────────XX────────────────────────────────Rz(θ_28)────Ry(θ_32)───XX──────────XX───────────XX────────────────────────────────────────────
#                                │          │           │                                                        │           │            │                                                        │           │            │
# (0, 1): ───Rz(θ_1)───Ry(θ_5)───XX^(θ_8)───┼───────────┼────────XX───────────XX──────────Rz(θ_15)────Ry(θ_19)───XX^(θ_22)───┼────────────┼────────XX───────────XX──────────Rz(θ_29)────Ry(θ_33)───XX^(θ_36)───┼────────────┼────────XX───────────XX──────────────────────
#                                           │           │        │            │                                              │            │        │            │                                              │            │        │            │
# (0, 2): ───Rz(θ_2)───Ry(θ_6)──────────────XX^(θ_9)────┼────────XX^(θ_11)────┼───────────XX──────────Rz(θ_16)───Ry(θ_20)────XX^(θ_23)────┼────────XX^(θ_25)────┼───────────XX──────────Rz(θ_30)───Ry(θ_34)────XX^(θ_37)────┼────────XX^(θ_39)────┼───────────XX──────────
#                                                       │                     │           │                                               │                     │           │                                               │                     │           │
# (0, 3): ───Rz(θ_3)───Ry(θ_7)──────────────────────────XX^(θ_10)─────────────XX^(θ_12)───XX^(θ_13)───Rz(θ_17)───Ry(θ_21)─────────────────XX^(θ_24)─────────────XX^(θ_26)───XX^(θ_27)───Rz(θ_31)───Ry(θ_35)─────────────────XX^(θ_38)─────────────XX^(θ_40)───XX^(θ_41)───
#                                                      └──────────────────┘                                                              └──────────────────┘                                                              └──────────────────┘

# %%
from quple.interface.tfq.layers import QConv2D, PQC
import cirq
import tensorflow as tf
#let's measure the last qubit
readout = [cirq.Z(kernel_circuit.qubits[-1])]
final_readout = [cirq.Z(output_model_circuit.qubits[-1])]

# create the quantum discriminator model
quantum_discriminator = tf.keras.Sequential()
quantum_discriminator.add(tf.keras.layers.Input(shape=(8, 8), dtype=tf.float32))
quantum_discriminator.add(QConv2D(kernel_circuit, data_circuit, readout, kernel_size=(3, 3), strides=(1, 1), padding="same"))
quantum_discriminator.add(tf.keras.layers.Reshape((8, 8, 1)))
quantum_discriminator.add(tf.keras.layers.MaxPooling2D((2,2)))
#quantum_discriminator.add(tf.keras.layers.LeakyReLU())
#quantum_discriminator.add(tf.keras.layers.Dropout(0.3))    
quantum_discriminator.add(QConv2D(kernel_circuit, data_circuit, readout, kernel_size=(3, 3), strides=(1, 1), padding="same"))
quantum_discriminator.add(tf.keras.layers.Reshape((4, 4, 1)))
quantum_discriminator.add(tf.keras.layers.MaxPooling2D((2,2)))
#quantum_discriminator.add(tf.keras.layers.LeakyReLU())
#quantum_discriminator.add(tf.keras.layers.Dropout(0.3))
quantum_discriminator.add(tf.keras.layers.Flatten())
quantum_discriminator.add(PQC(output_model_circuit, output_data_circuit, final_readout))

# %% [markdown]
# ## Create QGAN model

# %%
from quple.models import QGAN
qgan = QGAN(classical_generator, quantum_discriminator, encoding_circuit=None,
            latent_dim=100,
            epochs=50, d_lr=1e-3, g_lr=1e-3, random_state=2021, batch_size=128,
            checkpoint_dir="./training_checkpoints/qgan_with_cnn/")
# Out:
# Summary of Generator
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 128)               12800
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# reshape_20 (Reshape)         (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_transpose_15 (Conv2DT (None, 2, 2, 32)          4096
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2, 2, 32)          128
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_transpose_16 (Conv2DT (None, 4, 4, 16)          2048
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 4, 4, 16)          64
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_transpose_17 (Conv2DT (None, 8, 8, 1)           144
# _________________________________________________________________
# reshape_21 (Reshape)         (None, 8, 8)              0
# =================================================================
# Total params: 19,792
# Trainable params: 19,440
# Non-trainable params: 352
# _________________________________________________________________
# Summary of Discriminator
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# q_conv2d_17 (QConv2D)        (None, 8, 8)              78
# _________________________________________________________________
# reshape_26 (Reshape)         (None, 8, 8, 1)           0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 4, 1)           0
# _________________________________________________________________
# q_conv2d_18 (QConv2D)        (None, 4, 4)              78
# _________________________________________________________________
# reshape_27 (Reshape)         (None, 4, 4, 1)           0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 2, 2, 1)           0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 4)                 0
# _________________________________________________________________
# pqc_7 (PQC)                  (None, 1)                 42
# =================================================================
# Total params: 198
# Trainable params: 198
# Non-trainable params: 0
# _________________________________________________________________

# %%
qgan.enable_visualization(image_shape, n_image=16)

# %%
g_loss, d_loss = qgan.train(x_train_rescaled[:1280])

# %%
from quple.models import QGAN
qgan = QGAN(classical_generator, quantum_discriminator, encoding_circuit=None,
            latent_dim=100,
            epochs=50, d_lr=2e-3, g_lr=1e-3, random_state=2021, batch_size=32,
            checkpoint_dir="./training_checkpoints/qgan_with_cnn2/")
# Out:
# Summary of Generator
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 128)               12800
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# reshape_8 (Reshape)          (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 2, 2, 32)          4096
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 2, 2, 32)          128
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 4, 4, 16)          2048
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 4, 16)          64
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_transpose_8 (Conv2DTr (None, 8, 8, 1)           144
# _________________________________________________________________
# reshape_9 (Reshape)          (None, 8, 8)              0
# =================================================================
# Total params: 19,792
# Trainable params: 19,440
# Non-trainable params: 352
# _________________________________________________________________
# Summary of Discriminator
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# q_conv2d_7 (QConv2D)         (None, 8, 8)              78
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 8, 8, 1)           0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 1)           0
# _________________________________________________________________
# q_conv2d_8 (QConv2D)         (None, 4, 4)              78
# _________________________________________________________________
# reshape_11 (Reshape)         (None, 4, 4, 1)           0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 1)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4)                 0
# _________________________________________________________________
# pqc_2 (PQC)                  (None, 1)                 42
# =================================================================
# Total params: 198
# Trainable params: 198
# Non-trainable params: 0
# _________________________________________________________________

# %%
qgan.enable_visualization(image_shape, n_image=16)

# %%
g_loss, d_loss = qgan.train(x_train_rescaled[:200])

# %%
from quple.models import QGAN
qgan = QGAN(classical_generator, quantum_discriminator, encoding_circuit=None,
            latent_dim=100,
            epochs=50, d_lr=1e-3, g_lr=1e-3, random_state=2021, batch_size=32,
            checkpoint_dir="./training_checkpoints/qgan_with_cnn3/")
# Out:
# Summary of Generator
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               12800
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# reshape_16 (Reshape)         (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_transpose_12 (Conv2DT (None, 2, 2, 32)          4096
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 2, 2, 32)          128
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_transpose_13 (Conv2DT (None, 4, 4, 16)          2048
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4, 4, 16)          64
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_transpose_14 (Conv2DT (None, 8, 8, 1)           144
# _________________________________________________________________
# reshape_17 (Reshape)         (None, 8, 8)              0
# =================================================================
# Total params: 19,792
# Trainable params: 19,440
# Non-trainable params: 352
# _________________________________________________________________
# Summary of Discriminator
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# q_conv2d_11 (QConv2D)        (None, 8, 8)              78
# _________________________________________________________________
# reshape_18 (Reshape)         (None, 8, 8, 1)           0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 1)           0
# _________________________________________________________________
# q_conv2d_12 (QConv2D)        (None, 4, 4)              78
# _________________________________________________________________
# reshape_19 (Reshape)         (None, 4, 4, 1)           0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 2, 2, 1)           0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4)                 0
# _________________________________________________________________
# pqc_4 (PQC)                  (None, 1)                 42
# =================================================================
# Total params: 198
# Trainable params: 198
# Non-trainable params: 0
# _________________________________________________________________

# %%
qgan.enable_visualization(image_shape, n_image=16)

# %%
g_loss, d_loss = qgan.train(x_train_rescaled[200:400])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-4bfb62840150> in <module>
# ----> 1 g_loss, d_loss = qgan.train(x_train_rescaled[200:400])
#
# /afs/cern.ch/work/c/chlcheng/Repository/quple/quple/models/gan/qgan.py in train(self, x)
#     239         for epoch in range(self.epochs):
#     240             for batch in batches:
# --> 241                 gen_loss, disc_loss = self.train_step(batch)
#     242                 g_metric(gen_loss)
#     243                 d_metric(disc_loss)
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
