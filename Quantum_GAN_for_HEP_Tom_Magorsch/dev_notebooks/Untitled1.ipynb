# %%
import pennylane as qml

# %%
dev = qml.device("lightning.qubit", wires=18, shots=200000)

@qml.qnode(dev)
def circuit(x):
    for i in range(18): qml.Hadamard(wires=i)
    return qml.counts()

# %%
circuit(1)
# Out:
# {'000000000000000011': 1,
#  '000000000000000100': 1,
#  '000000000000001000': 1,
#  '000000000000001001': 1,
#  '000000000000001100': 1,
#  '000000000000001110': 2,
#  '000000000000010000': 2,
#  '000000000000010001': 1,
#  '000000000000010010': 1,
#  '000000000000010100': 1,
#  '000000000000010101': 1,
#  '000000000000010110': 3,
#  '000000000000010111': 2,
#  '000000000000011001': 1,
#  '000000000000011011': 1,
#  '000000000000011100': 1,
#  '000000000000011101': 2,
#  '000000000000011111': 1,
#  '000000000000100000': 1,
#  '000000000000100001': 1,
#  '000000000000100100': 2,
#  '000000000000100110': 1,
#  '000000000000101000': 1,
#  '000000000000101001': 2,
#  '000000000000101010': 2,
#  '000000000000101011': 1,
#  '000000000000101100': 3,
#  '000000000000110001': 1,
#  '000000000000110010': 1,
#  '000000000000110011': 1,
#  '000000000000110100': 1,
#  '000000000000110101': 2,
#  '000000000000111000': 1,
#  '000000000000111010': 2,
#  '000000000000111011': 1,
# ...
